# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
import requests
from pymongo.mongo_client import MongoClient

# %%
CONNECTION_URI = "mongodb+srv://fayadchowdhury:733squashBC@squashbc.ss6kkda.mongodb.net/?retryWrites=true&w=majority&appName=squashbc"

# %%
client = MongoClient(CONNECTION_URI)

# %%
# This works. Nice!
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print("Error: " + str(e))
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ### Get players aggregated data

# %%
players_collection = client["squashbc"]["players_aggregated"]

# %%
players = players_collection.find()

# %%
players_list = list(players)

# %%
players_list
# Out:
# [{'_id': 468003,
#   'fname': 'Stephane',
#   'lname': 'Melanson',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.73, 'ranking': 91}]},
#  {'_id': 405126,
#   'fname': 'Steffen',
#   'lname': 'Hoyemsvoll',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.26, 'ranking': 60}]},
#  {'_id': 255882,
#   'fname': 'Morgan',
#   'lname': 'Latremouille',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.96, 'ranking': 3},
#    {'category': 'doubles', 'rating': 5.59, 'ranking': 2}]},
#  {'_id': 479459,
#   'fname': 'Ben',
#   'lname': 'Hooker',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.45, 'ranking': 39}]},
#  {'_id': 242606,
#   'fname': 'Rashid',
#   'lname': 'Aziz',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 4.48, 'ranking': 2}]},
#  {'_id': 298218,
#   'fname': 'Elsie',
#   'lname': 'Krebs',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 2.4, 'ranking': 19}]},
#  {'_id': 396051,
#   'fname': 'Micah',
#   'lname': 'Burns',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 2.87, 'ranking': 106}]},
#  {'_id': 303657,
#   'fname': 'Christopher',
#   'lname': 'Purdon',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.8, 'ranking': 86}]},
#  {'_id': 298660,
#   'fname': 'Travis',
#   'lname': 'Mallow',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.61, 'ranking': 36}]},
#  {'_id': 405190,
#   'fname': 'Robin',
#   'lname': 'Heppenstall',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 3.99, 'ranking': 6}]},
#  {'_id': 385805,
#   'fname': 'Joanne',
#   'lname': 'Ditommaso',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 1.99, 'ranking': 15}]},
#  {'_id': 385904,
#   'fname': 'Liesje',
#   'lname': 'Ryerson',
#   'gender': 'women',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 4}]},
#  {'_id': 298148,
#   'fname': 'Todd',
#   'lname': 'Biffard',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.68, 'ranking': 34}]},
#  {'_id': 251534,
#   'fname': 'Ashwani',
#   'lname': 'Narwani',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.03, 'ranking': 81}]},
#  {'_id': 449803,
#   'fname': 'rhys',
#   'lname': 'blumer',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.36, 'ranking': 20}]},
#  {'_id': 257958,
#   'fname': 'Matthew',
#   'lname': 'Wong',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 4.26, 'ranking': 37}]},
#  {'_id': 246056,
#   'fname': 'Barry',
#   'lname': 'Gifford',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 5.21, 'ranking': 2},
#    {'category': 'doubles', 'rating': 2.25, 'ranking': 14}]},
#  {'_id': 411805,
#   'fname': 'DON',
#   'lname': 'MACDONALD',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.44, 'ranking': 15}]},
#  {'_id': 298184,
#   'fname': 'Ricky',
#   'lname': 'Lai',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 26}]},
#  {'_id': 90749,
#   'fname': 'Michael',
#   'lname': 'Mehl',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.89, 'ranking': 9}]},
#  {'_id': 398467,
#   'fname': 'Shane',
#   'lname': 'Reside',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.7, 'ranking': 88}]},
#  {'_id': 327930,
#   'fname': 'Patrick',
#   'lname': 'Reed',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.19, 'ranking': 45}]},
#  {'_id': 242751,
#   'fname': 'Chris',
#   'lname': 'Runnals',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.14, 'ranking': 39}]},
#  {'_id': 93512,
#   'fname': 'Jongho',
#   'lname': 'Kim',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.89, 'ranking': 17},
#    {'category': 'doubles', 'rating': 3.14, 'ranking': 12}]},
#  {'_id': 242900,
#   'fname': 'Martin',
#   'lname': 'Tessler',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.78, 'ranking': 55}]},
#  {'_id': 298318,
#   'fname': 'Jay',
#   'lname': 'Madsen',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.84, 'ranking': 81}]},
#  {'_id': 327966,
#   'fname': 'Emily',
#   'lname': 'Van Duin',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 2.65, 'ranking': 25}]},
#  {'_id': 251576,
#   'fname': 'Aneal',
#   'lname': 'Galbaransingh',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'doubles', 'rating': 4.15, 'ranking': 6}]},
#  {'_id': 255890,
#   'fname': 'Dennis',
#   'lname': 'Lee',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.26, 'ranking': 31}]},
#  {'_id': 432736,
#   'fname': 'Brett',
#   'lname': 'Miller',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.48, 'ranking': 12}]},
#  {'_id': 251627,
#   'fname': 'Brendan',
#   'lname': 'Gray',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.88, 'ranking': 25}]},
#  {'_id': 242976,
#   'fname': 'Jeff',
#   'lname': 'von Ende',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.36, 'ranking': 22}]},
#  {'_id': 256084,
#   'fname': 'Jim',
#   'lname': 'Miller',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 2.44, 'ranking': 8}]},
#  {'_id': 404532,
#   'fname': 'Johan',
#   'lname': 'Boshoff',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.78, 'ranking': 21}]},
#  {'_id': 395519,
#   'fname': 'Jonathon',
#   'lname': 'Chan',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.63, 'ranking': 43}]},
#  {'_id': 399725,
#   'fname': 'Michael',
#   'lname': 'Bajkor',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.77, 'ranking': 83}]},
#  {'_id': 251739,
#   'fname': 'Matthew',
#   'lname': 'Hungerford',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.72, 'ranking': 92}]},
#  {'_id': 442865,
#   'fname': 'Nolan',
#   'lname': 'Derby',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.75, 'ranking': 37}]},
#  {'_id': 396274,
#   'fname': 'Deepak',
#   'lname': 'Hayer',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.78, 'ranking': 31},
#    {'category': 'doubles', 'rating': 1.87, 'ranking': 11}]},
#  {'_id': 262100,
#   'fname': 'Ryan',
#   'lname': 'Ellis',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.94, 'ranking': 90}]},
#  {'_id': 242892,
#   'fname': 'Fraser',
#   'lname': 'Taylor-Mitchell',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.79, 'ranking': 29}]},
#  {'_id': 396178,
#   'fname': 'Elisha',
#   'lname': 'Liu',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.75, 'ranking': 12},
#    {'category': 'doubles', 'rating': 4.35, 'ranking': 1}]},
#  {'_id': 298803,
#   'fname': 'David',
#   'lname': 'Kerr',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.61, 'ranking': 9}]},
#  {'_id': 246680,
#   'fname': 'Lorraine',
#   'lname': 'June',
#   'gender': 'women',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 2.92, 'ranking': 5}]},
#  {'_id': 444661,
#   'fname': 'Sam',
#   'lname': 'Glacken',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 2.74, 'ranking': 109}]},
#  {'_id': 434402,
#   'fname': 'blair',
#   'lname': 'bullus',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.88, 'ranking': 32}]},
#  {'_id': 398904,
#   'fname': 'Justin',
#   'lname': 'Todd',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 6.36, 'ranking': 2},
#    {'category': 'doubles', 'rating': 5.94, 'ranking': 2}]},
#  {'_id': 437971,
#   'fname': 'Ricky',
#   'lname': 'Bal',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 2.38, 'ranking': 119}]},
#  {'_id': 376961,
#   'fname': 'Navin',
#   'lname': 'Samarasinghe',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.81, 'ranking': 3},
#    {'category': 'doubles', 'rating': 1.98, 'ranking': 9}]},
#  {'_id': 435749,
#   'fname': 'Britt',
#   'lname': 'Bluemel',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 1.79, 'ranking': 32}]},
#  {'_id': 399203,
#   'fname': 'Keifer',
#   'lname': 'Latremouille',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.32, 'ranking': 14}]},
#  {'_id': 246972,
#   'fname': 'Timo',
#   'lname': 'Bolder',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.6, 'ranking': 33},
#    {'category': 'doubles', 'rating': 3.39, 'ranking': 10}]},
#  {'_id': 251810,
#   'fname': 'Mitchell',
#   'lname': 'Kahnert',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 6.32, 'ranking': 4}]},
#  {'_id': 397445,
#   'fname': 'Rick',
#   'lname': 'Ng',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 4.55, 'ranking': 4},
#    {'category': 'doubles', 'rating': 4.41, 'ranking': 1}]},
#  {'_id': 398468,
#   'fname': 'Sharlene',
#   'lname': 'King',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.3, 'ranking': 18}]},
#  {'_id': 298633,
#   'fname': 'Adam',
#   'lname': 'Graham',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.85, 'ranking': 24}]},
#  {'_id': 242808,
#   'fname': 'Corry',
#   'lname': 'Silbernagel',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.68, 'ranking': 28}]},
#  {'_id': 298521,
#   'fname': 'Stefan',
#   'lname': 'Currie-Roberts',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.08, 'ranking': 21}]},
#  {'_id': 385850,
#   'fname': 'Sarah',
#   'lname': 'Eisler',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.31, 'ranking': 12}]},
#  {'_id': 297634,
#   'fname': 'Hee Young',
#   'lname': 'Lee',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 2.65, 'ranking': 17}]},
#  {'_id': 400160,
#   'fname': 'Kacey',
#   'lname': 'Cryan',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 3.17, 'ranking': 66}]},
#  {'_id': 297706,
#   'fname': 'Josh',
#   'lname': 'Dimaapi',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.85, 'ranking': 34}]},
#  {'_id': 242570,
#   'fname': 'Paul',
#   'lname': 'Aleong',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.78, 'ranking': 23}]},
#  {'_id': 417435,
#   'fname': 'Cody',
#   'lname': 'Blanleil',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.24, 'ranking': 66}]},
#  {'_id': 297920,
#   'fname': 'Mike',
#   'lname': 'Talbot',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 3.48, 'ranking': 23}]},
#  {'_id': 413625,
#   'fname': 'Juan Andres',
#   'lname': 'Varela',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 3.78, 'ranking': 57}]},
#  {'_id': 400235,
#   'fname': 'Evelyn',
#   'lname': 'Moorhouse',
#   'gender': 'women',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.68, 'ranking': 6}]},
#  {'_id': 467949,
#   'fname': 'Bill',
#   'lname': 'Randall',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 2.8, 'ranking': 68}]},
#  {'_id': 255939,
#   'fname': 'Warren',
#   'lname': 'Longpre',
#   'gender': 'men',
#   'age': '75+',
#   'ratings': [{'category': 'singles', 'rating': 3.33, 'ranking': 7}]},
#  {'_id': 423650,
#   'fname': 'Kate',
#   'lname': 'Furtuna',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.56, 'ranking': 29}]},
#  {'_id': 451422,
#   'fname': 'Mohammad',
#   'lname': 'Farhat',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.87, 'ranking': 82}]},
#  {'_id': 306133,
#   'fname': 'Amy',
#   'lname': 'Lakhani',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 2.86, 'ranking': 11},
#    {'category': 'doubles', 'rating': 2.14, 'ranking': 3}]},
#  {'_id': 246951,
#   'fname': 'Binstead',
#   'lname': 'Ian',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 1.89, 'ranking': 17}]},
#  {'_id': 414858,
#   'fname': 'Anuj',
#   'lname': 'Bahl',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.53, 'ranking': 14}]},
#  {'_id': 224817,
#   'fname': 'Cam',
#   'lname': 'Martyna',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.18, 'ranking': 19}]},
#  {'_id': 446754,
#   'fname': 'Rhys',
#   'lname': 'Archer',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4, 'ranking': 79}]},
#  {'_id': 273542,
#   'fname': 'Carol',
#   'lname': 'Eberhard',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.79, 'ranking': 2}]},
#  {'_id': 72487,
#   'fname': 'Tessa',
#   'lname': 'Breukels',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 3.66, 'ranking': 6}]},
#  {'_id': 297685,
#   'fname': 'Aly',
#   'lname': 'Thobani',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.56, 'ranking': 13}]},
#  {'_id': 242774,
#   'fname': 'Michael',
#   'lname': 'Schachter',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.77, 'ranking': 31}]},
#  {'_id': 399638,
#   'fname': 'Andrew Paul',
#   'lname': 'James',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.46, 'ranking': 83}]},
#  {'_id': 273279,
#   'fname': 'Nathan',
#   'lname': 'Bertram',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.06, 'ranking': 109}]},
#  {'_id': 396299,
#   'fname': 'Zhelin',
#   'lname': 'Bu',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.51, 'ranking': 16},
#    {'category': 'doubles', 'rating': 3.18, 'ranking': 6}]},
#  {'_id': 297884,
#   'fname': 'Armando',
#   'lname': 'Zarazua',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 5.5, 'ranking': 3}]},
#  {'_id': 256113,
#   'fname': 'Randy',
#   'lname': 'Mottus',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 3.16, 'ranking': 3}]},
#  {'_id': 429922,
#   'fname': 'Cody',
#   'lname': 'Smith',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.85, 'ranking': 79}]},
#  {'_id': 401815,
#   'fname': 'Jennifer',
#   'lname': 'West',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.1, 'ranking': 8}]},
#  {'_id': 297796,
#   'fname': 'Robin',
#   'lname': 'Barlow',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.69, 'ranking': 43}]},
#  {'_id': 462678,
#   'fname': 'Andrew Paul',
#   'lname': 'Fielding',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 2.85, 'ranking': 94}]},
#  {'_id': 431508,
#   'fname': 'Will',
#   'lname': 'Childs',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.35, 'ranking': 48}]},
#  {'_id': 463255,
#   'fname': 'Laurie',
#   'lname': 'Citynski',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.5, 'ranking': 30}]},
#  {'_id': 242226,
#   'fname': 'Marnie',
#   'lname': 'Costa',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.05, 'ranking': 10}]},
#  {'_id': 397904,
#   'fname': 'Mark',
#   'lname': 'St.Georges',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'doubles', 'rating': 2.54, 'ranking': 15}]},
#  {'_id': 280973,
#   'fname': 'Lauren',
#   'lname': 'Wagner',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 5.13, 'ranking': 1},
#    {'category': 'doubles', 'rating': 3.79, 'ranking': 1}]},
#  {'_id': 404735,
#   'fname': 'Wayne',
#   'lname': 'Diakow',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 3.8, 'ranking': 10}]},
#  {'_id': 469096,
#   'fname': 'Carol',
#   'lname': 'Jessa',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 2.59, 'ranking': 17}]},
#  {'_id': 431407,
#   'fname': 'Justin',
#   'lname': 'Wishart-MacDougall',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.11, 'ranking': 47}]},
#  {'_id': 432239,
#   'fname': 'Megan',
#   'lname': 'Lucks',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.34, 'ranking': 31}]},
#  {'_id': 439370,
#   'fname': 'Robert',
#   'lname': 'Shilton',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.79, 'ranking': 29}]},
#  {'_id': 411386,
#   'fname': 'Shehzad',
#   'lname': 'Bharmal',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.39, 'ranking': 18}]},
#  {'_id': 386019,
#   'fname': 'Fraser',
#   'lname': 'Barrett',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.29, 'ranking': 106}]},
#  {'_id': 298421,
#   'fname': 'Zach',
#   'lname': 'Owen',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.27, 'ranking': 63}]},
#  {'_id': 89286,
#   'fname': 'Michael',
#   'lname': 'Parker',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.13, 'ranking': 13},
#    {'category': 'doubles', 'rating': 1.5, 'ranking': 15}]},
#  {'_id': 57991,
#   'fname': 'Paro',
#   'lname': 'Ray',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.28, 'ranking': 9}]},
#  {'_id': 230743,
#   'fname': 'Peter',
#   'lname': 'Trafford',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.54, 'ranking': 16}]},
#  {'_id': 298904,
#   'fname': 'Charlie',
#   'lname': 'Drummond',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.97, 'ranking': 25}]},
#  {'_id': 399664,
#   'fname': 'Colin',
#   'lname': 'Lo',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.27, 'ranking': 63}]},
#  {'_id': 322546,
#   'fname': 'Grace',
#   'lname': 'Thomas',
#   'gender': 'women',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.49, 'ranking': 3}]},
#  {'_id': 298646,
#   'fname': 'Sean',
#   'lname': 'Burns',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.01, 'ranking': 77}]},
#  {'_id': 398295,
#   'fname': 'Matthew',
#   'lname': 'Taylor',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 4, 'ranking': 4}]},
#  {'_id': 85092,
#   'fname': 'Dennis',
#   'lname': 'Forsman',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 3.96, 'ranking': 4}]},
#  {'_id': 469896,
#   'fname': 'hunter',
#   'lname': 'kennedy',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.82, 'ranking': 41}]},
#  {'_id': 298662,
#   'fname': 'Chris',
#   'lname': 'Little',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.86, 'ranking': 97}]},
#  {'_id': 242853,
#   'fname': 'Paul',
#   'lname': 'Sterling',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.39, 'ranking': 14}]},
#  {'_id': 246256,
#   'fname': 'Gary',
#   'lname': 'Evans',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'doubles', 'rating': 4.89, 'ranking': 3}]},
#  {'_id': 247284,
#   'fname': 'Vince',
#   'lname': 'Waring',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.58, 'ranking': 37}]},
#  {'_id': 434945,
#   'fname': 'Todd',
#   'lname': 'Christianson',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 5.01, 'ranking': 4}]},
#  {'_id': 424323,
#   'fname': 'Alexander',
#   'lname': 'Aziz',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 4.04, 'ranking': 40}]},
#  {'_id': 250760,
#   'fname': 'Hussein',
#   'lname': 'Salemwalla',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.21, 'ranking': 16},
#    {'category': 'doubles', 'rating': 4.05, 'ranking': 10}]},
#  {'_id': 401332,
#   'fname': 'Josh',
#   'lname': 'Garber',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.63, 'ranking': 97},
#    {'category': 'doubles', 'rating': 1.5, 'ranking': 17}]},
#  {'_id': 431709,
#   'fname': 'Andrew',
#   'lname': 'Ladle',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.71, 'ranking': 105}]},
#  {'_id': 457188,
#   'fname': 'Kiaan',
#   'lname': 'Bondy',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.28, 'ranking': 52}]},
#  {'_id': 303648,
#   'fname': 'Paul',
#   'lname': 'Alford',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.11, 'ranking': 14}]},
#  {'_id': 396601,
#   'fname': 'Eric',
#   'lname': 'Collins',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.03, 'ranking': 63}]},
#  {'_id': 298782,
#   'fname': 'Annette',
#   'lname': 'Johanson',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.68, 'ranking': 5},
#    {'category': 'doubles', 'rating': 3.62, 'ranking': 7}]},
#  {'_id': 468962,
#   'fname': 'Samantha',
#   'lname': 'Leung',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.29, 'ranking': 32}]},
#  {'_id': 400794,
#   'fname': 'Jason',
#   'lname': 'Daou',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.37, 'ranking': 19},
#    {'category': 'doubles', 'rating': 2.31, 'ranking': 10}]},
#  {'_id': 394930,
#   'fname': 'Srabana',
#   'lname': 'Dasgupta',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 12}]},
#  {'_id': 388654,
#   'fname': 'Scott',
#   'lname': 'Wengi',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.57, 'ranking': 87}]},
#  {'_id': 415158,
#   'fname': 'Logan',
#   'lname': 'Northcote',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.53, 'ranking': 49}]},
#  {'_id': 246989,
#   'fname': 'Andrew',
#   'lname': 'Braff',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 5.04, 'ranking': 13}]},
#  {'_id': 260391,
#   'fname': 'Talha',
#   'lname': 'Sajjad',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.23, 'ranking': 63}]},
#  {'_id': 13263,
#   'fname': 'Viktor',
#   'lname': 'Berg',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'doubles', 'rating': 6.15, 'ranking': 2}]},
#  {'_id': 254487,
#   'fname': 'Tomos',
#   'lname': 'Edmonds',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.01, 'ranking': 23}]},
#  {'_id': 303586,
#   'fname': 'Lisa',
#   'lname': 'Cornish',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 2.65, 'ranking': 24}]},
#  {'_id': 401099,
#   'fname': 'Sujay',
#   'lname': 'Athani',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.28, 'ranking': 61}]},
#  {'_id': 255903,
#   'fname': 'Zachary',
#   'lname': 'Leman',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.9, 'ranking': 8}]},
#  {'_id': 298767,
#   'fname': 'Marc Andre',
#   'lname': 'Seguin',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.05, 'ranking': 14}]},
#  {'_id': 239021,
#   'fname': 'Jillian',
#   'lname': 'Anderson',
#   'gender': 'women',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 3.25, 'ranking': 12},
#    {'category': 'doubles', 'rating': 2.65, 'ranking': 5}]},
#  {'_id': 297764,
#   'fname': 'Eddie',
#   'lname': 'Gudewill',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.28, 'ranking': 11}]},
#  {'_id': 276518,
#   'fname': 'Olivia',
#   'lname': 'Waite',
#   'gender': 'women',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.31, 'ranking': 8},
#    {'category': 'doubles', 'rating': 2.11, 'ranking': 7}]},
#  {'_id': 468502,
#   'fname': 'Stephen',
#   'lname': 'Anderson',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 4.24, 'ranking': 12}]},
#  {'_id': 414963,
#   'fname': 'Colten',
#   'lname': 'Russell',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.79, 'ranking': 33}]},
#  {'_id': 328787,
#   'fname': 'Juana',
#   'lname': 'Chaves',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.43, 'ranking': 4},
#    {'category': 'doubles', 'rating': 2.78, 'ranking': 8}]},
#  {'_id': 298322,
#   'fname': 'Camille',
#   'lname': 'St-Cyr',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.95, 'ranking': 9}]},
#  {'_id': 310426,
#   'fname': 'Hamir',
#   'lname': 'Patel',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.54, 'ranking': 110}]},
#  {'_id': 298492,
#   'fname': 'Gareth',
#   'lname': 'Martin',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'doubles', 'rating': 3.82, 'ranking': 7}]},
#  {'_id': 397372,
#   'fname': 'Kevin',
#   'lname': 'McElgunn',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 3.4, 'ranking': 11}]},
#  {'_id': 404094,
#   'fname': 'Jorge-Renán',
#   'lname': 'Rodríguez López',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 6.18, 'ranking': 3},
#    {'category': 'doubles', 'rating': 3.72, 'ranking': 3}]},
#  {'_id': 386262,
#   'fname': 'Brian',
#   'lname': 'Meakin',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 3.09, 'ranking': 8}]},
#  {'_id': 417584,
#   'fname': 'Cory',
#   'lname': 'Bialecki',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.39, 'ranking': 91}]},
#  {'_id': 398461,
#   'fname': 'Pon',
#   'lname': 'Kongdara',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 2.56, 'ranking': 15}]},
#  {'_id': 298993,
#   'fname': 'Soroush',
#   'lname': 'Sefidkar',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.98, 'ranking': 86}]},
#  {'_id': 35042,
#   'fname': 'Maegen',
#   'lname': 'Giltrow',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.01, 'ranking': 5}]},
#  {'_id': 397271,
#   'fname': 'Jane',
#   'lname': 'McDonald',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 2.76, 'ranking': 15},
#    {'category': 'doubles', 'rating': 1.5, 'ranking': 10}]},
#  {'_id': 247341,
#   'fname': 'Adam',
#   'lname': 'Wong',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.29, 'ranking': 43}]},
#  {'_id': 246740,
#   'fname': 'Marilyn',
#   'lname': 'Mah',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 1.64, 'ranking': 17}]},
#  {'_id': 465721,
#   'fname': 'Efrain',
#   'lname': 'Desiga',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.08, 'ranking': 27}]},
#  {'_id': 400056,
#   'fname': 'Matt',
#   'lname': 'Sullivan',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.05, 'ranking': 17}]},
#  {'_id': 397371,
#   'fname': 'Albert',
#   'lname': 'Troll',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 2.18, 'ranking': 18}]},
#  {'_id': 399361,
#   'fname': 'Taylor',
#   'lname': 'Hall',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.34, 'ranking': 21}]},
#  {'_id': 297649,
#   'fname': 'Antoine',
#   'lname': 'Foukal',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.72, 'ranking': 37}]},
#  {'_id': 412000,
#   'fname': 'Duncan',
#   'lname': 'Macdonald',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.35, 'ranking': 25}]},
#  {'_id': 433957,
#   'fname': 'Steven',
#   'lname': 'Jefferys',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.77, 'ranking': 89}]},
#  {'_id': 297980,
#   'fname': 'Tom',
#   'lname': 'Dubowski',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.9, 'ranking': 24}]},
#  {'_id': 310528,
#   'fname': 'Nicole',
#   'lname': 'Ratiu',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.52, 'ranking': 8}]},
#  {'_id': 298363,
#   'fname': 'Jason',
#   'lname': 'Kurylo',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.04, 'ranking': 22}]},
#  {'_id': 432698,
#   'fname': 'Finley',
#   'lname': 'Armstrong',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 4.75, 'ranking': 33}]},
#  {'_id': 397297,
#   'fname': 'Warren',
#   'lname': 'Woodman',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 2.93, 'ranking': 10}]},
#  {'_id': 443964,
#   'fname': 'Naeem',
#   'lname': 'Sarwar',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.06, 'ranking': 66}]},
#  {'_id': 400424,
#   'fname': 'Ed',
#   'lname': 'Berwick',
#   'gender': 'men',
#   'age': '75+',
#   'ratings': [{'category': 'doubles', 'rating': 3.22, 'ranking': 3}]},
#  {'_id': 327964,
#   'fname': 'Robyn',
#   'lname': 'Dodwell',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.26, 'ranking': 19}]},
#  {'_id': 399052,
#   'fname': 'Garth',
#   'lname': 'Moore',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.51, 'ranking': 39}]},
#  {'_id': 251648,
#   'fname': 'George',
#   'lname': 'Hadjipavlou',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 5.52, 'ranking': 2}]},
#  {'_id': 397370,
#   'fname': 'Fungpiew',
#   'lname': 'Lim',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.24, 'ranking': 33},
#    {'category': 'doubles', 'rating': 3.21, 'ranking': 14}]},
#  {'_id': 252499,
#   'fname': 'Edward',
#   'lname': 'Smith Griffiths',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.85, 'ranking': 27}]},
#  {'_id': 299164,
#   'fname': 'Robin',
#   'lname': 'Drygas',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 4.49, 'ranking': 5}]},
#  {'_id': 381524,
#   'fname': 'Yasmine',
#   'lname': 'Franchi',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.28, 'ranking': 9},
#    {'category': 'doubles', 'rating': 2.51, 'ranking': 3}]},
#  {'_id': 327941,
#   'fname': 'Caitlyn',
#   'lname': 'Nyman',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.61, 'ranking': 13}]},
#  {'_id': 298064,
#   'fname': 'Daniel',
#   'lname': 'Hurd',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.87, 'ranking': 96}]},
#  {'_id': 386308,
#   'fname': 'Gary',
#   'lname': 'Morris',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.78, 'ranking': 48}]},
#  {'_id': 422179,
#   'fname': 'Robert',
#   'lname': 'Bulger',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 25}]},
#  {'_id': 323789,
#   'fname': 'Rob',
#   'lname': 'Moore',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.66, 'ranking': 96}]},
#  {'_id': 434857,
#   'fname': 'Andrew',
#   'lname': 'Blair',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 2.64, 'ranking': 98}]},
#  {'_id': 299107,
#   'fname': 'Simon',
#   'lname': 'Jongsma',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.66, 'ranking': 40}]},
#  {'_id': 247354,
#   'fname': 'Michael',
#   'lname': 'Woodworth',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.45, 'ranking': 41}]},
#  {'_id': 297822,
#   'fname': "Thomas (Te'om)",
#   'lname': 'Abrahams',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.62, 'ranking': 42}]},
#  {'_id': 432810,
#   'fname': 'Tad',
#   'lname': 'Lake',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.42, 'ranking': 43}]},
#  {'_id': 6726,
#   'fname': 'Dennis',
#   'lname': 'Cusack',
#   'gender': 'men',
#   'age': '75+',
#   'ratings': [{'category': 'doubles', 'rating': 4.25, 'ranking': 1}]},
#  {'_id': 242760,
#   'fname': 'Warren',
#   'lname': 'Saari',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.19, 'ranking': 35}]},
#  {'_id': 465130,
#   'fname': 'Luke',
#   'lname': 'Ramsay',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.37, 'ranking': 56}]},
#  {'_id': 240544,
#   'fname': 'Stephen',
#   'lname': 'Hui',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.5, 'ranking': 44}]},
#  {'_id': 431710,
#   'fname': 'Henri',
#   'lname': 'Van Rooy',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 3.73, 'ranking': 58}]},
#  {'_id': 401032,
#   'fname': 'Rodrigo',
#   'lname': 'Moreira',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5, 'ranking': 21}]},
#  {'_id': 298427,
#   'fname': 'Mark',
#   'lname': 'Lau',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.04, 'ranking': 32}]},
#  {'_id': 297591,
#   'fname': 'Tim',
#   'lname': 'Pearkes',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.91, 'ranking': 40}]},
#  {'_id': 443347,
#   'fname': 'Meghan',
#   'lname': 'Hall',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 2.14, 'ranking': 16}]},
#  {'_id': 246811,
#   'fname': 'Lisa',
#   'lname': 'Norlander',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 2.8, 'ranking': 4}]},
#  {'_id': 247283,
#   'fname': 'Jeffrey',
#   'lname': 'Ward',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 3.7, 'ranking': 8}]},
#  {'_id': 246841,
#   'fname': 'Supha',
#   'lname': 'Wall',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.58, 'ranking': 7}]},
#  {'_id': 303637,
#   'fname': 'Hank',
#   'lname': 'Wang',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.57, 'ranking': 37},
#    {'category': 'doubles', 'rating': 1.5, 'ranking': 12}]},
#  {'_id': 298994,
#   'fname': 'Kevin',
#   'lname': 'Chen',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.07, 'ranking': 43}]},
#  {'_id': 251855,
#   'fname': 'Jeff',
#   'lname': 'Kraemer',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.43, 'ranking': 42}]},
#  {'_id': 418444,
#   'fname': 'Jacques',
#   'lname': 'Prairie',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.98, 'ranking': 51}]},
#  {'_id': 434447,
#   'fname': 'Jerry',
#   'lname': 'Raduy',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.85, 'ranking': 54}]},
#  {'_id': 297726,
#   'fname': 'Richard',
#   'lname': 'Bradfield',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.26, 'ranking': 61}]},
#  {'_id': 461534,
#   'fname': 'Theron',
#   'lname': 'Jordan',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.3, 'ranking': 65}]},
#  {'_id': 386256,
#   'fname': 'Sean',
#   'lname': 'McKinley',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 2.88, 'ranking': 93}]},
#  {'_id': 418484,
#   'fname': 'Jennifer',
#   'lname': 'Morden',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 2.51, 'ranking': 27}]},
#  {'_id': 242256,
#   'fname': 'Connie',
#   'lname': 'Engh',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 2.4, 'ranking': 14}]},
#  {'_id': 246001,
#   'fname': 'Christopher',
#   'lname': 'Wallace',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 4.12, 'ranking': 15},
#    {'category': 'doubles', 'rating': 3.45, 'ranking': 7}]},
#  {'_id': 255955,
#   'fname': 'Greg',
#   'lname': 'MacDonald',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.72, 'ranking': 36}]},
#  {'_id': 468659,
#   'fname': 'Dianne',
#   'lname': 'Gauthier',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 2.49, 'ranking': 21}]},
#  {'_id': 256142,
#   'fname': 'Rod',
#   'lname': 'Nicolls',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 2.83, 'ranking': 10}]},
#  {'_id': 432870,
#   'fname': 'Connor',
#   'lname': 'Culhane',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.63, 'ranking': 35}]},
#  {'_id': 436713,
#   'fname': 'sasha',
#   'lname': 'djurdjevic',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'doubles', 'rating': 1.65, 'ranking': 13}]},
#  {'_id': 397827,
#   'fname': 'Sean',
#   'lname': 'Haylow',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.44, 'ranking': 40}]},
#  {'_id': 457305,
#   'fname': 'Chi Ho',
#   'lname': 'Ng',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.47, 'ranking': 89}]},
#  {'_id': 386698,
#   'fname': 'Roman',
#   'lname': 'Buksa',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.75, 'ranking': 57}]},
#  {'_id': 247360,
#   'fname': 'Dallas',
#   'lname': 'Worthington',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.47, 'ranking': 46},
#    {'category': 'doubles', 'rating': 3.38, 'ranking': 13}]},
#  {'_id': 255887,
#   'fname': 'Steve',
#   'lname': 'Lawton',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 2.68, 'ranking': 12}]},
#  {'_id': 385376,
#   'fname': 'Paul',
#   'lname': 'Gray',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 2.27, 'ranking': 18}]},
#  {'_id': 297984,
#   'fname': 'Brett',
#   'lname': 'Malli',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 4.47, 'ranking': 6}]},
#  {'_id': 386172,
#   'fname': 'Davis',
#   'lname': 'Fong',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 4.53, 'ranking': 35}]},
#  {'_id': 236110,
#   'fname': 'Josh',
#   'lname': 'Moncrieff',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.38, 'ranking': 57}]},
#  {'_id': 298549,
#   'fname': 'Reza',
#   'lname': 'Askari',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.6, 'ranking': 46}]},
#  {'_id': 297874,
#   'fname': 'Danny',
#   'lname': 'Wong',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.25, 'ranking': 64}]},
#  {'_id': 457951,
#   'fname': 'Akshay',
#   'lname': 'Nilangekar',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.19, 'ranking': 68}]},
#  {'_id': 437970,
#   'fname': 'Trevor',
#   'lname': 'Lashyn',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.1, 'ranking': 78}]},
#  {'_id': 43986,
#   'fname': 'Anthony',
#   'lname': 'Graham',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 6.51, 'ranking': 1},
#    {'category': 'doubles', 'rating': 1.96, 'ranking': 15}]},
#  {'_id': 404657,
#   'fname': 'Chadwick',
#   'lname': 'Walker',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.07, 'ranking': 70}]},
#  {'_id': 458424,
#   'fname': 'Brian',
#   'lname': 'Bartow',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.33, 'ranking': 95}]},
#  {'_id': 68931,
#   'fname': 'Christine',
#   'lname': 'Manhao',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 2.6, 'ranking': 16}]},
#  {'_id': 297721,
#   'fname': 'Alex',
#   'lname': 'Garceau',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.59, 'ranking': 9},
#    {'category': 'doubles', 'rating': 5.25, 'ranking': 5}]},
#  {'_id': 255999,
#   'fname': 'Kristopher',
#   'lname': 'Markgraf',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.43, 'ranking': 52}]},
#  {'_id': 240590,
#   'fname': 'Will',
#   'lname': 'Ferry',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.78, 'ranking': 30}]},
#  {'_id': 246000,
#   'fname': 'Winston',
#   'lname': 'Cabell',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'doubles', 'rating': 3.17, 'ranking': 11}]},
#  {'_id': 405975,
#   'fname': 'Ally',
#   'lname': 'Krug',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.56, 'ranking': 15}]},
#  {'_id': 323678,
#   'fname': 'Nick',
#   'lname': 'James',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.56, 'ranking': 10},
#    {'category': 'doubles', 'rating': 2.62, 'ranking': 14}]},
#  {'_id': 430806,
#   'fname': 'Jason',
#   'lname': 'Martin',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.13, 'ranking': 74}]},
#  {'_id': 298461,
#   'fname': 'Will',
#   'lname': 'McQueen',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.43, 'ranking': 51},
#    {'category': 'doubles', 'rating': 2.14, 'ranking': 7}]},
#  {'_id': 434556,
#   'fname': 'Thomas',
#   'lname': 'Cameron',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.21, 'ranking': 17}]},
#  {'_id': 423651,
#   'fname': 'Anastasiya',
#   'lname': 'Spivak',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.3, 'ranking': 5},
#    {'category': 'doubles', 'rating': 2.88, 'ranking': 7}]},
#  {'_id': 246771,
#   'fname': 'Jennifer',
#   'lname': 'McKinley',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 3.26, 'ranking': 3}]},
#  {'_id': 476656,
#   'fname': 'Michael',
#   'lname': 'Conlon',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.3, 'ranking': 51}]},
#  {'_id': 402287,
#   'fname': 'Andy',
#   'lname': 'Au-Yeung',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.55, 'ranking': 39}]},
#  {'_id': 386908,
#   'fname': 'Kevin',
#   'lname': 'Lore',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.68, 'ranking': 44}]},
#  {'_id': 251646,
#   'fname': 'Farzin',
#   'lname': 'Habibpour',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.76, 'ranking': 6},
#    {'category': 'doubles', 'rating': 4.5, 'ranking': 6}]},
#  {'_id': 386821,
#   'fname': 'Tim',
#   'lname': 'Crombie',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.16, 'ranking': 36}]},
#  {'_id': 469129,
#   'fname': 'Evan',
#   'lname': 'Kimoff',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 3.47, 'ranking': 59}]},
#  {'_id': 242844,
#   'fname': 'Brian',
#   'lname': 'Spahn',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.68, 'ranking': 39}]},
#  {'_id': 22283,
#   'fname': 'Aadam',
#   'lname': 'Tejpar',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.19, 'ranking': 16}]},
#  {'_id': 436239,
#   'fname': 'Colin',
#   'lname': 'Clay',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.85, 'ranking': 25}]},
#  {'_id': 432369,
#   'fname': 'David',
#   'lname': 'Green',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.17, 'ranking': 26}]},
#  {'_id': 398544,
#   'fname': 'Akshay',
#   'lname': 'Kotak',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.01, 'ranking': 84}]},
#  {'_id': 266998,
#   'fname': 'Shawn',
#   'lname': 'Zwierzchowski',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.51, 'ranking': 7}]},
#  {'_id': 298621,
#   'fname': 'Darcy',
#   'lname': 'Nyrose',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.27, 'ranking': 50}]},
#  {'_id': 435105,
#   'fname': 'Richard',
#   'lname': 'Johansen',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5, 'ranking': 24},
#    {'category': 'doubles', 'rating': 3.24, 'ranking': 4}]},
#  {'_id': 298678,
#   'fname': 'Peter',
#   'lname': 'Kajaks',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.57, 'ranking': 46}]},
#  {'_id': 430652,
#   'fname': 'Piara',
#   'lname': 'Mehat',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 4.06, 'ranking': 4}]},
#  {'_id': 413298,
#   'fname': 'Bob',
#   'lname': 'Trinder',
#   'gender': 'men',
#   'age': '75+',
#   'ratings': [{'category': 'singles', 'rating': 3.25, 'ranking': 8}]},
#  {'_id': 251564,
#   'fname': 'Peter',
#   'lname': 'Fritz',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.48, 'ranking': 54}]},
#  {'_id': 246750,
#   'fname': 'Vicki',
#   'lname': 'Marlatt',
#   'gender': 'women',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 2.7, 'ranking': 8}]},
#  {'_id': 472390,
#   'fname': 'Matt',
#   'lname': 'Hirji',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.56, 'ranking': 109}]},
#  {'_id': 265464,
#   'fname': 'Josh',
#   'lname': 'Struthers',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.83, 'ranking': 2},
#    {'category': 'doubles', 'rating': 3.43, 'ranking': 10}]},
#  {'_id': 264755,
#   'fname': 'Duncan',
#   'lname': 'Genge',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.43, 'ranking': 17}]},
#  {'_id': 265710,
#   'fname': 'Julia',
#   'lname': 'Horsey',
#   'gender': 'women',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 4.48, 'ranking': 6}]},
#  {'_id': 431612,
#   'fname': 'Jason',
#   'lname': 'Jobin',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.74, 'ranking': 41}]},
#  {'_id': 465857,
#   'fname': 'Alex',
#   'lname': 'Shi',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 2.52, 'ranking': 55}]},
#  {'_id': 297787,
#   'fname': 'Jeremy',
#   'lname': 'Lamb',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.17, 'ranking': 68}]},
#  {'_id': 247264,
#   'fname': 'Joe',
#   'lname': 'Forster',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.54, 'ranking': 4},
#    {'category': 'doubles', 'rating': 2.44, 'ranking': 15}]},
#  {'_id': 259717,
#   'fname': 'Matt',
#   'lname': 'Zilinski',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.02, 'ranking': 23}]},
#  {'_id': 411191,
#   'fname': 'Robbin',
#   'lname': 'Burns',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.79, 'ranking': 20}]},
#  {'_id': 434771,
#   'fname': 'Jordan',
#   'lname': 'Allen',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.16, 'ranking': 68}]},
#  {'_id': 404579,
#   'fname': 'Bruce',
#   'lname': 'Tennant',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.63, 'ranking': 41}]},
#  {'_id': 298943,
#   'fname': 'Mark',
#   'lname': 'Johnson',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.12, 'ranking': 60}]},
#  {'_id': 400410,
#   'fname': 'Aaron',
#   'lname': 'Yaremchuk',
#   'gender': 'men',
# ...
#   'ratings': [{'category': 'singles', 'rating': 4.7, 'ranking': 27},
#    {'category': 'doubles', 'rating': 1.5, 'ranking': 18}]},
#  {'_id': 230717,
#   'fname': 'Nicole',
#   'lname': 'Temple',
#   'gender': 'women',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 4.94, 'ranking': 5}]},
#  {'_id': 381517,
#   'fname': 'Randy',
#   'lname': 'Egan',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.02, 'ranking': 48}]},
#  {'_id': 246779,
#   'fname': 'Donalda',
#   'lname': 'Meyers',
#   'gender': 'women',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 2.74, 'ranking': 7}]},
#  {'_id': 404848,
#   'fname': 'Eric',
#   'lname': 'Sakawsky',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.53, 'ranking': 93}]},
#  {'_id': 230765,
#   'fname': 'Carolyn',
#   'lname': 'Binns',
#   'gender': 'women',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.22, 'ranking': 9},
#    {'category': 'doubles', 'rating': 2.5, 'ranking': 6}]},
#  {'_id': 242884,
#   'fname': 'Victor',
#   'lname': 'Tanaka',
#   'gender': 'men',
#   'age': '75+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 5}]},
#  {'_id': 400105,
#   'fname': 'Merat',
#   'lname': 'Goharshadi',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 3.24, 'ranking': 65}]},
#  {'_id': 297797,
#   'fname': 'Brian',
#   'lname': 'Duong',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.13, 'ranking': 12}]},
#  {'_id': 464846,
#   'fname': 'Geoff',
#   'lname': 'Falk',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.04, 'ranking': 15}]},
#  {'_id': 433661,
#   'fname': 'Charles',
#   'lname': 'Stenner',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.39, 'ranking': 17}]},
#  {'_id': 436389,
#   'fname': 'Hope',
#   'lname': 'Maron',
#   'gender': 'women',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.23, 'ranking': 11}]},
#  {'_id': 396573,
#   'fname': 'Byron',
#   'lname': 'Kidd',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 4.74, 'ranking': 1},
#    {'category': 'doubles', 'rating': 4.16, 'ranking': 3}]},
#  {'_id': 464887,
#   'fname': 'Jennifer',
#   'lname': 'Yeung',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 2.86, 'ranking': 13}]},
#  {'_id': 217589,
#   'fname': 'Nicola',
#   'lname': 'Ahern',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.28, 'ranking': 1},
#    {'category': 'doubles', 'rating': 4.92, 'ranking': 1}]},
#  {'_id': 397295,
#   'fname': 'Bonnie',
#   'lname': 'Cooney',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.83, 'ranking': 4},
#    {'category': 'doubles', 'rating': 2.44, 'ranking': 5}]},
#  {'_id': 398460,
#   'fname': 'Peter',
#   'lname': 'Bale',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.84, 'ranking': 76}]},
#  {'_id': 399700,
#   'fname': 'John',
#   'lname': 'Killoran',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.49, 'ranking': 95}]},
#  {'_id': 446030,
#   'fname': 'Ryan',
#   'lname': 'Gray',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.63, 'ranking': 91}]},
#  {'_id': 256171,
#   'fname': 'Nathan',
#   'lname': 'Ozog',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.21, 'ranking': 11},
#    {'category': 'doubles', 'rating': 1.5, 'ranking': 17}]},
#  {'_id': 395472,
#   'fname': 'Chie',
#   'lname': 'Kim',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.11, 'ranking': 18}]},
#  {'_id': 401526,
#   'fname': 'Colin',
#   'lname': 'Gordner',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.62, 'ranking': 43}]},
#  {'_id': 297799,
#   'fname': 'Hamid',
#   'lname': 'Shekarchi',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.88, 'ranking': 31}]},
#  {'_id': 386704,
#   'fname': 'Alaina',
#   'lname': 'Burnett',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 2.53, 'ranking': 16}]},
#  {'_id': 245999,
#   'fname': 'Snehal',
#   'lname': 'Lakhani',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 4.59, 'ranking': 3}]},
#  {'_id': 297694,
#   'fname': 'Karim',
#   'lname': 'Abraham',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.91, 'ranking': 93}]},
#  {'_id': 297811,
#   'fname': 'Sergio',
#   'lname': 'Andaloro',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.8, 'ranking': 31}]},
#  {'_id': 396293,
#   'fname': 'Connor',
#   'lname': 'Runnalls',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.03, 'ranking': 51}]},
#  {'_id': 212371,
#   'fname': 'Liam',
#   'lname': 'Leidekker',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.66, 'ranking': 13}]},
#  {'_id': 400500,
#   'fname': 'Rob',
#   'lname': 'Tuck',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.36, 'ranking': 47}]},
#  {'_id': 442762,
#   'fname': 'David',
#   'lname': 'Griffiths',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.26, 'ranking': 101}]},
#  {'_id': 416077,
#   'fname': 'Alex',
#   'lname': 'Wilkes',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.33, 'ranking': 59}]},
#  {'_id': 230886,
#   'fname': 'Trevor',
#   'lname': 'Koretz',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.17, 'ranking': 56}]},
#  {'_id': 402343,
#   'fname': 'Molina',
#   'lname': 'Chow',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 2.88, 'ranking': 10}]},
#  {'_id': 397348,
#   'fname': 'Ian',
#   'lname': 'Binstead',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 3.09, 'ranking': 8}]},
#  {'_id': 435476,
#   'fname': 'Blake',
#   'lname': 'Purcell',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.84, 'ranking': 101}]},
#  {'_id': 93518,
#   'fname': 'Mark',
#   'lname': 'Levey',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.75, 'ranking': 25},
#    {'category': 'doubles', 'rating': 3.86, 'ranking': 6}]},
#  {'_id': 323963,
#   'fname': 'Lucas',
#   'lname': 'Jessa',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.19, 'ranking': 25}]},
#  {'_id': 255906,
#   'fname': 'Daryl',
#   'lname': 'Leopold',
#   'gender': 'men',
#   'age': '75+',
#   'ratings': [{'category': 'singles', 'rating': 3.07, 'ranking': 9}]},
#  {'_id': 400973,
#   'fname': 'Nikki',
#   'lname': 'Sison',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.43, 'ranking': 17}]},
#  {'_id': 297725,
#   'fname': 'John',
#   'lname': 'Boyd',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.01, 'ranking': 66}]},
#  {'_id': 402180,
#   'fname': 'Mikaela',
#   'lname': 'Graham-Radford',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.2, 'ranking': 34}]},
#  {'_id': 247303,
#   'fname': 'Jason',
#   'lname': 'Weglo (PP)',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.35, 'ranking': 58}]},
#  {'_id': 298390,
#   'fname': 'Ian',
#   'lname': 'Sefton',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.92, 'ranking': 5}]},
#  {'_id': 477441,
#   'fname': 'Timothy',
#   'lname': 'Morgan',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 5.25, 'ranking': 7}]},
#  {'_id': 271931,
#   'fname': 'Cathy',
#   'lname': 'Brown',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.77, 'ranking': 3},
#    {'category': 'doubles', 'rating': 2.82, 'ranking': 12}]},
#  {'_id': 435705,
#   'fname': 'Toby',
#   'lname': 'Page',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4, 'ranking': 78}]},
#  {'_id': 438244,
#   'fname': 'Christian',
#   'lname': 'Maas',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.87, 'ranking': 73}]},
#  {'_id': 423643,
#   'fname': 'Sean',
#   'lname': 'Peever',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.77, 'ranking': 39}]},
#  {'_id': 404707,
#   'fname': 'Jim',
#   'lname': 'Foo',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.99, 'ranking': 37}]},
#  {'_id': 242138,
#   'fname': 'Jamie',
#   'lname': 'Sonego',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.93, 'ranking': 10},
#    {'category': 'doubles', 'rating': 4.14, 'ranking': 2}]},
#  {'_id': 432587,
#   'fname': 'David',
#   'lname': 'Simpson',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.02, 'ranking': 47}]},
#  {'_id': 378374,
#   'fname': 'Tiffany',
#   'lname': 'Jung',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.49, 'ranking': 6},
#    {'category': 'doubles', 'rating': 2.27, 'ranking': 2}]},
#  {'_id': 247342,
#   'fname': 'Gary',
#   'lname': 'Wong',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 17}]},
#  {'_id': 251708,
#   'fname': 'Brandon',
#   'lname': 'Hofmarks',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.98, 'ranking': 87}]},
#  {'_id': 255994,
#   'fname': 'John',
#   'lname': 'Maltais',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.78, 'ranking': 81}]},
#  {'_id': 398419,
#   'fname': 'Graeme',
#   'lname': 'Vass',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.66, 'ranking': 95}]},
#  {'_id': 430526,
#   'fname': 'Greg',
#   'lname': 'Hamelin',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.41, 'ranking': 50}]},
#  {'_id': 298566,
#   'fname': 'Tyler',
#   'lname': 'Kristiansen',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.63, 'ranking': 41},
#    {'category': 'doubles', 'rating': 2.71, 'ranking': 13}]},
#  {'_id': 300029,
#   'fname': 'Steve',
#   'lname': 'Jacobs',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 4.25, 'ranking': 3}]},
#  {'_id': 452740,
#   'fname': 'Ted',
#   'lname': 'Stanford',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.53, 'ranking': 88}]},
#  {'_id': 247018,
#   'fname': 'Doug',
#   'lname': 'Buchanan',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 20}]},
#  {'_id': 317427,
#   'fname': 'Matt',
#   'lname': 'Warner',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 2.11, 'ranking': 19}]},
#  {'_id': 469885,
#   'fname': 'Yannick',
#   'lname': 'Girardin',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.89, 'ranking': 72}]},
#  {'_id': 383136,
#   'fname': 'Sam',
#   'lname': 'Crawford',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.57, 'ranking': 48}]},
#  {'_id': 416082,
#   'fname': 'Aaron',
#   'lname': 'Schmidt',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.66, 'ranking': 90}]},
#  {'_id': 264593,
#   'fname': 'Carly',
#   'lname': 'Morrison',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.8, 'ranking': 6}]},
#  {'_id': 430795,
#   'fname': 'Kellen',
#   'lname': 'Richards',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.24, 'ranking': 20}]},
#  {'_id': 246849,
#   'fname': 'Lauren',
#   'lname': 'Price',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.55, 'ranking': 7},
#    {'category': 'doubles', 'rating': 3.6, 'ranking': 3}]},
#  {'_id': 447094,
#   'fname': 'Barry',
#   'lname': 'Warren',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.3, 'ranking': 116}]},
#  {'_id': 247093,
#   'fname': 'Andrew',
#   'lname': 'Clements',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.27, 'ranking': 10}]},
#  {'_id': 167312,
#   'fname': 'Amelia',
#   'lname': 'Knapp',
#   'gender': 'women',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.02, 'ranking': 4}]},
#  {'_id': 435730,
#   'fname': 'Alevtina',
#   'lname': 'Akbulatova',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 2.01, 'ranking': 25}]},
#  {'_id': 298209,
#   'fname': 'Angela',
#   'lname': 'Hutchinson-Georgi',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 2.57, 'ranking': 19}]},
#  {'_id': 297781,
#   'fname': 'Scott',
#   'lname': 'Emslie',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.68, 'ranking': 33}]},
#  {'_id': 386430,
#   'fname': 'Otto',
#   'lname': 'Kamstra',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.66, 'ranking': 51}]},
#  {'_id': 417338,
#   'fname': 'Neel',
#   'lname': 'Deshpande',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.59, 'ranking': 107}]},
#  {'_id': 247064,
#   'fname': 'Joel',
#   'lname': 'Casey',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 5.18, 'ranking': 8}]},
#  {'_id': 317431,
#   'fname': 'Sandra',
#   'lname': 'Ferguson',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.37, 'ranking': 9}]},
#  {'_id': 299145,
#   'fname': 'Pauline',
#   'lname': 'Ambrose',
#   'gender': 'women',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 2.41, 'ranking': 9}]},
#  {'_id': 399116,
#   'fname': 'Andrew',
#   'lname': 'Cunningham',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 3.67, 'ranking': 9}]},
#  {'_id': 251837,
#   'fname': 'Struan',
#   'lname': 'Kilgour',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.11, 'ranking': 10}]},
#  {'_id': 251736,
#   'fname': 'Ian',
#   'lname': 'Humphries',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.92, 'ranking': 27}]},
#  {'_id': 318031,
#   'fname': 'Harry',
#   'lname': 'Heathcock',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.57, 'ranking': 12}]},
#  {'_id': 410672,
#   'fname': 'Eric',
#   'lname': 'Fought',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.26, 'ranking': 20},
#    {'category': 'doubles', 'rating': 5.31, 'ranking': 1}]},
#  {'_id': 263583,
#   'fname': 'Rio',
#   'lname': 'Schafer',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.96, 'ranking': 8}]},
#  {'_id': 415725,
#   'fname': 'Jody',
#   'lname': 'Evans',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.15, 'ranking': 9},
#    {'category': 'doubles', 'rating': 4.78, 'ranking': 4}]},
#  {'_id': 255954,
#   'fname': 'David',
#   'lname': 'MacDonald',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.72, 'ranking': 35}]},
#  {'_id': 435109,
#   'fname': 'Peter',
#   'lname': 'McLean',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4, 'ranking': 68}]},
#  {'_id': 242216,
#   'fname': 'Sandra',
#   'lname': 'Clark',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.28, 'ranking': 11}]},
#  {'_id': 400364,
#   'fname': 'Andrew',
#   'lname': 'Ripley',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 3.3, 'ranking': 6}]},
#  {'_id': 400795,
#   'fname': 'Eric',
#   'lname': 'Donatelli',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.91, 'ranking': 27}]},
#  ...]

# %%
print("Total number of players: {num}".format(num=len(players_list)))
# Out:
# Total number of players: 1216

# %%
players_df = pd.DataFrame(players_list)

# %%
players_df
# Out:
#          _id     fname         lname gender  age  \
# 0     468003  Stephane      Melanson    men  30+
# 1     405126   Steffen    Hoyemsvoll    men  30+
# 2     255882    Morgan  Latremouille    men  30+
# 3     479459       Ben        Hooker    men  25+
# 4     242606    Rashid          Aziz    men  70+
# ...      ...       ...           ...    ...  ...
# 1211  385482      John       Hosking    men  25+
# 1212  303641       Rob     Gutierrez    men  40+
# 1213  410878     David     Goldsmith    men  50+
# 1214  475096      Eoin      Cosgrave    men  45+
# 1215  398940     Chloe       Deserre  women  19+
#
#                                                 ratings
# 0     [{'category': 'singles', 'rating': 3.73, 'rank...
# 1     [{'category': 'singles', 'rating': 4.26, 'rank...
# 2     [{'category': 'singles', 'rating': 5.96, 'rank...
# 3     [{'category': 'singles', 'rating': 4.45, 'rank...
# 4     [{'category': 'singles', 'rating': 4.48, 'rank...
# ...                                                 ...
# 1211  [{'category': 'singles', 'rating': 4.41, 'rank...
# 1212  [{'category': 'singles', 'rating': 3.38, 'rank...
# 1213  [{'category': 'doubles', 'rating': 5.52, 'rank...
# 1214  [{'category': 'singles', 'rating': 3.84, 'rank...
# 1215  [{'category': 'singles', 'rating': 3.66, 'rank...
#
# [1216 rows x 6 columns]

# %% [markdown]
# ### Get matches data

# %%
matches_collection = client["squashbc"]["matches"]

# %%
matches = matches_collection.find()

# %%
matches_list = list(matches)

# %%
matches_list
# Out:
# [{'_id': ObjectId('6614a37733614c4135bfcfcc'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-07-20T00:00:00',
#   'scores': '10-15, 7-15, 10-15',
#   'player_a1': 397238,
#   'player_a2': None,
#   'player_b1': 397370,
#   'player_b2': 385805},
#  {'_id': ObjectId('6614a37733614c4135bfcfcd'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-07-20T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 396299,
#   'player_a2': 386742,
#   'player_b1': 397348,
#   'player_b2': 399783},
#  {'_id': ObjectId('6614a37733614c4135bfcfce'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-07-13T00:00:00',
#   'scores': '15-14, 4-15, 11-15, 15-11, 10-15',
#   'player_a1': 247259,
#   'player_a2': 246931,
#   'player_b1': 397370,
#   'player_b2': 303589},
#  {'_id': ObjectId('6614a37733614c4135bfcfcf'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-07-06T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 399783,
#   'player_a2': 385805,
#   'player_b1': 246849,
#   'player_b2': 303555},
#  {'_id': ObjectId('6614a37733614c4135bfcfd0'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-06-29T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 85092,
#   'player_a2': 397348,
#   'player_b1': 70354,
#   'player_b2': 396178},
#  {'_id': ObjectId('6614a37733614c4135bfcfd1'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-04-13T00:00:00',
#   'scores': '15-13, 10-15, 15-8, 13-15, 10-15',
#   'player_a1': 246182,
#   'player_a2': 271931,
#   'player_b1': 1000000289,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a37733614c4135bfcfd2'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-30T00:00:00',
#   'scores': '11-0, 11-0, 11-0',
#   'player_a1': 0,
#   'player_a2': 0,
#   'player_b1': 71931,
#   'player_b2': 246824},
#  {'_id': ObjectId('6614a37733614c4135bfcfd3'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-30T00:00:00',
#   'scores': '15-6, 14-15, 15-11, 15-4',
#   'player_a1': 246182,
#   'player_a2': 246930,
#   'player_b1': 242138,
#   'player_b2': 246021},
#  {'_id': ObjectId('6614a37733614c4135bfcfd4'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-23T00:00:00',
#   'scores': '15-13, 15-14, 13-15, 15-11',
#   'player_a1': 271931,
#   'player_a2': 246930,
#   'player_b1': 72487,
#   'player_b2': 279520},
#  {'_id': ObjectId('6614a37733614c4135bfcfd5'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-16T00:00:00',
#   'scores': '14-15, 15-14, 6-15, 5-15',
#   'player_a1': 246021,
#   'player_a2': 1000000289,
#   'player_b1': 72487,
#   'player_b2': 279520},
#  {'_id': ObjectId('6614a37733614c4135bfcfd6'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-16T00:00:00',
#   'scores': '15-14, 15-11, 10-15, 15-10',
#   'player_a1': 271931,
#   'player_a2': 242079,
#   'player_b1': 246811,
#   'player_b2': None},
#  {'_id': ObjectId('6614a37733614c4135bfcfd7'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-02T00:00:00',
#   'scores': '15-12, 15-3, 15-6',
#   'player_a1': 246182,
#   'player_a2': 246675,
#   'player_b1': 298782,
#   'player_b2': 246945},
#  {'_id': ObjectId('6614a37733614c4135bfcfd8'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-23T00:00:00',
#   'scores': '15-5, 11-15, 15-3, 14-15, 15-7',
#   'player_a1': 242138,
#   'player_a2': 1000000289,
#   'player_b1': 298782,
#   'player_b2': 72487},
#  {'_id': ObjectId('6614a37733614c4135bfcfd9'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-23T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 71931,
#   'player_a2': 246811,
#   'player_b1': 246182,
#   'player_b2': 246930},
#  {'_id': ObjectId('6614a37733614c4135bfcfda'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-16T00:00:00',
#   'scores': '15-4, 15-6, 8-15, 15-8',
#   'player_a1': 279520,
#   'player_a2': 72487,
#   'player_b1': 71931,
#   'player_b2': 246824},
#  {'_id': ObjectId('6614a37733614c4135bfcfdb'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-16T00:00:00',
#   'scores': '7-15, 10-15, 15-9, 7-15',
#   'player_a1': 271931,
#   'player_a2': 242079,
#   'player_b1': 1000000289,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a37733614c4135bfcfdc'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-02T00:00:00',
#   'scores': '11-0, 11-0, 11-0',
#   'player_a1': 242227,
#   'player_a2': 298782,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('6614a37733614c4135bfcfdd'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-02T00:00:00',
#   'scores': '15-8, 15-5, 15-11',
#   'player_a1': 242138,
#   'player_a2': 423651,
#   'player_b1': 71931,
#   'player_b2': 431418},
#  {'_id': ObjectId('6614a37733614c4135bfcfde'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-19T00:00:00',
#   'scores': '15-6, 15-12, 15-9',
#   'player_a1': 246182,
#   'player_a2': 242227,
#   'player_b1': 246811,
#   'player_b2': 431418},
#  {'_id': ObjectId('6614a37733614c4135bfcfdf'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-12T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 71931,
#   'player_a2': 246811,
#   'player_b1': 72487,
#   'player_b2': 279520},
#  {'_id': ObjectId('6614a37733614c4135bfcfe0'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-12T00:00:00',
#   'scores': '15-8, 13-15, 15-10, 3-15, 15-14',
#   'player_a1': 246182,
#   'player_a2': 246675,
#   'player_b1': 246021,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a37733614c4135bfcfe1'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-05T00:00:00',
#   'scores': '15-12, 10-15, 14-15, 15-5, 13-15',
#   'player_a1': 72487,
#   'player_a2': 279520,
#   'player_b1': 246182,
#   'player_b2': 246930},
#  {'_id': ObjectId('6614a37733614c4135bfcfe2'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-12-15T00:00:00',
#   'scores': '15-14, 13-15, 15-7, 10-15, 7-15',
#   'player_a1': 71931,
#   'player_a2': 246811,
#   'player_b1': 271931,
#   'player_b2': 246930},
#  {'_id': ObjectId('6614a37733614c4135bfcfe3'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-12-01T00:00:00',
#   'scores': '11-0, 11-0, 11-0',
#   'player_a1': 246811,
#   'player_a2': 246824,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('6614a37733614c4135bfcfe4'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-12-01T00:00:00',
#   'scores': '15-13, 15-12, 15-9',
#   'player_a1': 246182,
#   'player_a2': 246811,
#   'player_b1': 217589,
#   'player_b2': 246021},
#  {'_id': ObjectId('6614a37733614c4135bfcfe5'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-17T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 246824,
#   'player_a2': 423651,
#   'player_b1': 242138,
#   'player_b2': 1000000289},
#  {'_id': ObjectId('6614a37733614c4135bfcfe6'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-10T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 242138,
#   'player_a2': 246021,
#   'player_b1': None,
#   'player_b2': 72487},
#  {'_id': ObjectId('6614a37733614c4135bfcfe7'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-10T00:00:00',
#   'scores': '9-15, 15-12, 15-9, 7-15, 13-15',
#   'player_a1': 271931,
#   'player_a2': 242227,
#   'player_b1': 71931,
#   'player_b2': 246824},
#  {'_id': ObjectId('6614a37733614c4135bfcfe8'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-03T00:00:00',
#   'scores': '9-15, 15-11, 15-12, 12-15, 14-15',
#   'player_a1': 242138,
#   'player_a2': 246021,
#   'player_b1': 246675,
#   'player_b2': 246930},
#  {'_id': ObjectId('6614a37733614c4135bfcfe9'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-03T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 246811,
#   'player_a2': 423651,
#   'player_b1': 72487,
#   'player_b2': 279520},
#  {'_id': ObjectId('6614a37733614c4135bfcfea'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-27T00:00:00',
#   'scores': '10-15, 10-15, 12-15',
#   'player_a1': 1000000289,
#   'player_a2': 246021,
#   'player_b1': 246824,
#   'player_b2': 423651},
#  {'_id': ObjectId('6614a37733614c4135bfcfeb'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-20T00:00:00',
#   'scores': '6-15, 12-15, 7-15',
#   'player_a1': None,
#   'player_a2': 246824,
#   'player_b1': 271931,
#   'player_b2': 246930},
#  {'_id': ObjectId('6614a37733614c4135bfcfec'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-06T00:00:00',
#   'scores': '9-15, 9-15, 12-15',
#   'player_a1': 1000000289,
#   'player_a2': 246021,
#   'player_b1': 271931,
#   'player_b2': 246930},
#  {'_id': ObjectId('6614a37733614c4135bfcfed'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-04-05T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 77849,
#   'player_a2': 297721,
#   'player_b1': 13263,
#   'player_b2': 330944},
#  {'_id': ObjectId('6614a37733614c4135bfcfee'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-22T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 93512,
#   'player_a2': 256046,
#   'player_b1': 246256,
#   'player_b2': 251576},
#  {'_id': ObjectId('6614a37733614c4135bfcfef'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-22T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': 242629,
#   'player_b2': 71511},
#  {'_id': ObjectId('6614a37733614c4135bfcff0'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-04T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 13263,
#   'player_a2': 410878,
#   'player_b1': 410672,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a37733614c4135bfcff1'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-15T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 77849,
#   'player_a2': 297721,
#   'player_b1': 13263,
#   'player_b2': 330944},
#  {'_id': ObjectId('6614a37733614c4135bfcff2'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-15T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 217592,
#   'player_a2': 417797,
#   'player_b1': 250760,
#   'player_b2': 265464},
#  {'_id': ObjectId('6614a37733614c4135bfcff3'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-01T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 71511,
#   'player_b1': 382735,
#   'player_b2': 411278},
#  {'_id': ObjectId('6614a37733614c4135bfcff4'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-01T00:00:00',
#   'scores': '14-15, 15-11, 15-13, 10-15, 12-15',
#   'player_a1': 265464,
#   'player_a2': 250760,
#   'player_b1': 398304,
#   'player_b2': 297721},
#  {'_id': ObjectId('6614a37733614c4135bfcff5'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-22T00:00:00',
#   'scores': '15-14, 15-12, 12-15, 15-10',
#   'player_a1': 251646,
#   'player_a2': 250672,
#   'player_b1': None,
#   'player_b2': 397904},
#  {'_id': ObjectId('6614a37733614c4135bfcff6'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-22T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 72446,
#   'player_a2': 13263,
#   'player_b1': 256145,
#   'player_b2': 93518},
#  {'_id': ObjectId('6614a37733614c4135bfcff7'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-15T00:00:00',
#   'scores': '15-5, 15-7, 13-15, 15-6',
#   'player_a1': 13263,
#   'player_a2': 72446,
#   'player_b1': 410672,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a37733614c4135bfcff8'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-01T00:00:00',
#   'scores': '12-15, 15-13, 13-15, 11-15',
#   'player_a1': 398304,
#   'player_a2': 250672,
#   'player_b1': 265464,
#   'player_b2': 250760},
#  {'_id': ObjectId('6614a37733614c4135bfcff9'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-01T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 382735,
#   'player_a2': 415725,
#   'player_b1': None,
#   'player_b2': 246000},
#  {'_id': ObjectId('6614a37733614c4135bfcffa'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-25T00:00:00',
#   'scores': '15-13, 8-15, 11-15, 8-15',
#   'player_a1': None,
#   'player_a2': 71511,
#   'player_b1': 251646,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a37733614c4135bfcffb'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-18T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 77849,
#   'player_a2': 93465,
#   'player_b1': 398904,
#   'player_b2': 415725},
#  {'_id': ObjectId('6614a37733614c4135bfcffc'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-18T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 242629,
#   'player_a2': None,
#   'player_b1': 64414,
#   'player_b2': 93512},
#  {'_id': ObjectId('6614a37733614c4135bfcffd'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-11T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 251646,
#   'player_a2': 77849,
#   'player_b1': 64414,
#   'player_b2': 265464},
#  {'_id': ObjectId('6614a37733614c4135bfcffe'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-11T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 242629,
#   'player_a2': None,
#   'player_b1': 242644,
#   'player_b2': 415725},
#  {'_id': ObjectId('6614a37733614c4135bfcfff'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-12-14T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 242629,
#   'player_a2': 71511,
#   'player_b1': 382735,
#   'player_b2': 415725},
#  {'_id': ObjectId('6614a37733614c4135bfd000'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-12-14T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 400555,
#   'player_a2': 64414,
#   'player_b1': 251646,
#   'player_b2': 250672},
#  {'_id': ObjectId('6614a37733614c4135bfd001'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-30T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 71511,
#   'player_b1': 410672,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a37733614c4135bfd002'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-28T00:00:00',
#   'scores': '14-15, 15-8, 15-11, 11-15, 15-6',
#   'player_a1': 382735,
#   'player_a2': 415725,
#   'player_b1': 440965,
#   'player_b2': 256145},
#  {'_id': ObjectId('6614a37733614c4135bfd003'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-16T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': 72446,
#   'player_b2': 13263},
#  {'_id': ObjectId('6614a37733614c4135bfd004'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-16T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 71511,
#   'player_b1': 265464,
#   'player_b2': 256046},
#  {'_id': ObjectId('6614a37733614c4135bfd005'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-09T00:00:00',
#   'scores': '15-6, 15-14, 8-15, 15-13',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': 64414,
#   'player_b2': 250760},
#  {'_id': ObjectId('6614a37733614c4135bfd006'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-09T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 71511,
#   'player_b1': 382735,
#   'player_b2': 415725},
#  {'_id': ObjectId('6614a37733614c4135bfd007'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-02T00:00:00',
#   'scores': '15-13, 14-15, 15-8, 15-12',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': None,
#   'player_b2': 71511},
#  {'_id': ObjectId('6614a37733614c4135bfd008'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-02T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 64414,
#   'player_a2': 265464,
#   'player_b1': 13263,
#   'player_b2': 411278},
#  {'_id': ObjectId('6614a37733614c4135bfd009'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-19T00:00:00',
#   'scores': '15-10, 15-11, 15-12',
#   'player_a1': 411278,
#   'player_a2': 410878,
#   'player_b1': 297721,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a37733614c4135bfd00a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-19T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 400555,
#   'player_a2': 256046,
#   'player_b1': None,
#   'player_b2': 71511},
#  {'_id': ObjectId('6614a37733614c4135bfd00b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-12T00:00:00',
#   'scores': '15-11, 15-4, 8-15, 15-8',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': 440965,
#   'player_b2': 250760},
#  {'_id': ObjectId('6614a37733614c4135bfd00c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-12T00:00:00',
#   'scores': '15-11, 15-9, 15-12',
#   'player_a1': 72446,
#   'player_a2': 415725,
#   'player_b1': None,
#   'player_b2': 71511},
#  {'_id': ObjectId('6614a37733614c4135bfd00d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-05T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 397904,
#   'player_b1': 410672,
#   'player_b2': 242554},
#  {'_id': ObjectId('6614a37733614c4135bfd00e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-05T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 415725,
#   'player_a2': 411278,
#   'player_b1': 250760,
#   'player_b2': 256046},
#  {'_id': ObjectId('6614a37733614c4135bfd00f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-24T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 323007,
#   'player_a2': 0,
#   'player_b1': 71809,
#   'player_b2': 385805},
#  {'_id': ObjectId('6614a37733614c4135bfd010'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-24T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 246849,
#   'player_a2': 303589,
#   'player_b1': 397238,
#   'player_b2': 396573},
#  {'_id': ObjectId('6614a37733614c4135bfd011'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-14T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 415271,
#   'player_a2': 247342,
#   'player_b1': 400727,
#   'player_b2': 85092},
#  {'_id': ObjectId('6614a37733614c4135bfd012'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-17T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 298195,
#   'player_a2': 399677,
#   'player_b1': 303569,
#   'player_b2': 303555},
#  {'_id': ObjectId('6614a37733614c4135bfd013'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-10T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 242692,
#   'player_a2': 303569,
#   'player_b1': 323007,
#   'player_b2': 298184},
#  {'_id': ObjectId('6614a37733614c4135bfd014'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-27T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 397271,
#   'player_a2': 400727,
#   'player_b1': None,
#   'player_b2': 322882},
#  {'_id': ObjectId('6614a37733614c4135bfd015'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-27T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 298945,
#   'player_a2': 386742,
#   'player_b1': None,
#   'player_b2': 303569},
#  {'_id': ObjectId('6614a37733614c4135bfd016'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-03T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 298206,
#   'player_a2': 400727,
#   'player_b1': 298945,
#   'player_b2': 303589},
#  {'_id': ObjectId('6614a37733614c4135bfd017'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-03T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 303569,
#   'player_a2': None,
#   'player_b1': 399677,
#   'player_b2': None},
#  {'_id': ObjectId('6614a37733614c4135bfd018'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-20T00:00:00',
#   'scores': '2-15, 9-15, 6-15',
#   'player_a1': 298184,
#   'player_a2': 397271,
#   'player_b1': 415271,
#   'player_b2': 246849},
#  {'_id': ObjectId('6614a37733614c4135bfd019'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-13T00:00:00',
#   'scores': '15-9, 15-13, 15-6',
#   'player_a1': 386213,
#   'player_a2': 246849,
#   'player_b1': 399677,
#   'player_b2': 396178},
#  {'_id': ObjectId('6614a37733614c4135bfd01a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-06T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 242207,
#   'player_a2': 298945,
#   'player_b1': 396178,
#   'player_b2': 298195},
#  {'_id': ObjectId('6614a37733614c4135bfd01b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-06T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 303555,
#   'player_a2': 242692,
#   'player_b1': 400727,
#   'player_b2': 298206},
#  {'_id': ObjectId('6614a37733614c4135bfd01c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-17T00:00:00',
#   'scores': '15-12, 10-15, 3-15, 13-15',
#   'player_a1': 167417,
#   'player_a2': 246905,
#   'player_b1': 271931,
#   'player_b2': 1000000289},
#  {'_id': ObjectId('6614a37733614c4135bfd01d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-17T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 71931,
#   'player_a2': 242138,
#   'player_b1': 397295,
#   'player_b2': 242227},
#  {'_id': ObjectId('6614a37733614c4135bfd01e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-10T00:00:00',
#   'scores': '15-8, 15-10, 15-12',
#   'player_a1': 246777,
#   'player_a2': 71931,
#   'player_b1': 167417,
#   'player_b2': 246905},
#  {'_id': ObjectId('6614a37733614c4135bfd01f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-10T00:00:00',
#   'scores': '15-14, 15-11, 8-15, 13-15, 13-15',
#   'player_a1': 271931,
#   'player_a2': 397295,
#   'player_b1': 246811,
#   'player_b2': 246021},
#  {'_id': ObjectId('6614a37733614c4135bfd020'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-03T00:00:00',
#   'scores': '5-15, 11-15, 6-15',
#   'player_a1': 1000000289,
#   'player_a2': 246930,
#   'player_b1': 242227,
#   'player_b2': 217589},
#  {'_id': ObjectId('6614a37733614c4135bfd021'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-03T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 72487,
#   'player_a2': 246824,
#   'player_b1': 246811,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a37733614c4135bfd022'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-24T00:00:00',
#   'scores': '15-13, 10-15, 15-7, 15-12',
#   'player_a1': 271931,
#   'player_a2': 242227,
#   'player_b1': 246811,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a37733614c4135bfd023'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-24T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 298782,
#   'player_a2': 1000000289,
#   'player_b1': 72487,
#   'player_b2': 246824},
#  {'_id': ObjectId('6614a37733614c4135bfd024'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-17T00:00:00',
#   'scores': '15-7, 8-15, 15-13, 15-7',
#   'player_a1': 298782,
#   'player_a2': 271931,
#   'player_b1': 71931,
#   'player_b2': 246811},
#  {'_id': ObjectId('6614a37733614c4135bfd025'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-10T00:00:00',
#   'scores': '11-15, 15-8, 15-12, 12-15, 15-14',
#   'player_a1': 397295,
#   'player_a2': 242227,
#   'player_b1': 246930,
#   'player_b2': 298782},
#  {'_id': ObjectId('6614a37733614c4135bfd026'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-10T00:00:00',
#   'scores': '6-15, 15-12, 15-3, 15-12',
#   'player_a1': 71931,
#   'player_a2': 242138,
#   'player_b1': 167417,
#   'player_b2': 246824},
#  {'_id': ObjectId('6614a37733614c4135bfd027'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-03T00:00:00',
#   'scores': '15-10, 15-5, 9-15, 15-4',
#   'player_a1': 217589,
#   'player_a2': 242227,
#   'player_b1': 71931,
#   'player_b2': 246811},
#  {'_id': ObjectId('6614a37733614c4135bfd028'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-03T00:00:00',
#   'scores': '15-13, 15-12, 15-6',
#   'player_a1': 246930,
#   'player_a2': 298782,
#   'player_b1': 72487,
#   'player_b2': 246675},
#  {'_id': ObjectId('6614a37733614c4135bfd029'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-27T00:00:00',
#   'scores': '15-8, 15-8, 15-13',
#   'player_a1': 72487,
#   'player_a2': 246824,
#   'player_b1': 271931,
#   'player_b2': 246930},
#  {'_id': ObjectId('6614a37733614c4135bfd02a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-27T00:00:00',
#   'scores': '4-15, 9-15, 15-9, 15-6, 12-15',
#   'player_a1': 246811,
#   'player_a2': 242138,
#   'player_b1': 279520,
#   'player_b2': 242227},
#  {'_id': ObjectId('6614a37733614c4135bfd02b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-20T00:00:00',
#   'scores': '15-10, 15-12, 10-15, 15-12',
#   'player_a1': 298782,
#   'player_a2': 279520,
#   'player_b1': 246675,
#   'player_b2': 246021},
#  {'_id': ObjectId('6614a37733614c4135bfd02c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-20T00:00:00',
#   'scores': '7-15, 9-15, 9-15',
#   'player_a1': 246811,
#   'player_a2': 242138,
#   'player_b1': 1000000289,
#   'player_b2': 246930},
#  {'_id': ObjectId('6614a37733614c4135bfd02d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-13T00:00:00',
#   'scores': '11-0, 11-0, 11-0',
#   'player_a1': 271931,
#   'player_a2': 246930,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('6614a37733614c4135bfd02e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-13T00:00:00',
#   'scores': '11-0, 11-0, 11-0',
#   'player_a1': 0,
#   'player_a2': 0,
#   'player_b1': 71931,
#   'player_b2': 246811},
#  {'_id': ObjectId('6614a37733614c4135bfd02f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-16T00:00:00',
#   'scores': '12-15, 15-13, 15-12, 15-9',
#   'player_a1': 298782,
#   'player_a2': 246930,
#   'player_b1': 246021,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a37733614c4135bfd030'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-16T00:00:00',
#   'scores': '15-12, 15-12, 15-13',
#   'player_a1': 381524,
#   'player_a2': 246931,
#   'player_b1': 381524,
#   'player_b2': 242310},
#  {'_id': ObjectId('6614a37733614c4135bfd031'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-09T00:00:00',
#   'scores': '15-11, 15-8, 15-11',
#   'player_a1': 242227,
#   'player_a2': 279520,
#   'player_b1': 298782,
#   'player_b2': 246930},
#  {'_id': ObjectId('6614a37733614c4135bfd032'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-09T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 246811,
#   'player_a2': 242138,
#   'player_b1': 167417,
#   'player_b2': 246824},
#  {'_id': ObjectId('6614a37733614c4135bfd033'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-18T00:00:00',
#   'scores': '15-9, 15-11, 15-12',
#   'player_a1': 72487,
#   'player_a2': 246824,
#   'player_b1': 271931,
#   'player_b2': 246930},
#  {'_id': ObjectId('6614a37733614c4135bfd034'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-18T00:00:00',
#   'scores': '15-11, 15-5, 10-15, 9-15, 12-15',
#   'player_a1': 246811,
#   'player_a2': 242138,
#   'player_b1': 242227,
#   'player_b2': 279520},
#  {'_id': ObjectId('6614a37733614c4135bfd035'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-04T00:00:00',
#   'scores': '12-15, 7-15, 9-15',
#   'player_a1': 246777,
#   'player_a2': 242227,
#   'player_b1': 72487,
#   'player_b2': 246824},
#  {'_id': ObjectId('6614a37733614c4135bfd036'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-10-28T00:00:00',
#   'scores': '12-15, 15-12, 15-14, 15-13',
#   'player_a1': 246930,
#   'player_a2': 271931,
#   'player_b1': 242227,
#   'player_b2': 279520},
#  {'_id': ObjectId('6614a37733614c4135bfd037'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-30T00:00:00',
#   'scores': '9-15, 11-15, 8-15',
#   'player_a1': None,
#   'player_a2': 397904,
#   'player_b1': 411278,
#   'player_b2': 410878},
#  {'_id': ObjectId('6614a37733614c4135bfd038'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-16T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': None,
#   'player_a2': 410672,
#   'player_b1': 251576,
#   'player_b2': 415725},
#  {'_id': ObjectId('6614a37733614c4135bfd039'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-16T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 265464,
#   'player_a2': 93512,
#   'player_b1': 255885,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a37733614c4135bfd03a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-09T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 298492,
#   'player_a2': 410878,
#   'player_b1': 255885,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a37733614c4135bfd03b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-09T00:00:00',
#   'scores': '15-10, 12-15, 15-7, 11-15, 15-13',
#   'player_a1': 246972,
#   'player_a2': 273389,
#   'player_b1': 298930,
#   'player_b2': 1000000289},
#  {'_id': ObjectId('6614a37733614c4135bfd03c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-02T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 251646,
#   'player_a2': 93465,
#   'player_b1': 93512,
#   'player_b2': 440965},
#  {'_id': ObjectId('6614a37733614c4135bfd03d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-02T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 242629,
#   'player_b1': 411278,
#   'player_b2': 410878},
#  {'_id': ObjectId('6614a37733614c4135bfd03e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-02T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 297780,
#   'player_a2': 303589,
#   'player_b1': 398145,
#   'player_b2': 271931},
#  {'_id': ObjectId('6614a37733614c4135bfd03f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-23T00:00:00',
#   'scores': '13-15, 15-14, 10-15, 13-15',
#   'player_a1': 246972,
#   'player_a2': 0,
#   'player_b1': 242842,
#   'player_b2': 399642},
#  {'_id': ObjectId('6614a37733614c4135bfd040'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-23T00:00:00',
#   'scores': '15-10, 15-9, 8-15, 15-8',
#   'player_a1': 271931,
#   'player_a2': 256018,
#   'player_b1': 242595,
#   'player_b2': 397351},
#  {'_id': ObjectId('6614a37733614c4135bfd041'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-16T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 255885,
#   'player_a2': 250672,
#   'player_b1': 72446,
#   'player_b2': 415725},
#  {'_id': ObjectId('6614a37733614c4135bfd042'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-16T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 242629,
#   'player_b1': 93512,
#   'player_b2': 256046},
#  {'_id': ObjectId('6614a37733614c4135bfd043'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-16T00:00:00',
#   'scores': '14-15, 12-15, 15-10, 15-14, 15-10',
#   'player_a1': 256018,
#   'player_a2': 271931,
#   'player_b1': 246972,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a37733614c4135bfd044'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-16T00:00:00',
#   'scores': '14-15, 8-15, 15-6, 8-15',
#   'player_a1': 242842,
#   'player_a2': 303589,
#   'player_b1': 397351,
#   'player_b2': 242595},
#  {'_id': ObjectId('6614a37733614c4135bfd045'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-09T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 265464,
#   'player_a2': 256046,
#   'player_b1': 251781,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a37733614c4135bfd046'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-09T00:00:00',
#   'scores': '14-15, 9-15, 14-15',
#   'player_a1': 1000000289,
#   'player_a2': 271931,
#   'player_b1': 297780,
#   'player_b2': 303589},
#  {'_id': ObjectId('6614a37733614c4135bfd047'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-02T00:00:00',
#   'scores': '14-15, 15-11, 13-15, 15-11, 12-15',
#   'player_a1': 398145,
#   'player_a2': None,
#   'player_b1': 242765,
#   'player_b2': 242595},
#  {'_id': ObjectId('6614a37733614c4135bfd048'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-26T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': None,
#   'player_a2': 242629,
#   'player_b1': 250672,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a37733614c4135bfd049'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-26T00:00:00',
#   'scores': '15-14, 12-15, 13-15, 15-11, 10-15',
#   'player_a1': 93518,
#   'player_a2': 265464,
#   'player_b1': 72446,
#   'player_b2': 410878},
#  {'_id': ObjectId('6614a37733614c4135bfd04a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-26T00:00:00',
#   'scores': '12-15, 15-13, 12-15, 8-15',
#   'player_a1': 256018,
#   'player_a2': 271931,
#   'player_b1': 242765,
#   'player_b2': 242595},
#  {'_id': ObjectId('6614a37733614c4135bfd04b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-26T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 242842,
#   'player_a2': 71809,
#   'player_b1': 246972,
#   'player_b2': None},
#  {'_id': ObjectId('6614a37733614c4135bfd04c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-19T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 13263,
#   'player_a2': 411278,
#   'player_b1': 77849,
#   'player_b2': None},
#  {'_id': ObjectId('6614a37733614c4135bfd04d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-19T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 298934,
#   'player_a2': 93512,
#   'player_b1': 401706,
#   'player_b2': 242629},
#  {'_id': ObjectId('6614a37733614c4135bfd04e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-19T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': None,
#   'player_a2': None,
#   'player_b1': 298930,
#   'player_b2': 256142},
#  {'_id': ObjectId('6614a37733614c4135bfd04f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-19T00:00:00',
#   'scores': '15-12, 14-15, 13-15, 15-9, 15-12',
#   'player_a1': 242765,
#   'player_a2': 242595,
#   'player_b1': 297780,
#   'player_b2': 397343},
#  {'_id': ObjectId('6614a37733614c4135bfd050'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-12T00:00:00',
#   'scores': '15-14, 15-11, 14-15, 14-15, 7-15',
#   'player_a1': 246256,
#   'player_a2': 398195,
#   'player_b1': 242629,
#   'player_b2': None},
#  {'_id': ObjectId('6614a37733614c4135bfd051'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-12T00:00:00',
#   'scores': '9-15, 5-15, 12-15',
#   'player_a1': 242842,
#   'player_a2': 71809,
#   'player_b1': 256018,
#   'player_b2': 271931},
#  {'_id': ObjectId('6614a37733614c4135bfd052'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-05T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 440965,
#   'player_a2': 265464,
#   'player_b1': 72446,
#   'player_b2': 411278},
#  {'_id': ObjectId('6614a37733614c4135bfd053'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-05T00:00:00',
#   'scores': '12-15, 12-15, 15-14, 11-15',
#   'player_a1': 246972,
#   'player_a2': None,
#   'player_b1': 297780,
#   'player_b2': 303589},
#  {'_id': ObjectId('6614a37733614c4135bfd054'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-15T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': None,
#   'player_a2': None,
#   'player_b1': 250760,
#   'player_b2': 298934},
#  {'_id': ObjectId('6614a37733614c4135bfd055'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-15T00:00:00',
#   'scores': '15-13, 15-14, 8-15, 15-14',
#   'player_a1': 415725,
#   'player_a2': 411278,
#   'player_b1': 255885,
#   'player_b2': 77849},
#  {'_id': ObjectId('6614a37733614c4135bfd056'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-15T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 246972,
#   'player_a2': None,
#   'player_b1': 256018,
#   'player_b2': None},
#  {'_id': ObjectId('6614a37733614c4135bfd057'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-15T00:00:00',
#   'scores': '11-15, 15-11, 15-6, 15-4',
#   'player_a1': 242842,
#   'player_a2': 71809,
#   'player_b1': 242765,
#   'player_b2': 242595},
#  {'_id': ObjectId('6614a37733614c4135bfd058'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-08T00:00:00',
#   'scores': '15-10, 15-10, 10-15, 10-15, 10-15',
#   'player_a1': 255885,
#   'player_a2': None,
#   'player_b1': 250760,
#   'player_b2': 265464},
#  {'_id': ObjectId('6614a37733614c4135bfd059'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-08T00:00:00',
#   'scores': '8-15, 14-15, 7-15',
#   'player_a1': 298930,
#   'player_a2': 242869,
#   'player_b1': 242842,
#   'player_b2': 397343},
#  {'_id': ObjectId('6614a37733614c4135bfd05a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-08T00:00:00',
#   'scores': '15-14, 10-15, 12-15, 15-7, 14-15',
#   'player_a1': 397370,
#   'player_a2': 242595,
#   'player_b1': 246972,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a37733614c4135bfd05b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-17T00:00:00',
#   'scores': '15-8, 8-15, 15-7, 15-6',
#   'player_a1': 397343,
#   'player_a2': 71809,
#   'player_b1': None,
#   'player_b2': 397297},
#  {'_id': ObjectId('6614a37733614c4135bfd05c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-17T00:00:00',
#   'scores': '15-10, 15-11, 15-9',
#   'player_a1': 397351,
#   'player_a2': 397370,
#   'player_b1': 386262,
#   'player_b2': 256142},
#  {'_id': ObjectId('6614a37733614c4135bfd05d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-10T00:00:00',
#   'scores': '15-6, 15-5, 13-15, 15-13',
#   'player_a1': 255885,
#   'player_a2': 93465,
#   'player_b1': 246256,
#   'player_b2': 397422},
#  {'_id': ObjectId('6614a37733614c4135bfd05e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-10T00:00:00',
#   'scores': '15-4, 15-4, 15-13',
#   'player_a1': 398145,
#   'player_a2': 271931,
#   'player_b1': None,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a37733614c4135bfd05f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-10T00:00:00',
#   'scores': '12-15, 15-14, 15-11, 15-13',
#   'player_a1': 310387,
#   'player_a2': 242595,
#   'player_b1': 297780,
#   'player_b2': 247283},
#  {'_id': ObjectId('6614a37733614c4135bfd060'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-10-27T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': None,
#   'player_a2': 242138,
#   'player_b1': 71809,
#   'player_b2': 242842},
#  {'_id': ObjectId('6614a37733614c4135bfd061'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-10-27T00:00:00',
#   'scores': '15-12, 15-13, 11-15, 15-6',
#   'player_a1': 397351,
#   'player_a2': 242595,
#   'player_b1': 256018,
#   'player_b2': 256142},
#  {'_id': ObjectId('6614a38c33614c4135bfd063'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-16T00:00:00',
#   'scores': '15-9,15-13,15-9',
#   'player_a1': 251646,
#   'player_a2': 398904,
#   'player_b1': 255882,
#   'player_b2': 263492},
#  {'_id': ObjectId('6614a38c33614c4135bfd064'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-15T00:00:00',
#   'scores': '15-11,11-15,7-15,15-14,15-12',
#   'player_a1': 382735,
#   'player_a2': 415725,
#   'player_b1': 64414,
#   'player_b2': 404094},
#  {'_id': ObjectId('6614a38c33614c4135bfd065'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-16T00:00:00',
#   'scores': '13-15,15-4,15-8,15-9',
#   'player_a1': 78826,
#   'player_a2': 77849,
#   'player_b1': 410672,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a38c33614c4135bfd066'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '15-10,15-4,15-4',
#   'player_a1': 400794,
#   'player_a2': 72670,
#   'player_b1': 72446,
#   'player_b2': 256029},
#  {'_id': ObjectId('6614a38c33614c4135bfd067'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '15-9,15-11,15-12',
#   'player_a1': 251646,
#   'player_a2': 398904,
#   'player_b1': 382735,
#   'player_b2': 415725},
#  {'_id': ObjectId('6614a38c33614c4135bfd068'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-9,12-15,15-7,15-12',
#   'player_a1': 78826,
#   'player_a2': 77849,
#   'player_b1': 72446,
#   'player_b2': 256029},
#  {'_id': ObjectId('6614a38c33614c4135bfd069'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-19T00:00:00',
#   'scores': '15-12,15-14,15-7',
#   'player_a1': 251646,
#   'player_a2': 398904,
#   'player_b1': 72446,
#   'player_b2': 256029},
#  {'_id': ObjectId('6614a38c33614c4135bfd06a'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-0,15-0,14-15,15-0',
#   'player_a1': 255882,
#   'player_a2': 263492,
#   'player_b1': 64414,
#   'player_b2': 404094},
#  {'_id': ObjectId('6614a38c33614c4135bfd06b'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-8,15-7,15-10',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': 400794,
#   'player_b2': 72670},
#  {'_id': ObjectId('6614a38c33614c4135bfd06c'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-19T00:00:00',
#   'scores': '',
#   'player_a1': 255882,
#   'player_a2': 263492,
#   'player_b1': 410672,
#   'player_b2': 93465},
#  {'_id': ObjectId('6614a38c33614c4135bfd06d'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-15T00:00:00',
#   'scores': '',
#   'player_a1': 72487,
#   'player_a2': 242227,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('6614a38c33614c4135bfd06e'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '7-15,7-15,15-10,15-11,15-9',
#   'player_a1': 246824,
#   'player_a2': 280973,
#   'player_b1': 174510,
#   'player_b2': 271931},
#  {'_id': ObjectId('6614a38c33614c4135bfd06f'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-15T00:00:00',
#   'scores': '15-4,15-7,15-7',
#   'player_a1': 398968,
#   'player_a2': 323011,
#   'player_b1': 279520,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a38c33614c4135bfd070'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-16T00:00:00',
#   'scores': '15-9,15-7,15-3',
#   'player_a1': 328787,
#   'player_a2': 71931,
#   'player_b1': 397037,
#   'player_b2': 246843},
#  {'_id': ObjectId('6614a38c33614c4135bfd071'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-7,15-11,11-15,15-12',
#   'player_a1': 72487,
#   'player_a2': 242227,
#   'player_b1': 174510,
#   'player_b2': 271931},
#  {'_id': ObjectId('6614a38c33614c4135bfd072'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-13,10-15,15-11,15-5',
#   'player_a1': 398968,
#   'player_a2': 323011,
#   'player_b1': 397037,
#   'player_b2': 246843},
#  {'_id': ObjectId('6614a38c33614c4135bfd073'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-19T00:00:00',
#   'scores': '15-7,13-15,15-4,15-6',
#   'player_a1': 72487,
#   'player_a2': 242227,
#   'player_b1': 397037,
#   'player_b2': 246843},
#  {'_id': ObjectId('6614a38c33614c4135bfd074'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-15T00:00:00',
#   'scores': '',
#   'player_a1': 0,
#   'player_a2': 0,
#   'player_b1': 246824,
#   'player_b2': 280973},
#  {'_id': ObjectId('6614a38c33614c4135bfd075'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-13,13-15,15-14,15-5',
#   'player_a1': 279520,
#   'player_a2': 242138,
#   'player_b1': 328787,
#   'player_b2': 71931},
#  {'_id': ObjectId('6614a38c33614c4135bfd076'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-19T00:00:00',
#   'scores': '12-15,15-10,15-12,15-4',
#   'player_a1': 246824,
#   'player_a2': 280973,
#   'player_b1': 279520,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a38c33614c4135bfd077'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '15-9,15-3,15-11',
#   'player_a1': 77849,
#   'player_a2': 280973,
#   'player_b1': 71931,
#   'player_b2': 256046},
#  {'_id': ObjectId('6614a38c33614c4135bfd078'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '15-14,15-8,15-13',
#   'player_a1': 167312,
#   'player_a2': 130188,
#   'player_b1': 242227,
#   'player_b2': 410672},
#  {'_id': ObjectId('6614a38c33614c4135bfd079'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-15T00:00:00',
#   'scores': '15-13,9-15,15-12,15-14',
#   'player_a1': 398904,
#   'player_a2': 398968,
#   'player_b1': 250672,
#   'player_b2': 217589},
#  {'_id': ObjectId('6614a38c33614c4135bfd07a'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '14-15,15-11,15-7,15-4',
#   'player_a1': 327890,
#   'player_a2': 72670,
#   'player_b1': 255882,
#   'player_b2': 246843},
#  {'_id': ObjectId('6614a38c33614c4135bfd07b'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-10,15-8,15-10',
#   'player_a1': 77849,
#   'player_a2': 280973,
#   'player_b1': 242227,
#   'player_b2': 410672},
#  {'_id': ObjectId('6614a38c33614c4135bfd07c'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '8-15,15-5,13-15,15-12,15-8',
#   'player_a1': 398904,
#   'player_a2': 398968,
#   'player_b1': 255882,
#   'player_b2': 246843},
#  {'_id': ObjectId('6614a38c33614c4135bfd07d'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-19T00:00:00',
#   'scores': '15-12,15-11,12-15,15-14',
#   'player_a1': 77849,
#   'player_a2': 280973,
#   'player_b1': 398904,
#   'player_b2': 398968},
#  {'_id': ObjectId('6614a38c33614c4135bfd07e'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-12,15-9,15-6',
#   'player_a1': 71931,
#   'player_a2': 256046,
#   'player_b1': 167312,
#   'player_b2': 130188},
#  {'_id': ObjectId('6614a38c33614c4135bfd07f'),
# ...
#  {'_id': ObjectId('6614a38c33614c4135bfd214'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '12-15,12-15,15-14,15-9,15-11',
#   'player_a1': 397370,
#   'player_a2': 239021,
#   'player_b1': 381524,
#   'player_b2': 242842},
#  {'_id': ObjectId('6614a38c33614c4135bfd215'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '',
#   'player_a1': 410672,
#   'player_a2': 437332,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('6614a38c33614c4135bfd216'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 397370,
#   'player_a2': 303589,
#   'player_b1': 237850,
#   'player_b2': 398852},
#  {'_id': ObjectId('6614a38c33614c4135bfd217'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '9-15,15-9,15-9,15-9',
#   'player_a1': 310387,
#   'player_a2': 71809,
#   'player_b1': 325934,
#   'player_b2': 437578},
#  {'_id': ObjectId('6614a38c33614c4135bfd218'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '15-6,15-13,15-14',
#   'player_a1': 397043,
#   'player_a2': 386860,
#   'player_b1': 398008,
#   'player_b2': 254814},
#  {'_id': ObjectId('6614a38c33614c4135bfd219'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 397343,
#   'player_a2': 242765,
#   'player_b1': 71473,
#   'player_b2': 242884},
#  {'_id': ObjectId('6614a38c33614c4135bfd21a'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-11,15-14,15-11',
#   'player_a1': 297880,
#   'player_a2': 436713,
#   'player_b1': 85092,
#   'player_b2': 246972},
#  {'_id': ObjectId('6614a38c33614c4135bfd21b'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-8,15-5,15-12',
#   'player_a1': 399732,
#   'player_a2': 71912,
#   'player_b1': 417740,
#   'player_b2': 397297},
#  {'_id': ObjectId('6614a38c33614c4135bfd21c'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '',
#   'player_a1': 0,
#   'player_a2': 0,
#   'player_b1': 245999,
#   'player_b2': 246824},
#  {'_id': ObjectId('6614a38c33614c4135bfd21d'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '15-11,15-9,15-9',
#   'player_a1': 410672,
#   'player_a2': 437332,
#   'player_b1': 237850,
#   'player_b2': 398852},
#  {'_id': ObjectId('6614a38c33614c4135bfd21e'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-12,4-15,15-10,9-15,15-13',
#   'player_a1': 310387,
#   'player_a2': 71809,
#   'player_b1': 398008,
#   'player_b2': 254814},
#  {'_id': ObjectId('6614a38c33614c4135bfd21f'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-14,15-14,15-11',
#   'player_a1': 397343,
#   'player_a2': 242765,
#   'player_b1': 85092,
#   'player_b2': 246972},
#  {'_id': ObjectId('6614a38c33614c4135bfd220'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-11,15-14',
#   'player_a1': 399732,
#   'player_a2': 71912,
#   'player_b1': 245999,
#   'player_b2': 246824},
#  {'_id': ObjectId('6614a38c33614c4135bfd221'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-3,15-5,15-3',
#   'player_a1': 410672,
#   'player_a2': 437332,
#   'player_b1': 310387,
#   'player_b2': 71809},
#  {'_id': ObjectId('6614a38c33614c4135bfd222'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-6,15-11,11-15,15-13',
#   'player_a1': 85092,
#   'player_a2': 246972,
#   'player_b1': 399732,
#   'player_b2': 71912},
#  {'_id': ObjectId('6614a38c33614c4135bfd223'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '15-7,15-9,15-11',
#   'player_a1': 410672,
#   'player_a2': 437332,
#   'player_b1': 399732,
#   'player_b2': 71912},
#  {'_id': ObjectId('6614a38c33614c4135bfd224'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '',
#   'player_a1': 0,
#   'player_a2': 0,
#   'player_b1': 397370,
#   'player_b2': 303589},
#  {'_id': ObjectId('6614a38c33614c4135bfd225'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '15-7,15-8,15-12',
#   'player_a1': 325934,
#   'player_a2': 437578,
#   'player_b1': 397043,
#   'player_b2': 386860},
#  {'_id': ObjectId('6614a38c33614c4135bfd226'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '15-3,15-5,15-5',
#   'player_a1': 71473,
#   'player_a2': 242884,
#   'player_b1': 297880,
#   'player_b2': 436713},
#  {'_id': ObjectId('6614a38c33614c4135bfd227'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '',
#   'player_a1': 417740,
#   'player_a2': 397297,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('6614a38c33614c4135bfd228'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '15-9,15-7,12-15,15-4',
#   'player_a1': 397370,
#   'player_a2': 303589,
#   'player_b1': 245999,
#   'player_b2': 246824},
#  {'_id': ObjectId('6614a38c33614c4135bfd229'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-10,15-8,15-13',
#   'player_a1': 325934,
#   'player_a2': 437578,
#   'player_b1': 397343,
#   'player_b2': 242765},
#  {'_id': ObjectId('6614a38c33614c4135bfd22a'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '',
#   'player_a1': 297880,
#   'player_a2': 436713,
#   'player_b1': 398008,
#   'player_b2': 254814},
#  {'_id': ObjectId('6614a38c33614c4135bfd22b'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-6,15-10,15-6',
#   'player_a1': 417740,
#   'player_a2': 397297,
#   'player_b1': 237850,
#   'player_b2': 398852},
#  {'_id': ObjectId('6614a38c33614c4135bfd22c'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '9-15,9-15,15-9,15-9,15-9',
#   'player_a1': 245999,
#   'player_a2': 246824,
#   'player_b1': 397343,
#   'player_b2': 242765},
#  {'_id': ObjectId('6614a38c33614c4135bfd22d'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '',
#   'player_a1': -1,
#   'player_a2': -1,
#   'player_b1': 237850,
#   'player_b2': 398852},
#  {'_id': ObjectId('6614a38c33614c4135bfd22e'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '15-7,15-6,15-13',
#   'player_a1': 397343,
#   'player_a2': 242765,
#   'player_b1': 237850,
#   'player_b2': 398852},
#  {'_id': ObjectId('6614a38c33614c4135bfd22f'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '14-15,15-10,15-10,14-15,15-9',
#   'player_a1': 317416,
#   'player_a2': 242182,
#   'player_b1': 306133,
#   'player_b2': 396178},
#  {'_id': ObjectId('6614a38c33614c4135bfd230'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '15-6,15-8,15-10',
#   'player_a1': 246687,
#   'player_a2': 396299,
#   'player_b1': 298945,
#   'player_b2': 397271},
#  {'_id': ObjectId('6614a38c33614c4135bfd231'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '12-15,8-15,15-13,15-14,15-12',
#   'player_a1': 306133,
#   'player_a2': 396178,
#   'player_b1': 246687,
#   'player_b2': 396299},
#  {'_id': ObjectId('6614a38c33614c4135bfd232'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-6,15-5,15-11',
#   'player_a1': 317416,
#   'player_a2': 242182,
#   'player_b1': 298945,
#   'player_b2': 397271},
#  {'_id': ObjectId('6614a38c33614c4135bfd233'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-7,15-11,15-4',
#   'player_a1': 246021,
#   'player_a2': 298222,
#   'player_b1': 306133,
#   'player_b2': 396178},
#  {'_id': ObjectId('6614a38c33614c4135bfd234'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 246849,
#   'player_a2': 298206,
#   'player_b1': 317416,
#   'player_b2': 242182},
#  {'_id': ObjectId('6614a38c33614c4135bfd235'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-6,15-7,15-11',
#   'player_a1': 246021,
#   'player_a2': 298222,
#   'player_b1': 246687,
#   'player_b2': 396299},
#  {'_id': ObjectId('6614a38c33614c4135bfd236'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-10,15-4,15-8',
#   'player_a1': 246849,
#   'player_a2': 298206,
#   'player_b1': 298945,
#   'player_b2': 397271},
#  {'_id': ObjectId('6614a38c33614c4135bfd237'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': 246182,
#   'player_b2': 250760},
#  {'_id': ObjectId('6614a38c33614c4135bfd238'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 423651,
#   'player_a2': 330944,
#   'player_b1': 297721,
#   'player_b2': 280973},
#  {'_id': ObjectId('6614a38c33614c4135bfd239'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-6,15-11,15-10',
#   'player_a1': 410672,
#   'player_a2': 246930,
#   'player_b1': 323678,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a38c33614c4135bfd23a'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-10,15-9,15-11',
#   'player_a1': 244338,
#   'player_a2': 399111,
#   'player_b1': 398904,
#   'player_b2': 279520},
#  {'_id': ObjectId('6614a38c33614c4135bfd23b'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-12,15-6,15-14',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': 297721,
#   'player_b2': 280973},
#  {'_id': ObjectId('6614a38c33614c4135bfd23c'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '',
#   'player_a1': 410672,
#   'player_a2': 246930,
#   'player_b1': 398904,
#   'player_b2': 279520},
#  {'_id': ObjectId('6614a38c33614c4135bfd23d'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': -1,
#   'player_b2': -1},
#  {'_id': ObjectId('6614a38c33614c4135bfd23e'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '9-15,15-9,15-9,15-9',
#   'player_a1': 246182,
#   'player_a2': 250760,
#   'player_b1': 423651,
#   'player_b2': 330944},
#  {'_id': ObjectId('6614a38c33614c4135bfd23f'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '5-15,15-9,15-12,15-12',
#   'player_a1': 323678,
#   'player_a2': 242138,
#   'player_b1': 244338,
#   'player_b2': 399111},
#  {'_id': ObjectId('6614a38c33614c4135bfd240'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '15-10,15-7,15-6',
#   'player_a1': 423651,
#   'player_a2': 330944,
#   'player_b1': 244338,
#   'player_b2': 399111},
#  {'_id': ObjectId('6614a38c33614c4135bfd241'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': 246182,
#   'player_b2': 250760},
#  {'_id': ObjectId('6614a38c33614c4135bfd242'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 423651,
#   'player_a2': 330944,
#   'player_b1': 297721,
#   'player_b2': 280973},
#  {'_id': ObjectId('6614a38c33614c4135bfd243'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-6,15-11,15-10',
#   'player_a1': 410672,
#   'player_a2': 246930,
#   'player_b1': 323678,
#   'player_b2': 242138},
#  {'_id': ObjectId('6614a38c33614c4135bfd244'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-10,15-9,15-11',
#   'player_a1': 244338,
#   'player_a2': 399111,
#   'player_b1': 398904,
#   'player_b2': 279520},
#  {'_id': ObjectId('6614a38c33614c4135bfd245'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-12,15-6,15-14',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': 297721,
#   'player_b2': 280973},
#  {'_id': ObjectId('6614a38c33614c4135bfd246'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '',
#   'player_a1': 410672,
#   'player_a2': 246930,
#   'player_b1': 398904,
#   'player_b2': 279520},
#  {'_id': ObjectId('6614a38c33614c4135bfd247'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': -1,
#   'player_b2': -1},
#  {'_id': ObjectId('6614a38c33614c4135bfd248'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '9-15,15-9,15-9,15-9',
#   'player_a1': 246182,
#   'player_a2': 250760,
#   'player_b1': 423651,
#   'player_b2': 330944},
#  {'_id': ObjectId('6614a38c33614c4135bfd249'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '5-15,15-9,15-12,15-12',
#   'player_a1': 323678,
#   'player_a2': 242138,
#   'player_b1': 244338,
#   'player_b2': 399111},
#  {'_id': ObjectId('6614a38c33614c4135bfd24a'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '15-10,15-7,15-6',
#   'player_a1': 423651,
#   'player_a2': 330944,
#   'player_b1': 244338,
#   'player_b2': 399111}]

# %%
matches_df = pd.DataFrame(matches_list)

# %%
matches_df
# Out:
#                           _id                                     event_name  \
# 0    6614a37733614c4135bfcfcc                                  Random League
# 1    6614a37733614c4135bfcfcd                                  Random League
# 2    6614a37733614c4135bfcfce                                  Random League
# 3    6614a37733614c4135bfcfcf                                  Random League
# 4    6614a37733614c4135bfcfd0                                  Random League
# ..                        ...                                            ...
# 633  6614a38c33614c4135bfd246  Western Canadian Doubles Squash Championships
# 634  6614a38c33614c4135bfd247  Western Canadian Doubles Squash Championships
# 635  6614a38c33614c4135bfd248  Western Canadian Doubles Squash Championships
# 636  6614a38c33614c4135bfd249  Western Canadian Doubles Squash Championships
# 637  6614a38c33614c4135bfd24a  Western Canadian Doubles Squash Championships
#
#            type                 date                            scores  \
# 0        League  2023-07-20T00:00:00                10-15, 7-15, 10-15
# 1        League  2023-07-20T00:00:00                  9-15, 9-15, 9-15
# 2        League  2023-07-13T00:00:00  15-14, 4-15, 11-15, 15-11, 10-15
# 3        League  2023-07-06T00:00:00      9-15, 9-15, 15-9, 15-9, 15-9
# 4        League  2023-06-29T00:00:00            9-15, 15-9, 15-9, 15-9
# ..          ...                  ...                               ...
# 633  Tournament  2022-11-26T00:00:00
# 634  Tournament  2022-11-27T00:00:00
# 635  Tournament  2022-11-25T00:00:00               9-15,15-9,15-9,15-9
# 636  Tournament  2022-11-25T00:00:00             5-15,15-9,15-12,15-12
# 637  Tournament  2022-11-27T00:00:00                   15-10,15-7,15-6
#
#      player_a1  player_a2  player_b1  player_b2
# 0     397238.0        NaN   397370.0   385805.0
# 1     396299.0   386742.0   397348.0   399783.0
# 2     247259.0   246931.0   397370.0   303589.0
# 3     399783.0   385805.0   246849.0   303555.0
# 4      85092.0   397348.0    70354.0   396178.0
# ..         ...        ...        ...        ...
# 633   410672.0   246930.0   398904.0   279520.0
# 634   242227.0    77849.0       -1.0       -1.0
# 635   246182.0   250760.0   423651.0   330944.0
# 636   323678.0   242138.0   244338.0   399111.0
# 637   423651.0   330944.0   244338.0   399111.0
#
# [638 rows x 9 columns]

# %% [markdown]
# ### Merge matches and players

# %%
for col in matches_df.columns:
    print("{col} colunm has {nullcount} null values".format(col=col, nullcount=matches_df[col].isna().sum()))
# Out:
# _id colunm has 0 null values
# event_name colunm has 0 null values
# type colunm has 0 null values
# date colunm has 0 null values
# scores colunm has 0 null values
# player_a1 colunm has 15 null values
# player_a2 colunm has 10 null values
# player_b1 colunm has 10 null values
# player_b2 colunm has 6 null values

# %%
# First drop NaN player IDs
matches_df = matches_df.dropna(subset=["player_a1", "player_a2", "player_b1", "player_b2"])

# %%
for col in players_df.columns:
    print("{col} colunm has {nullcount} null values".format(col=col, nullcount=players_df[col].isna().sum()))
# Out:
# _id colunm has 0 null values
# fname colunm has 0 null values
# lname colunm has 0 null values
# gender colunm has 0 null values
# age colunm has 0 null values
# ratings colunm has 0 null values

# %%
merged_df = pd.merge(matches_df, players_df, left_on=["player_a1"], right_on=["_id"], how="inner") \
                .drop(columns=["_id_x", "_id_y"]) \
                .rename(columns={
                    "ratings": "player_a1_ratings",
                    "gender": "player_a1_gender",
                    "age": "player_a1_age",
                })
merged_df["player_a1_name"] = merged_df["fname"] + " " + merged_df["lname"]
merged_df.drop(columns=["fname", "lname", "player_a1"], inplace=True)

# %%
merged_df = pd.merge(merged_df, players_df, left_on=["player_a2"], right_on=["_id"], how="inner") \
                .drop(columns=["_id"]) \
                .rename(columns={
                    "ratings": "player_a2_ratings",
                    "gender": "player_a2_gender",
                    "age": "player_a2_age",
                })
merged_df["player_a2_name"] = merged_df["fname"] + " " + merged_df["lname"]
merged_df.drop(columns=["fname", "lname", "player_a2"], inplace=True)

# %%
merged_df = pd.merge(merged_df, players_df, left_on=["player_b1"], right_on=["_id"], how="inner") \
                .drop(columns=["_id"]) \
                .rename(columns={
                    "ratings": "player_b1_ratings",
                    "gender": "player_b1_gender",
                    "age": "player_b1_age",
                })
merged_df["player_b1_name"] = merged_df["fname"] + " " + merged_df["lname"]
merged_df.drop(columns=["fname", "lname", "player_b1"], inplace=True)

# %%
merged_df = pd.merge(merged_df, players_df, left_on=["player_b2"], right_on=["_id"], how="inner") \
                .drop(columns=["_id"]) \
                .rename(columns={
                    "ratings": "player_b2_ratings",
                    "gender": "player_b2_gender",
                    "age": "player_b2_age",
                })
merged_df["player_b2_name"] = merged_df["fname"] + " " + merged_df["lname"]
merged_df.drop(columns=["fname", "lname", "player_b2"], inplace=True)

# %%
merged_df
# Out:
#                                             event_name        type  \
# 0                                        Random League      League
# 1           Evergreen Summer Doubles Squash Tournament  Tournament
# 2           Evergreen Summer Doubles Squash Tournament  Tournament
# 3    2023 Western Canadian Doubles Squash Champions...  Tournament
# 4    2023 Western Canadian Doubles Squash Champions...  Tournament
# ..                                                 ...         ...
# 389         Evergreen Summer Doubles Squash Tournament  Tournament
# 390         Evergreen Summer Doubles Squash Tournament  Tournament
# 391      Western Canadian Doubles Squash Championships  Tournament
# 392         Evergreen Summer Doubles Squash Tournament  Tournament
# 393  Hillside Wealth Management 2023 BC Doubles Cha...  Tournament
#
#                     date                         scores player_a1_gender  \
# 0    2023-07-20T00:00:00               9-15, 9-15, 9-15            women
# 1    2023-06-22T00:00:00                 15-6,15-6,15-9              men
# 2    2023-06-24T00:00:00                15-11,15-8,15-8            women
# 3    2023-11-16T00:00:00         15-12,15-13,14-15,15-5              men
# 4    2023-11-16T00:00:00         15-12,15-13,14-15,15-5              men
# ..                   ...                            ...              ...
# 389  2023-06-22T00:00:00  15-12,12-15,14-15,15-14,15-10              men
# 390  2023-06-22T00:00:00                15-9,15-7,15-10              men
# 391  2022-11-23T00:00:00                15-8,15-5,15-12              men
# 392  2023-06-23T00:00:00    15-8,10-15,10-15,15-12,15-9              men
# 393  2023-03-08T00:00:00                15-9,15-14,15-8              men
#
#     player_a1_age                                  player_a1_ratings  \
# 0             30+  [{'category': 'singles', 'rating': 3.51, 'rank...
# 1             60+  [{'category': 'doubles', 'rating': 3.96, 'rank...
# 2             60+  [{'category': 'singles', 'rating': 3.68, 'rank...
# 3             50+  [{'category': 'singles', 'rating': 4.75, 'rank...
# 4             50+  [{'category': 'singles', 'rating': 4.75, 'rank...
# ..            ...                                                ...
# 389           25+  [{'category': 'singles', 'rating': 6.57, 'rank...
# 390           45+  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 391           45+  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 392           40+  [{'category': 'singles', 'rating': 3.78, 'rank...
# 393           45+  [{'category': 'doubles', 'rating': 4.89, 'rank...
#
#              player_a1_name player_a2_gender player_a2_age  \
# 0                 Zhelin Bu              men           65+
# 1            Dennis Forsman            women           65+
# 2          Annette Johanson              men           65+
# 3                Mark Levey              men           50+
# 4                Mark Levey              men           50+
# ..                      ...              ...           ...
# 389  Guillermo Cortes-Ortiz              men           25+
# 390                Mike Lee              men           55+
# 391                Mike Lee              men           55+
# 392          Roman Razenkov              men           40+
# 393              Gary Evans              men           40+
#
#                                      player_a2_ratings    player_a2_name  \
# 0    [{'category': 'doubles', 'rating': 1.98, 'rank...        Ernie Chan
# 1    [{'category': 'doubles', 'rating': 2.01, 'rank...  Pamela Brunswick
# 2    [{'category': 'doubles', 'rating': 2.3, 'ranki...    Richard Dustan
# 3    [{'category': 'singles', 'rating': 4.89, 'rank...        Jongho Kim
# 4    [{'category': 'singles', 'rating': 4.89, 'rank...        Jongho Kim
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.76, 'rank...    Eduardo Flores
# 390  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 391  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 392  [{'category': 'singles', 'rating': 3.39, 'rank...     Andrew Lavrov
# 393  [{'category': 'doubles', 'rating': 1.75, 'rank...      Jon De Souza
#
#     player_b1_gender player_b1_age  \
# 0                men           60+
# 1              women           60+
# 2              women           60+
# 3                men           55+
# 4                men           55+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           30+
# 392              men           65+
# 393              men           40+
#
#                                      player_b1_ratings    player_b1_name  \
# 0    [{'category': 'doubles', 'rating': 3.09, 'rank...      Ian Binstead
# 1    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 2    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 3    [{'category': 'singles', 'rating': 4.9, 'ranki...      Mike Carrier
# 4    [{'category': 'singles', 'rating': 4.9, 'ranki...      Mike Carrier
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 4.99, 'rank...     Patrick Frost
# 390  [{'category': 'singles', 'rating': 5.43, 'rank...      Duncan Genge
# 391  [{'category': 'singles', 'rating': 4.52, 'rank...   Thomas Charlton
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Robert Bulger
# 393  [{'category': 'singles', 'rating': 4.78, 'rank...      Deepak Hayer
#
#     player_b2_gender player_b2_age  \
# 0                men           35+
# 1                men           35+
# 2                men           35+
# 3                men           35+
# 4                men           35+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           65+
# 392              men           75+
# 393              men           25+
#
#                                      player_b2_ratings    player_b2_name
# 0    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 1    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 2    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 3    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 4    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.76, 'rank...  Farzin Habibpour
# 390  [{'category': 'singles', 'rating': 4.64, 'rank...       Cole Parmar
# 391  [{'category': 'doubles', 'rating': 2.93, 'rank...    Warren Woodman
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Victor Tanaka
# 393  [{'category': 'singles', 'rating': 5.37, 'rank...        Jason Daou
#
# [394 rows x 20 columns]

# %%
merged_df["date"] = pd.to_datetime(merged_df["date"])

# %% [markdown]
# #### Basic stats

# %%
# Date spread
print(merged_df["date"].min(), merged_df["date"].max())
# Out:
# 2021-10-27 00:00:00 2023-11-19 00:00:00

# %%
# Counts of tournaments and league matches
for type_ in merged_df["type"].unique():
    print("{type_} : {count}".format(type_=type_, count=len(merged_df[merged_df["type"]==type_])))
# Out:
# League : 106
# Tournament : 288

# %%
merged_df
# Out:
#                                             event_name        type       date  \
# 0                                        Random League      League 2023-07-20
# 1           Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 2           Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-24
# 3    2023 Western Canadian Doubles Squash Champions...  Tournament 2023-11-16
# 4    2023 Western Canadian Doubles Squash Champions...  Tournament 2023-11-16
# ..                                                 ...         ...        ...
# 389         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 390         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 391      Western Canadian Doubles Squash Championships  Tournament 2022-11-23
# 392         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-23
# 393  Hillside Wealth Management 2023 BC Doubles Cha...  Tournament 2023-03-08
#
#                             scores player_a1_gender player_a1_age  \
# 0                 9-15, 9-15, 9-15            women           30+
# 1                   15-6,15-6,15-9              men           60+
# 2                  15-11,15-8,15-8            women           60+
# 3           15-12,15-13,14-15,15-5              men           50+
# 4           15-12,15-13,14-15,15-5              men           50+
# ..                             ...              ...           ...
# 389  15-12,12-15,14-15,15-14,15-10              men           25+
# 390                15-9,15-7,15-10              men           45+
# 391                15-8,15-5,15-12              men           45+
# 392    15-8,10-15,10-15,15-12,15-9              men           40+
# 393                15-9,15-14,15-8              men           45+
#
#                                      player_a1_ratings  \
# 0    [{'category': 'singles', 'rating': 3.51, 'rank...
# 1    [{'category': 'doubles', 'rating': 3.96, 'rank...
# 2    [{'category': 'singles', 'rating': 3.68, 'rank...
# 3    [{'category': 'singles', 'rating': 4.75, 'rank...
# 4    [{'category': 'singles', 'rating': 4.75, 'rank...
# ..                                                 ...
# 389  [{'category': 'singles', 'rating': 6.57, 'rank...
# 390  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 391  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 392  [{'category': 'singles', 'rating': 3.78, 'rank...
# 393  [{'category': 'doubles', 'rating': 4.89, 'rank...
#
#              player_a1_name player_a2_gender player_a2_age  \
# 0                 Zhelin Bu              men           65+
# 1            Dennis Forsman            women           65+
# 2          Annette Johanson              men           65+
# 3                Mark Levey              men           50+
# 4                Mark Levey              men           50+
# ..                      ...              ...           ...
# 389  Guillermo Cortes-Ortiz              men           25+
# 390                Mike Lee              men           55+
# 391                Mike Lee              men           55+
# 392          Roman Razenkov              men           40+
# 393              Gary Evans              men           40+
#
#                                      player_a2_ratings    player_a2_name  \
# 0    [{'category': 'doubles', 'rating': 1.98, 'rank...        Ernie Chan
# 1    [{'category': 'doubles', 'rating': 2.01, 'rank...  Pamela Brunswick
# 2    [{'category': 'doubles', 'rating': 2.3, 'ranki...    Richard Dustan
# 3    [{'category': 'singles', 'rating': 4.89, 'rank...        Jongho Kim
# 4    [{'category': 'singles', 'rating': 4.89, 'rank...        Jongho Kim
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.76, 'rank...    Eduardo Flores
# 390  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 391  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 392  [{'category': 'singles', 'rating': 3.39, 'rank...     Andrew Lavrov
# 393  [{'category': 'doubles', 'rating': 1.75, 'rank...      Jon De Souza
#
#     player_b1_gender player_b1_age  \
# 0                men           60+
# 1              women           60+
# 2              women           60+
# 3                men           55+
# 4                men           55+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           30+
# 392              men           65+
# 393              men           40+
#
#                                      player_b1_ratings    player_b1_name  \
# 0    [{'category': 'doubles', 'rating': 3.09, 'rank...      Ian Binstead
# 1    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 2    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 3    [{'category': 'singles', 'rating': 4.9, 'ranki...      Mike Carrier
# 4    [{'category': 'singles', 'rating': 4.9, 'ranki...      Mike Carrier
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 4.99, 'rank...     Patrick Frost
# 390  [{'category': 'singles', 'rating': 5.43, 'rank...      Duncan Genge
# 391  [{'category': 'singles', 'rating': 4.52, 'rank...   Thomas Charlton
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Robert Bulger
# 393  [{'category': 'singles', 'rating': 4.78, 'rank...      Deepak Hayer
#
#     player_b2_gender player_b2_age  \
# 0                men           35+
# 1                men           35+
# 2                men           35+
# 3                men           35+
# 4                men           35+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           65+
# 392              men           75+
# 393              men           25+
#
#                                      player_b2_ratings    player_b2_name
# 0    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 1    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 2    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 3    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 4    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.76, 'rank...  Farzin Habibpour
# 390  [{'category': 'singles', 'rating': 4.64, 'rank...       Cole Parmar
# 391  [{'category': 'doubles', 'rating': 2.93, 'rank...    Warren Woodman
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Victor Tanaka
# 393  [{'category': 'singles', 'rating': 5.37, 'rank...        Jason Daou
#
# [394 rows x 20 columns]

# %%
merged_df["scores"]
# Out:
# 0                   9-15, 9-15, 9-15
# 1                     15-6,15-6,15-9
# 2                    15-11,15-8,15-8
# 3             15-12,15-13,14-15,15-5
# 4             15-12,15-13,14-15,15-5
#                    ...
# 389    15-12,12-15,14-15,15-14,15-10
# 390                  15-9,15-7,15-10
# 391                  15-8,15-5,15-12
# 392      15-8,10-15,10-15,15-12,15-9
# 393                  15-9,15-14,15-8
# Name: scores, Length: 394, dtype: object

# %%
# Convert into array of scores
def convert_to_score_array(val):
    # Split by space and append to array
    arr = []
    if type(val) == str:
        for score in val.split(", "):
            arr.append(score)
    elif type(val) == datetime.datetime:
        arr.append(val)
    return arr

# %%
# def convert_to_game_score(values):
#     temp = []
#     for val in values:
#         if type(val) == datetime:
#             val = pd.Timestamp(val)
#             # Extract month and date
#             month = val.month
#             day = val.day
#             temp.append((int(month), int(day)))
#         elif type(val) == str:
#             a, b = val.split("-")
#             temp.append((int(a), int(b)))
            
#     return temp

# %%
merged_df["scores"] = merged_df["scores"].apply(convert_to_score_array)

# %%
def convert_to_game_score(scores):
    if len(scores) == 1: # 1 major string
        scores = scores[0]
        scores_arr = []
        if len(scores) != 0: # Empty string
            scores = scores.split(",") # scores array
            for score in scores:
                score_a, score_b = score.split("-")
                score_tuple = (int(score_a), int(score_b))
                scores_arr.append(score_tuple)
        return scores_arr
    else:
        scores_arr = []
        for score in scores:
            score_a, score_b = score.split("-")
            score_tuple = (int(score_a), int(score_b))
            scores_arr.append(score_tuple)
        return scores_arr

# %%
merged_df["scores"] = merged_df["scores"].apply(convert_to_game_score)

# %%
merged_df
# Out:
#                                             event_name        type       date  \
# 0                                        Random League      League 2023-07-20
# 1           Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 2           Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-24
# 3    2023 Western Canadian Doubles Squash Champions...  Tournament 2023-11-16
# 4    2023 Western Canadian Doubles Squash Champions...  Tournament 2023-11-16
# ..                                                 ...         ...        ...
# 389         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 390         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 391      Western Canadian Doubles Squash Championships  Tournament 2022-11-23
# 392         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-23
# 393  Hillside Wealth Management 2023 BC Doubles Cha...  Tournament 2023-03-08
#
#                                                 scores player_a1_gender  \
# 0                          [(9, 15), (9, 15), (9, 15)]            women
# 1                          [(15, 6), (15, 6), (15, 9)]              men
# 2                         [(15, 11), (15, 8), (15, 8)]            women
# 3              [(15, 12), (15, 13), (14, 15), (15, 5)]              men
# 4              [(15, 12), (15, 13), (14, 15), (15, 5)]              men
# ..                                                 ...              ...
# 389  [(15, 12), (12, 15), (14, 15), (15, 14), (15, ...              men
# 390                       [(15, 9), (15, 7), (15, 10)]              men
# 391                       [(15, 8), (15, 5), (15, 12)]              men
# 392   [(15, 8), (10, 15), (10, 15), (15, 12), (15, 9)]              men
# 393                       [(15, 9), (15, 14), (15, 8)]              men
#
#     player_a1_age                                  player_a1_ratings  \
# 0             30+  [{'category': 'singles', 'rating': 3.51, 'rank...
# 1             60+  [{'category': 'doubles', 'rating': 3.96, 'rank...
# 2             60+  [{'category': 'singles', 'rating': 3.68, 'rank...
# 3             50+  [{'category': 'singles', 'rating': 4.75, 'rank...
# 4             50+  [{'category': 'singles', 'rating': 4.75, 'rank...
# ..            ...                                                ...
# 389           25+  [{'category': 'singles', 'rating': 6.57, 'rank...
# 390           45+  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 391           45+  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 392           40+  [{'category': 'singles', 'rating': 3.78, 'rank...
# 393           45+  [{'category': 'doubles', 'rating': 4.89, 'rank...
#
#              player_a1_name player_a2_gender player_a2_age  \
# 0                 Zhelin Bu              men           65+
# 1            Dennis Forsman            women           65+
# 2          Annette Johanson              men           65+
# 3                Mark Levey              men           50+
# 4                Mark Levey              men           50+
# ..                      ...              ...           ...
# 389  Guillermo Cortes-Ortiz              men           25+
# 390                Mike Lee              men           55+
# 391                Mike Lee              men           55+
# 392          Roman Razenkov              men           40+
# 393              Gary Evans              men           40+
#
#                                      player_a2_ratings    player_a2_name  \
# 0    [{'category': 'doubles', 'rating': 1.98, 'rank...        Ernie Chan
# 1    [{'category': 'doubles', 'rating': 2.01, 'rank...  Pamela Brunswick
# 2    [{'category': 'doubles', 'rating': 2.3, 'ranki...    Richard Dustan
# 3    [{'category': 'singles', 'rating': 4.89, 'rank...        Jongho Kim
# 4    [{'category': 'singles', 'rating': 4.89, 'rank...        Jongho Kim
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.76, 'rank...    Eduardo Flores
# 390  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 391  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 392  [{'category': 'singles', 'rating': 3.39, 'rank...     Andrew Lavrov
# 393  [{'category': 'doubles', 'rating': 1.75, 'rank...      Jon De Souza
#
#     player_b1_gender player_b1_age  \
# 0                men           60+
# 1              women           60+
# 2              women           60+
# 3                men           55+
# 4                men           55+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           30+
# 392              men           65+
# 393              men           40+
#
#                                      player_b1_ratings    player_b1_name  \
# 0    [{'category': 'doubles', 'rating': 3.09, 'rank...      Ian Binstead
# 1    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 2    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 3    [{'category': 'singles', 'rating': 4.9, 'ranki...      Mike Carrier
# 4    [{'category': 'singles', 'rating': 4.9, 'ranki...      Mike Carrier
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 4.99, 'rank...     Patrick Frost
# 390  [{'category': 'singles', 'rating': 5.43, 'rank...      Duncan Genge
# 391  [{'category': 'singles', 'rating': 4.52, 'rank...   Thomas Charlton
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Robert Bulger
# 393  [{'category': 'singles', 'rating': 4.78, 'rank...      Deepak Hayer
#
#     player_b2_gender player_b2_age  \
# 0                men           35+
# 1                men           35+
# 2                men           35+
# 3                men           35+
# 4                men           35+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           65+
# 392              men           75+
# 393              men           25+
#
#                                      player_b2_ratings    player_b2_name
# 0    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 1    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 2    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 3    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# 4    [{'category': 'singles', 'rating': 4.18, 'rank...          Lam Uong
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.76, 'rank...  Farzin Habibpour
# 390  [{'category': 'singles', 'rating': 4.64, 'rank...       Cole Parmar
# 391  [{'category': 'doubles', 'rating': 2.93, 'rank...    Warren Woodman
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Victor Tanaka
# 393  [{'category': 'singles', 'rating': 5.37, 'rank...        Jason Daou
#
# [394 rows x 20 columns]
