# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
import requests
from pymongo.mongo_client import MongoClient

# %%
CONNECTION_URI = "mongodb+srv://fayadchowdhury:733squashBC@squashbc.ss6kkda.mongodb.net/?retryWrites=true&w=majority&appName=squashbc"

# %%
client = MongoClient(CONNECTION_URI)

# %%
# This works. Nice!
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print("Error: " + str(e))
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ### Get players aggregated data

# %%
players_collection = client["squashbc"]["players_aggregated"]

# %%
players = players_collection.find()

# %%
players_list = list(players)

# %%
players_list
# Out:
# [{'_id': 397930,
#   'fname': 'Daniel',
#   'lname': 'Maczko',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.52, 'ranking': 50}]},
#  {'_id': 298206,
#   'fname': 'Shelley',
#   'lname': 'Neil',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.31, 'ranking': 10},
#    {'category': 'doubles', 'rating': 4.07, 'ranking': 4}]},
#  {'_id': 399360,
#   'fname': 'Julie',
#   'lname': 'Cornett-Ching',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.48, 'ranking': 7}]},
#  {'_id': 242692,
#   'fname': 'Tony',
#   'lname': 'Quan',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 19}]},
#  {'_id': 437976,
#   'fname': 'Andrew',
#   'lname': 'Sage',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.41, 'ranking': 112}]},
#  {'_id': 206027,
#   'fname': 'Abhinav',
#   'lname': 'Deswal',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.23, 'ranking': 14}]},
#  {'_id': 276865,
#   'fname': 'Joseph',
#   'lname': 'Weinerman',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.76, 'ranking': 11}]},
#  {'_id': 433792,
#   'fname': 'Maxwell',
#   'lname': 'Webster',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.79, 'ranking': 87}]},
#  {'_id': 299111,
#   'fname': 'Atlee',
#   'lname': 'James',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.8, 'ranking': 27}]},
#  {'_id': 430483,
#   'fname': 'Blain',
#   'lname': 'Weber',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.45, 'ranking': 52}]},
#  {'_id': 310508,
#   'fname': 'Sebastian',
#   'lname': 'Motora',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.12, 'ranking': 72}]},
#  {'_id': 298171,
#   'fname': 'Ryan',
#   'lname': 'Martin',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.49, 'ranking': 43}]},
#  {'_id': 397343,
#   'fname': 'Mikhail',
#   'lname': 'Din',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.15, 'ranking': 70},
#    {'category': 'doubles', 'rating': 4.11, 'ranking': 11}]},
#  {'_id': 297995,
#   'fname': 'tom',
#   'lname': 'urban',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.28, 'ranking': 29}]},
#  {'_id': 297747,
#   'fname': 'Keith',
#   'lname': 'Bootle',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.82, 'ranking': 35}]},
#  {'_id': 273335,
#   'fname': 'Huw',
#   'lname': 'Saunders',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.68, 'ranking': 106}]},
#  {'_id': 299095,
#   'fname': 'Hart',
#   'lname': 'Massey',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.74, 'ranking': 30}]},
#  {'_id': 417740,
#   'fname': 'Thomas',
#   'lname': 'Charlton',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.51, 'ranking': 50},
#    {'category': 'doubles', 'rating': 1.81, 'ranking': 16}]},
#  {'_id': 298114,
#   'fname': 'Marc',
#   'lname': 'Jubinville',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.56, 'ranking': 49}]},
#  {'_id': 273665,
#   'fname': 'Greg',
#   'lname': 'Longster',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.69, 'ranking': 26}]},
#  {'_id': 386210,
#   'fname': 'Eric',
#   'lname': 'Gambini',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.09, 'ranking': 61}]},
#  {'_id': 322949,
#   'fname': 'Karen',
#   'lname': 'Stierhoff',
#   'gender': 'women',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 3.05, 'ranking': 3}]},
#  {'_id': 471986,
#   'fname': 'Julienne',
#   'lname': 'Joe',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'doubles', 'rating': 2.19, 'ranking': 5}]},
#  {'_id': 404232,
#   'fname': 'Aaron',
#   'lname': 'Volpatti',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.76, 'ranking': 38}]},
#  {'_id': 401867,
#   'fname': 'Guillermo',
#   'lname': 'Cortes-Ortiz',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 6.53, 'ranking': 1}]},
#  {'_id': 471686,
#   'fname': 'William',
#   'lname': 'Emm',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.08, 'ranking': 104}]},
#  {'_id': 385831,
#   'fname': 'Tom',
#   'lname': 'Dukeson',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.82, 'ranking': 85}]},
#  {'_id': 1000000124,
#   'fname': 'Douglas',
#   'lname': 'Hardie',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 5.34, 'ranking': 1}]},
#  {'_id': 467345,
#   'fname': 'Nikita',
#   'lname': 'Kitagawa',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.14, 'ranking': 23}]},
#  {'_id': 478277,
#   'fname': 'Meghan',
#   'lname': 'Hassall',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 2.88, 'ranking': 22}]},
#  {'_id': 246686,
#   'fname': 'Kate',
#   'lname': 'Keetch',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.16, 'ranking': 7}]},
#  {'_id': 462962,
#   'fname': 'Katie',
#   'lname': 'Meredith',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 1.65, 'ranking': 36}]},
#  {'_id': 477699,
#   'fname': 'Marlene',
#   'lname': 'Ma',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 2.28, 'ranking': 22}]},
#  {'_id': 273389,
#   'fname': 'Will',
#   'lname': 'Stiphout',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 3.76, 'ranking': 2}]},
#  {'_id': 43379,
#   'fname': 'Leanne',
#   'lname': 'Averbach',
#   'gender': 'women',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 2.01, 'ranking': 3}]},
#  {'_id': 413014,
#   'fname': 'Wolfgang',
#   'lname': 'Anton',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 4.28, 'ranking': 12}]},
#  {'_id': 242169,
#   'fname': 'Niki',
#   'lname': 'Boyd',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.02, 'ranking': 11}]},
#  {'_id': 271847,
#   'fname': 'Bruce',
#   'lname': 'Macfarlane',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 2.41, 'ranking': 15}]},
#  {'_id': 415765,
#   'fname': 'Philip',
#   'lname': 'Barton',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.71, 'ranking': 75}]},
#  {'_id': 264804,
#   'fname': 'Richard',
#   'lname': 'Hatfield',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.93, 'ranking': 4}]},
#  {'_id': 418032,
#   'fname': 'Patrick',
#   'lname': 'McDonough',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.99, 'ranking': 5}]},
#  {'_id': 438461,
#   'fname': 'Stephen',
#   'lname': 'Shevoley',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.3, 'ranking': 22}]},
#  {'_id': 413638,
#   'fname': 'Alisha',
#   'lname': 'Rahemtulla',
#   'gender': 'women',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.94, 'ranking': 8}]},
#  {'_id': 418274,
#   'fname': 'Erik',
#   'lname': 'Zaremba',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.93, 'ranking': 1}]},
#  {'_id': 71809,
#   'fname': 'Gordon',
#   'lname': 'Pybus',
#   'gender': 'men',
#   'age': '75+',
#   'ratings': [{'category': 'doubles', 'rating': 4.09, 'ranking': 2}]},
#  {'_id': 385584,
#   'fname': 'Jonathan',
#   'lname': 'Reimer',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.36, 'ranking': 94}]},
#  {'_id': 250191,
#   'fname': 'Alex',
#   'lname': 'Brown',
#   'gender': 'women',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.22, 'ranking': 2}]},
#  {'_id': 462963,
#   'fname': 'Danita',
#   'lname': 'Lichti',
#   'gender': 'women',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 2.94, 'ranking': 15}]},
#  {'_id': 462199,
#   'fname': 'Brett',
#   'lname': 'Creed',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.69, 'ranking': 87}]},
#  {'_id': 384897,
#   'fname': 'Scott',
#   'lname': 'Martyna',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.95, 'ranking': 88}]},
#  {'_id': 417682,
#   'fname': 'Jason',
#   'lname': 'Lotoski',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.86, 'ranking': 82}]},
#  {'_id': 310632,
#   'fname': 'Sayeed',
#   'lname': 'Mavani',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.65, 'ranking': 12}]},
#  {'_id': 271744,
#   'fname': 'Steve',
#   'lname': 'Hawyes',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 5.02, 'ranking': 2}]},
#  {'_id': 316311,
#   'fname': 'Heinz',
#   'lname': 'Winterscheidt',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.49, 'ranking': 11}]},
#  {'_id': 274171,
#   'fname': 'Leland',
#   'lname': 'Spettigue',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.77, 'ranking': 32}]},
#  {'_id': 439449,
#   'fname': 'Reagan',
#   'lname': 'Glazier',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.04, 'ranking': 22}]},
#  {'_id': 251614,
#   'fname': 'Glen',
#   'lname': 'Goodvin',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.81, 'ranking': 28}]},
#  {'_id': 417572,
#   'fname': 'Philip',
#   'lname': 'Warner',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.39, 'ranking': 61}]},
#  {'_id': 165314,
#   'fname': 'Simon',
#   'lname': 'Min',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.47, 'ranking': 14}]},
#  {'_id': 385385,
#   'fname': 'Mike',
#   'lname': 'Grummett',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.08, 'ranking': 19}]},
#  {'_id': 377273,
#   'fname': 'Rebecca',
#   'lname': 'Vassilakakis',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.87, 'ranking': 1}]},
#  {'_id': 453573,
#   'fname': 'Kurt',
#   'lname': 'Lindemark',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.07, 'ranking': 12},
#    {'category': 'doubles', 'rating': 3.37, 'ranking': 14}]},
#  {'_id': 247125,
#   'fname': 'Phil',
#   'lname': 'Croteau',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.41, 'ranking': 16}]},
#  {'_id': 247120,
#   'fname': 'Trevor',
#   'lname': 'Cox',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.76, 'ranking': 23}]},
#  {'_id': 418376,
#   'fname': 'Aidan',
#   'lname': 'Verster',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.27, 'ranking': 59}]},
#  {'_id': 387871,
#   'fname': 'Colin',
#   'lname': 'Latchford',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3, 'ranking': 110}]},
#  {'_id': 299024,
#   'fname': 'Peter',
#   'lname': 'Hoh',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.23, 'ranking': 53}]},
#  {'_id': 466484,
#   'fname': 'Heather',
#   'lname': 'Brunstad',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 2.12, 'ranking': 24}]},
#  {'_id': 298574,
#   'fname': 'Ryan',
#   'lname': 'Darby',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.01, 'ranking': 66}]},
#  {'_id': 298726,
#   'fname': 'Mathew',
#   'lname': 'Stalberg',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.59, 'ranking': 45}]},
#  {'_id': 310467,
#   'fname': 'Norman',
#   'lname': 'Wegerhoff',
#   'gender': 'men',
#   'age': '75+',
#   'ratings': [{'category': 'singles', 'rating': 3.32, 'ranking': 7}]},
#  {'_id': 310459,
#   'fname': 'Kylie',
#   'lname': 'Neiser',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.09, 'ranking': 8}]},
#  {'_id': 298795,
#   'fname': 'Emily',
#   'lname': 'Christian',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 2.86, 'ranking': 23}]},
#  {'_id': 242297,
#   'fname': 'Cindy',
#   'lname': 'Goundrey',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.09, 'ranking': 12}]},
#  {'_id': 246905,
#   'fname': 'Monica',
#   'lname': 'Szpak',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'doubles', 'rating': 2.15, 'ranking': 6}]},
#  {'_id': 297700,
#   'fname': 'Fernando',
#   'lname': 'Ruiz',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.24, 'ranking': 58}]},
#  {'_id': 303623,
#   'fname': 'Janelle',
#   'lname': "O'Connor",
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 2.75, 'ranking': 12}]},
#  {'_id': 247374,
#   'fname': 'Christian',
#   'lname': 'Yuen',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 6.07, 'ranking': 6}]},
#  {'_id': 436159,
#   'fname': 'Hannah',
#   'lname': 'Phelps',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.72, 'ranking': 27}]},
#  {'_id': 385684,
#   'fname': 'Graham',
#   'lname': 'Watson',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.24, 'ranking': 24}]},
#  {'_id': 399773,
#   'fname': 'Sukhi S.',
#   'lname': 'Hundal',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 14}]},
#  {'_id': 234271,
#   'fname': 'Riley',
#   'lname': 'Trottier',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.83, 'ranking': 29}]},
#  {'_id': 386475,
#   'fname': 'Andrew',
#   'lname': 'Kostiw',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.92, 'ranking': 53}]},
#  {'_id': 324707,
#   'fname': 'Nicola',
#   'lname': 'Martin',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.2, 'ranking': 3},
#    {'category': 'doubles', 'rating': 1.5, 'ranking': 7}]},
#  {'_id': 298544,
#   'fname': 'Rob',
#   'lname': 'Macdonald',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.51, 'ranking': 41}]},
#  {'_id': 431029,
#   'fname': 'Tom',
#   'lname': 'Wojciechowski',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.14, 'ranking': 73}]},
#  {'_id': 400088,
#   'fname': 'Jonathan',
#   'lname': 'Roberts',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'doubles', 'rating': 1.55, 'ranking': 9}]},
#  {'_id': 431418,
#   'fname': 'Kelly Ann',
#   'lname': 'Zander',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.76, 'ranking': 4},
#    {'category': 'doubles', 'rating': 1.9, 'ranking': 7}]},
#  {'_id': 297913,
#   'fname': 'Michelle R',
#   'lname': 'Lindsay',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.26, 'ranking': 2}]},
#  {'_id': 398924,
#   'fname': 'Ahmad',
#   'lname': 'Doroudian',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.85, 'ranking': 43}]},
#  {'_id': 217592,
#   'fname': 'Joe',
#   'lname': 'Lopes',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 3.59, 'ranking': 10}]},
#  {'_id': 298651,
#   'fname': 'Jak',
#   'lname': 'Meyer',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 4.27, 'ranking': 13}]},
#  {'_id': 299121,
#   'fname': 'Barbara',
#   'lname': 'Brebner',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 13}]},
#  {'_id': 437578,
#   'fname': 'David',
#   'lname': 'Adams',
#   'gender': 'men',
#   'age': '80+',
#   'ratings': [{'category': 'doubles', 'rating': 1.62, 'ranking': 2}]},
#  {'_id': 259792,
#   'fname': 'Inderjit',
#   'lname': 'Singh',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.25, 'ranking': 22}]},
#  {'_id': 235143,
#   'fname': 'Tianxia',
#   'lname': 'Yang',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.62, 'ranking': 14}]},
#  {'_id': 297589,
#   'fname': 'Simon',
#   'lname': 'Liddell',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.66, 'ranking': 30}]},
#  {'_id': 441963,
#   'fname': 'Nick',
#   'lname': 'Baer',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.18, 'ranking': 67}]},
#  {'_id': 478414,
#   'fname': 'Spencer',
#   'lname': 'Burnie',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.11, 'ranking': 47}]},
#  {'_id': 298489,
#   'fname': 'Rami',
#   'lname': 'Singh',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.38, 'ranking': 45}]},
#  {'_id': 436171,
#   'fname': 'James',
#   'lname': 'Rhodes',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.73, 'ranking': 38}]},
#  {'_id': 400572,
#   'fname': 'Matt',
#   'lname': 'Harper',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.08, 'ranking': 67}]},
#  {'_id': 298315,
#   'fname': 'Faisal',
#   'lname': 'Vallani',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.09, 'ranking': 117}]},
#  {'_id': 405450,
#   'fname': 'Kasha',
#   'lname': 'Mysliwiec',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 1.98, 'ranking': 31}]},
#  {'_id': 397422,
#   'fname': 'Ryan',
#   'lname': 'Haider',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'doubles', 'rating': 3.41, 'ranking': 12}]},
#  {'_id': 298778,
#   'fname': 'Rick',
#   'lname': 'Palmer',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.47, 'ranking': 60}]},
#  {'_id': 246736,
#   'fname': 'Sarah',
#   'lname': 'MacKinnon',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.13, 'ranking': 8}]},
#  {'_id': 438002,
#   'fname': 'Brett',
#   'lname': 'Miller',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 5.16, 'ranking': 19}]},
#  {'_id': 298671,
#   'fname': 'Brett',
#   'lname': 'Martyna',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.71, 'ranking': 39}]},
#  {'_id': 402019,
#   'fname': 'Blaise',
#   'lname': 'Sack',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.5, 'ranking': 51}]},
#  {'_id': 398008,
#   'fname': 'Derek',
#   'lname': 'Smith',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 3.29, 'ranking': 12}]},
#  {'_id': 216853,
#   'fname': 'Laura',
#   'lname': 'Ramsay',
#   'gender': 'women',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 2.91, 'ranking': 2}]},
#  {'_id': 298488,
#   'fname': 'Tyler',
#   'lname': 'Pollock',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.01, 'ranking': 23}]},
#  {'_id': 415000,
#   'fname': 'Jose',
#   'lname': 'Carrillo',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.92, 'ranking': 39}]},
#  {'_id': 298922,
#   'fname': 'Jeff',
#   'lname': 'Evans',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.34, 'ranking': 5}]},
#  {'_id': 257610,
#   'fname': 'David',
#   'lname': 'Chow',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.14, 'ranking': 37}]},
#  {'_id': 397553,
#   'fname': 'Greg',
#   'lname': 'Almas',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 3.5, 'ranking': 5}]},
#  {'_id': 265737,
#   'fname': 'Dave',
#   'lname': 'Glass',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 6.39, 'ranking': 1}]},
#  {'_id': 469252,
#   'fname': 'Isaac',
#   'lname': 'Williams',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 3.94, 'ranking': 54}]},
#  {'_id': 435112,
#   'fname': 'Remy',
#   'lname': 'St. Cyr',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.16, 'ranking': 68}]},
#  {'_id': 379629,
#   'fname': 'Josh',
#   'lname': 'Heuving',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.6, 'ranking': 113}]},
#  {'_id': 320229,
#   'fname': 'Karen',
#   'lname': 'Hawyes',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.01, 'ranking': 2}]},
#  {'_id': 299165,
#   'fname': 'Trina',
#   'lname': 'Zanni',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.55, 'ranking': 5}]},
#  {'_id': 398455,
#   'fname': 'Maren',
#   'lname': 'Oetling',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 2.44, 'ranking': 17}]},
#  {'_id': 446119,
#   'fname': 'Josh',
#   'lname': 'Kirby',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.01, 'ranking': 83}]},
#  {'_id': 399713,
#   'fname': 'Campbell',
#   'lname': 'Maxwell',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.03, 'ranking': 32}]},
#  {'_id': 382735,
#   'fname': 'Luke',
#   'lname': 'Vaggers',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 6.12, 'ranking': 3},
#    {'category': 'doubles', 'rating': 4.9, 'ranking': 3}]},
#  {'_id': 405189,
#   'fname': 'Mike',
#   'lname': 'McKee',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.49, 'ranking': 81}]},
#  {'_id': 418357,
#   'fname': 'Brian',
#   'lname': 'McGaw',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.88, 'ranking': 6}]},
#  {'_id': 242845,
#   'fname': 'Rob',
#   'lname': 'Spanier',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 3.54, 'ranking': 21}]},
#  {'_id': 418468,
#   'fname': 'Alex',
#   'lname': 'Crowther',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.7, 'ranking': 28}]},
#  {'_id': 461843,
#   'fname': 'Gavin',
#   'lname': 'Servai',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.26, 'ranking': 107}]},
#  {'_id': 246889,
#   'fname': 'Nancy',
#   'lname': 'Sly',
#   'gender': 'women',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 3.03, 'ranking': 4}]},
#  {'_id': 298867,
#   'fname': 'Mike',
#   'lname': 'Worsley',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.03, 'ranking': 28}]},
#  {'_id': 386313,
#   'fname': 'Chris',
#   'lname': 'Morrow',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.35, 'ranking': 57}]},
#  {'_id': 297814,
#   'fname': 'Andrew',
#   'lname': 'Ransom',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.9, 'ranking': 16}]},
#  {'_id': 400288,
#   'fname': 'Garo',
#   'lname': 'Deyrmenjian',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.23, 'ranking': 32}]},
#  {'_id': 316276,
#   'fname': 'Peter',
#   'lname': 'Russell',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.04, 'ranking': 15}]},
#  {'_id': 436701,
#   'fname': 'Katie',
#   'lname': 'Birchard',
#   'gender': 'women',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 2.8, 'ranking': 16}]},
#  {'_id': 450650,
#   'fname': 'Van-Gerald',
#   'lname': 'Olivares Herrara',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.64, 'ranking': 40}]},
#  {'_id': 409209,
#   'fname': 'Myles',
#   'lname': 'Brown',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.36, 'ranking': 57}]},
#  {'_id': 247259,
#   'fname': 'Chad',
#   'lname': 'Forbes',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'doubles', 'rating': 3.56, 'ranking': 8}]},
#  {'_id': 386389,
#   'fname': 'Peter',
#   'lname': 'OLoughlin',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 2.61, 'ranking': 13}]},
#  {'_id': 429667,
#   'fname': 'Gordon',
#   'lname': 'Ritson',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.27, 'ranking': 61}]},
#  {'_id': 242763,
#   'fname': 'Ray',
#   'lname': 'Salama',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.33, 'ranking': 64}]},
#  {'_id': 404912,
#   'fname': 'Kurt',
#   'lname': 'Woodman',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5, 'ranking': 24}]},
#  {'_id': 251638,
#   'fname': 'Tim',
#   'lname': 'Gudewill',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.77, 'ranking': 30}]},
#  {'_id': 402994,
#   'fname': 'Martijn',
#   'lname': 'van Atten',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.54, 'ranking': 36}]},
#  {'_id': 298675,
#   'fname': 'Alan',
#   'lname': 'Uniat',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.32, 'ranking': 20}]},
#  {'_id': 247355,
#   'fname': 'Hugh',
#   'lname': 'Woolley',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 2.17, 'ranking': 15}]},
#  {'_id': 466681,
#   'fname': 'Alexandra',
#   'lname': 'Capello',
#   'gender': 'women',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 2.22, 'ranking': 18}]},
#  {'_id': 464883,
#   'fname': 'Cindy',
#   'lname': 'Lee',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 2.96, 'ranking': 13}]},
#  {'_id': 216092,
#   'fname': 'Brian',
#   'lname': 'Covernton',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 4.37, 'ranking': 1}]},
#  {'_id': 246891,
#   'fname': 'Deidre',
#   'lname': 'Smith',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 12}]},
#  {'_id': 398779,
#   'fname': 'Sianoosh',
#   'lname': 'Nasiriziba',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.42, 'ranking': 52}]},
#  {'_id': 298973,
#   'fname': 'Fabio',
#   'lname': 'Markman',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.59, 'ranking': 58}]},
#  {'_id': 388400,
#   'fname': 'Adam',
#   'lname': 'Min',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.08, 'ranking': 21}]},
#  {'_id': 443751,
#   'fname': 'Bryson',
#   'lname': 'Norrish',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 2.9, 'ranking': 118}]},
#  {'_id': 94973,
#   'fname': 'Richard',
#   'lname': 'Freeman',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.49, 'ranking': 53},
#    {'category': 'doubles', 'rating': 2.69, 'ranking': 11}]},
#  {'_id': 297594,
#   'fname': 'Mike',
#   'lname': 'Amantea',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.19, 'ranking': 34}]},
#  {'_id': 71511,
#   'fname': 'Mark',
#   'lname': 'Heaney',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'doubles', 'rating': 4.24, 'ranking': 2}]},
#  {'_id': 273298,
#   'fname': 'Gabriella',
#   'lname': 'Draboczi',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.06, 'ranking': 12}]},
#  {'_id': 298902,
#   'fname': 'Gerald',
#   'lname': 'Watson',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.14, 'ranking': 36}]},
#  {'_id': 466648,
#   'fname': 'Cateline',
#   'lname': 'Gomez',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 2.34, 'ranking': 19}]},
#  {'_id': 417621,
#   'fname': 'Anthony',
#   'lname': 'Kokin',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.34, 'ranking': 115}]},
#  {'_id': 254814,
#   'fname': 'Dave',
#   'lname': 'Watson',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.75, 'ranking': 9},
#    {'category': 'doubles', 'rating': 2.08, 'ranking': 16}]},
#  {'_id': 234346,
#   'fname': 'Joel',
#   'lname': 'Vosburg',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.77, 'ranking': 33}]},
#  {'_id': 247019,
#   'fname': 'Benno',
#   'lname': 'Bucher',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 3.41, 'ranking': 16}]},
#  {'_id': 242596,
#   'fname': 'Ara',
#   'lname': 'Ashikian',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.25, 'ranking': 31}]},
#  {'_id': 414543,
#   'fname': 'Kuong, Bosco',
#   'lname': 'Ao leong',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.38, 'ranking': 14}]},
#  {'_id': 386213,
#   'fname': 'Wayne',
#   'lname': 'Maunder',
#   'gender': 'men',
#   'age': '85+',
#   'ratings': [{'category': 'doubles', 'rating': 3.42, 'ranking': 1}]},
#  {'_id': 310670,
#   'fname': 'Cole',
#   'lname': 'Parmar',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 4.62, 'ranking': 34}]},
#  {'_id': 444955,
#   'fname': 'Roman',
#   'lname': 'Razenkov',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.78, 'ranking': 82}]},
#  {'_id': 297669,
#   'fname': 'John-Mark',
#   'lname': 'Ferguson',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.58, 'ranking': 46}]},
#  {'_id': 385660,
#   'fname': 'Cam',
#   'lname': 'Verrier',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.19, 'ranking': 67}]},
#  {'_id': 400350,
#   'fname': 'Jef',
#   'lname': 'Young',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.88, 'ranking': 22},
#    {'category': 'doubles', 'rating': 1.5, 'ranking': 20}]},
#  {'_id': 246945,
#   'fname': 'Ashley',
#   'lname': 'Walker',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'doubles', 'rating': 4.05, 'ranking': 1}]},
#  {'_id': 399778,
#   'fname': 'Tom',
#   'lname': 'Dobrzanski',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 2.98, 'ranking': 105}]},
#  {'_id': 247112,
#   'fname': 'Sean',
#   'lname': 'Copeland',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.37, 'ranking': 20}]},
#  {'_id': 255947,
#   'fname': 'Connor',
#   'lname': 'Lukas',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.39, 'ranking': 16}]},
#  {'_id': 466488,
#   'fname': 'Louis Philippe',
#   'lname': 'Leonard',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.26, 'ranking': 97}]},
#  {'_id': 476455,
#   'fname': 'Benjamin',
#   'lname': 'Davis-Purcell',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.59, 'ranking': 44}]},
#  {'_id': 298818,
#   'fname': 'Lindsay',
#   'lname': 'Seginson',
#   'gender': 'women',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.08, 'ranking': 4}]},
#  {'_id': 167417,
#   'fname': 'Sue',
#   'lname': 'Kaffka',
#   'gender': 'women',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 2.28, 'ranking': 3}]},
#  {'_id': 71931,
#   'fname': 'Tasha',
#   'lname': 'Doucas',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.76, 'ranking': 3},
#    {'category': 'doubles', 'rating': 2.22, 'ranking': 5}]},
#  {'_id': 452584,
#   'fname': 'Amy',
#   'lname': 'Willms',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 2.33, 'ranking': 20}]},
#  {'_id': 402432,
#   'fname': 'Kento',
#   'lname': 'Marui',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.64, 'ranking': 44}]},
#  {'_id': 298832,
#   'fname': 'Mark',
#   'lname': 'Feldthusen',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.32, 'ranking': 59}]},
#  {'_id': 442047,
#   'fname': 'Casey',
#   'lname': 'Hawley',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.19, 'ranking': 67}]},
#  {'_id': 386437,
#   'fname': 'jonathan',
#   'lname': 'katronis',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.97, 'ranking': 22}]},
#  {'_id': 242907,
#   'fname': 'Ben',
#   'lname': 'Thomas',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 5.39, 'ranking': 6}]},
#  {'_id': 322575,
#   'fname': 'Thomas',
#   'lname': 'Clark',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.74, 'ranking': 10}]},
#  {'_id': 397351,
#   'fname': 'Shawn',
#   'lname': 'Patton',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 3.28, 'ranking': 13}]},
#  {'_id': 242214,
#   'fname': 'Chris',
#   'lname': 'Buksa',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 2.91, 'ranking': 15}]},
#  {'_id': 299174,
#   'fname': 'Andrew',
#   'lname': 'Hall',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.11, 'ranking': 73}]},
#  {'_id': 418346,
#   'fname': 'Marc',
#   'lname': 'Kazimirski',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 5.48, 'ranking': 4}]},
#  {'_id': 251562,
#   'fname': 'Ron',
#   'lname': 'Fretwell',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 4.08, 'ranking': 16}]},
#  {'_id': 325174,
#   'fname': 'Kiran',
#   'lname': 'Sunar',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.08, 'ranking': 19}]},
#  {'_id': 400140,
#   'fname': 'Amir',
#   'lname': 'Mousavi',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 3.79, 'ranking': 56}]},
#  {'_id': 72557,
#   'fname': 'Matt',
#   'lname': 'Fahey',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 5.06, 'ranking': 3}]},
#  {'_id': 299077,
#   'fname': 'William',
#   'lname': 'Johnston',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.07, 'ranking': 13}]},
#  {'_id': 298958,
#   'fname': 'Nick',
#   'lname': 'Howald',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.16, 'ranking': 56}]},
#  {'_id': 242247,
#   'fname': 'Sophie',
#   'lname': 'Dorrius',
#   'gender': 'women',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.88, 'ranking': 9}]},
#  {'_id': 405131,
#   'fname': 'Rich',
#   'lname': 'Thompson',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.75, 'ranking': 39}]},
#  {'_id': 204714,
#   'fname': 'Jason',
#   'lname': 'Herring',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 6.01, 'ranking': 7}]},
#  {'_id': 299112,
#   'fname': 'Khaled',
#   'lname': 'Dossa',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.97, 'ranking': 19}]},
#  {'_id': 446498,
#   'fname': 'Nathan',
#   'lname': 'Jolly',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.57, 'ranking': 92}]},
#  {'_id': 442018,
#   'fname': 'Jenn',
#   'lname': 'Tennant',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.26, 'ranking': 13}]},
#  {'_id': 463159,
#   'fname': 'Sven',
#   'lname': 'Theunissen',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.99, 'ranking': 75}]},
#  {'_id': 327929,
#   'fname': 'Kolya',
#   'lname': 'Kowalchuk',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.93, 'ranking': 91}]},
#  {'_id': 381623,
#   'fname': 'Rip',
#   'lname': 'Peterman',
#   'gender': 'men',
#   'age': '75+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 4}]},
#  {'_id': 379503,
#   'fname': 'Kai',
#   'lname': 'Niu',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.62, 'ranking': 99}]},
#  {'_id': 298366,
#   'fname': 'David',
#   'lname': 'Moonlight',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.3, 'ranking': 9}]},
#  {'_id': 436410,
#   'fname': 'Mark',
#   'lname': 'Taylor',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.33, 'ranking': 19}]},
#  {'_id': 397301,
#   'fname': 'Alex',
#   'lname': 'Gass',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.05, 'ranking': 76}]},
#  {'_id': 310546,
#   'fname': 'Gord',
#   'lname': 'Neilson',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.03, 'ranking': 33}]},
#  {'_id': 478561,
#   'fname': 'Joe',
#   'lname': 'Holder',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.01, 'ranking': 81}]},
#  {'_id': 468555,
#   'fname': 'Craig',
#   'lname': 'Stewart',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.3, 'ranking': 59}]},
#  {'_id': 380080,
#   'fname': 'Heinrich',
#   'lname': 'Botha',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.92, 'ranking': 74}]},
#  {'_id': 242295,
#   'fname': 'Kristen',
#   'lname': 'Goldsmith',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.23, 'ranking': 10}]},
#  {'_id': 405066,
#   'fname': 'Zak',
#   'lname': 'Allison',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.4, 'ranking': 55}]},
#  {'_id': 251761,
#   'fname': 'Sean',
#   'lname': 'Jaegli',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.75, 'ranking': 6}]},
#  {'_id': 398145,
#   'fname': 'Thomas',
#   'lname': 'Haebler',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.51, 'ranking': 51},
#    {'category': 'doubles', 'rating': 4.39, 'ranking': 9}]},
#  {'_id': 297902,
#   'fname': 'Michael',
#   'lname': 'Volker',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.75, 'ranking': 49}]},
#  {'_id': 385416,
#   'fname': 'Steve',
#   'lname': 'Harms',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.51, 'ranking': 42}]},
#  {'_id': 404686,
#   'fname': 'Diana',
#   'lname': 'Chang',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.51, 'ranking': 9}]},
#  {'_id': 242638,
#   'fname': 'Owen',
#   'lname': 'Belton',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.4, 'ranking': 17}]},
#  {'_id': 417536,
#   'fname': 'Bradley',
#   'lname': 'Chessa',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.03, 'ranking': 34}]},
#  {'_id': 256018,
#   'fname': 'Bruce',
#   'lname': 'Matthews',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.77, 'ranking': 8},
#    {'category': 'doubles', 'rating': 2.38, 'ranking': 12}]},
#  {'_id': 475398,
#   'fname': 'Yijing',
#   'lname': 'Li',
#   'gender': 'women',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 1.72, 'ranking': 20}]},
#  {'_id': 163402,
#   'fname': 'Ben',
#   'lname': 'Uliana',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.32, 'ranking': 6}]},
#  {'_id': 402020,
#   'fname': 'Sarvenaz',
#   'lname': 'Amanat',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 2.61, 'ranking': 16}]},
#  {'_id': 451296,
#   'fname': 'Mark',
#   'lname': 'Ponter',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.41, 'ranking': 13}]},
#  {'_id': 298182,
#   'fname': 'Steve',
#   'lname': 'Crozier',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.16, 'ranking': 70}]},
#  {'_id': 385453,
#   'fname': 'Fraser',
#   'lname': 'Hesby',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.01, 'ranking': 17}]},
#  {'_id': 443914,
#   'fname': 'Paul',
#   'lname': 'Borchert',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4, 'ranking': 37}]},
#  {'_id': 469554,
#   'fname': 'Greg',
#   'lname': 'Cooney',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.04, 'ranking': 90}]},
#  {'_id': 385894,
#   'fname': 'Leanne',
#   'lname': 'Rousell',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 2.12, 'ranking': 23}]},
#  {'_id': 264963,
#   'fname': 'Gursharan',
#   'lname': 'Singh',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.3, 'ranking': 8}]},
#  {'_id': 299162,
#   'fname': 'Richard',
#   'lname': 'Humphries',
#   'gender': 'men',
#   'age': '75+',
#   'ratings': [{'category': 'singles', 'rating': 3.57, 'ranking': 4}]},
#  {'_id': 246931,
#   'fname': 'Liz',
#   'lname': 'Tuck',
#   'gender': 'women',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 4.68, 'ranking': 1}]},
#  {'_id': 242504,
#   'fname': 'Paul',
#   'lname': 'Adamiak',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.15, 'ranking': 17},
#    {'category': 'doubles', 'rating': 1.57, 'ranking': 8}]},
#  {'_id': 299355,
#   'fname': 'Andrew',
#   'lname': 'Clements',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.34, 'ranking': 6},
#    {'category': 'doubles', 'rating': 2.08, 'ranking': 8}]},
#  {'_id': 385866,
#   'fname': 'Antoine',
#   'lname': 'Fafard Couture',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 3.4, 'ranking': 60}]},
#  {'_id': 256179,
#   'fname': 'Pat',
#   'lname': 'Paproski',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 4.19, 'ranking': 14}]},
#  {'_id': 474650,
#   'fname': 'Glenn',
#   'lname': 'Doucet',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.1, 'ranking': 65}]},
#  {'_id': 386205,
#   'fname': 'Andre',
#   'lname': 'Gailits',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.25, 'ranking': 13},
#    {'category': 'doubles', 'rating': 2.68, 'ranking': 6}]},
#  {'_id': 425461,
#   'fname': 'Sharisse Ying-Ho',
#   'lname': 'Lin',
#   'gender': 'women',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 2.99, 'ranking': 12}]},
#  {'_id': 386276,
#   'fname': 'Jason',
#   'lname': 'Miket',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.78, 'ranking': 82}]},
#  {'_id': 433078,
#   'fname': 'Azmina',
#   'lname': 'Karim-Bondy',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 2.54, 'ranking': 18}]},
#  {'_id': 386742,
#   'fname': 'Ernie',
#   'lname': 'Chan',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 1.98, 'ranking': 20}]},
#  {'_id': 397037,
#   'fname': 'Rachel',
#   'lname': 'Au',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'doubles', 'rating': 3.96, 'ranking': 3}]},
#  {'_id': 249162,
#   'fname': 'Davood',
#   'lname': 'Anbarnam',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.7, 'ranking': 32}]},
#  {'_id': 399709,
#   'fname': 'Kevin',
#   'lname': 'Fraser',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.14, 'ranking': 72}]},
#  {'_id': 256085,
#   'fname': 'Ken',
#   'lname': 'Miller',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 3.59, 'ranking': 12}]},
#  {'_id': 298215,
#   'fname': 'Deb',
#   'lname': 'Baxter',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.28, 'ranking': 7}]},
#  {'_id': 246719,
#   'fname': 'Pamela',
#   'lname': 'Lewis',
#   'gender': 'women',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 3.07, 'ranking': 2}]},
#  {'_id': 400383,
#   'fname': 'Leslie',
#   'lname': 'Kerluke',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 24}]},
#  {'_id': 297898,
#   'fname': 'Neil',
#   'lname': 'Philcox',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.59, 'ranking': 32}]},
#  {'_id': 242629,
#   'fname': 'David',
#   'lname': 'Bauman',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.8, 'ranking': 26},
#    {'category': 'doubles', 'rating': 3.52, 'ranking': 9}]},
#  {'_id': 242792,
#   'fname': 'Jeff',
#   'lname': 'Scott',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.46, 'ranking': 45}]},
#  {'_id': 402212,
#   'fname': 'Adil',
#   'lname': 'Hooda',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.94, 'ranking': 89}]},
#  {'_id': 297986,
#   'fname': 'Leonard',
#   'lname': 'Bruno',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 3.6, 'ranking': 20}]},
#  {'_id': 465987,
#   'fname': 'Gautam',
#   'lname': 'Dhingra',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 2.57, 'ranking': 70}]},
#  {'_id': 310507,
#   'fname': 'Alex',
#   'lname': 'To',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.77, 'ranking': 37}]},
#  {'_id': 297703,
#   'fname': 'nelson',
#   'lname': 'lai',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.35, 'ranking': 22}]},
#  {'_id': 303589,
#   'fname': 'Matthew',
#   'lname': 'Waite',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'doubles', 'rating': 3.7, 'ranking': 8}]},
#  {'_id': 239708,
#   'fname': 'Graham',
#   'lname': 'Kerford',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.97, 'ranking': 6}]},
#  {'_id': 434299,
#   'fname': 'Taeyeon',
#   'lname': 'Lee',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.17, 'ranking': 26}]},
#  {'_id': 298636,
#   'fname': 'Hussein',
#   'lname': 'Hollands',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.78, 'ranking': 29}]},
#  {'_id': 298629,
#   'fname': 'Steve',
#   'lname': 'Berna',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.77, 'ranking': 48}]},
#  {'_id': 297582,
#   'fname': 'Mike',
#   'lname': 'Halliwell',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.68, 'ranking': 38}]},
#  {'_id': 298597,
#   'fname': 'Neeraj',
#   'lname': 'Mehra',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.4, 'ranking': 97}]},
#  {'_id': 298789,
#   'fname': 'Rose',
#   'lname': 'Pagnotta',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 2.79, 'ranking': 14}]},
#  {'_id': 399753,
#   'fname': 'Raj',
#   'lname': 'Sidhu',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.52, 'ranking': 48}]},
#  {'_id': 220682,
#   'fname': 'Alec',
#   'lname': 'Sleeth',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'doubles', 'rating': 2.89, 'ranking': 6}]},
#  {'_id': 246777,
#   'fname': 'Dana',
#   'lname': 'Merritt',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 3.64, 'ranking': 2}]},
#  {'_id': 467970,
#   'fname': 'Jenna',
#   'lname': 'Cook',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.17, 'ranking': 22}]},
#  {'_id': 425428,
#   'fname': 'Keanau',
#   'lname': 'Reid',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.9, 'ranking': 26}]},
#  {'_id': 274558,
#   'fname': 'Richard',
#   'lname': 'Yendell',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.8, 'ranking': 3},
#    {'category': 'doubles', 'rating': 4.53, 'ranking': 5}]},
#  {'_id': 466680,
#   'fname': 'Robert',
#   'lname': 'Smith',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.64, 'ranking': 112}]},
#  {'_id': 425026,
#   'fname': 'Greg',
#   'lname': 'Louttit',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 3.5, 'ranking': 22}]},
#  {'_id': 462518,
#   'fname': 'Mahir',
#   'lname': 'Nibber',
#   'gender': 'men',
#   'age': '35+',
# ...
#   'lname': 'Buntain',
#   'gender': 'women',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 3.63, 'ranking': 1}]},
#  {'_id': 299163,
#   'fname': 'Mike',
#   'lname': 'Zanni',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.74, 'ranking': 34}]},
#  {'_id': 415407,
#   'fname': 'Tyler',
#   'lname': 'Steele',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.39, 'ranking': 44},
#    {'category': 'doubles', 'rating': 1.5, 'ranking': 21}]},
#  {'_id': 434852,
#   'fname': 'Robbie',
#   'lname': 'Johnson',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.82, 'ranking': 84}]},
#  {'_id': 299027,
#   'fname': 'Colin',
#   'lname': 'Brown',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 5.13, 'ranking': 10}]},
#  {'_id': 413371,
#   'fname': 'Tony',
#   'lname': 'Burge',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4, 'ranking': 36}]},
#  {'_id': 244578,
#   'fname': 'Antonio',
#   'lname': 'Carrillo',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.43, 'ranking': 15}]},
#  {'_id': 317449,
#   'fname': 'Dean',
#   'lname': 'Kao',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 2.87, 'ranking': 107}]},
#  {'_id': 403379,
#   'fname': 'Paul',
#   'lname': 'Mori',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.04, 'ranking': 15}]},
#  {'_id': 470738,
#   'fname': 'Dennis',
#   'lname': 'Tubbs',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.56, 'ranking': 59}]},
#  {'_id': 408892,
#   'fname': 'Graham',
#   'lname': 'Milne',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 3.36, 'ranking': 100}]},
#  {'_id': 298368,
#   'fname': 'Kurtis',
#   'lname': 'Scriba',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 4.2, 'ranking': 44}]},
#  {'_id': 255442,
#   'fname': 'Giselle',
#   'lname': 'Delgado',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.52, 'ranking': 1}]},
#  {'_id': 246803,
#   'fname': 'Krystal',
#   'lname': 'Nevar',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 2.71, 'ranking': 13}]},
#  {'_id': 247059,
#   'fname': 'Jade',
#   'lname': 'Carter',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.66, 'ranking': 7}]},
#  {'_id': 11197,
#   'fname': 'Carolyn',
#   'lname': 'Russell',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.1, 'ranking': 1}]},
#  {'_id': 465749,
#   'fname': 'Luke',
#   'lname': 'Thomas',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.73, 'ranking': 43}]},
#  {'_id': 430732,
#   'fname': 'Darren',
#   'lname': 'Nobrega',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.73, 'ranking': 86}]},
#  {'_id': 386284,
#   'fname': 'Doug',
#   'lname': 'Milne',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'doubles', 'rating': 2.64, 'ranking': 14}]},
#  {'_id': 254790,
#   'fname': 'Paul',
#   'lname': 'Brebner',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 18}]},
#  {'_id': 398852,
#   'fname': 'Michael',
#   'lname': 'Thompson',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 6.03, 'ranking': 5},
#    {'category': 'doubles', 'rating': 2.45, 'ranking': 9}]},
#  {'_id': 466646,
#   'fname': 'Allison',
#   'lname': 'Li',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.23, 'ranking': 33}]},
#  {'_id': 246824,
#   'fname': 'Donna',
#   'lname': 'Pakulak',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.17, 'ranking': 2},
#    {'category': 'doubles', 'rating': 4.1, 'ranking': 3}]},
#  {'_id': 398463,
#   'fname': 'Jaye',
#   'lname': 'Russell',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.13, 'ranking': 11}]},
#  {'_id': 298158,
#   'fname': 'Kevin',
#   'lname': 'Limbert',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.27, 'ranking': 10}]},
#  {'_id': 298919,
#   'fname': 'Todd',
#   'lname': 'Rutherford',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.77, 'ranking': 7}]},
#  {'_id': 386280,
#   'fname': 'Adam',
#   'lname': 'Miller',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.99, 'ranking': 85}]},
#  {'_id': 434401,
#   'fname': 'Stuart',
#   'lname': 'Rance',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.21, 'ranking': 65}]},
#  {'_id': 397288,
#   'fname': 'John',
#   'lname': 'Carsley',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 3.57, 'ranking': 13}]},
#  {'_id': 256019,
#   'fname': 'Ron',
#   'lname': 'Matthews',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.8, 'ranking': 45}]},
#  {'_id': 448147,
#   'fname': 'Madeleine',
#   'lname': 'Macey',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.16, 'ranking': 7},
#    {'category': 'doubles', 'rating': 3.47, 'ranking': 4}]},
#  {'_id': 297600,
#   'fname': 'Anne',
#   'lname': 'Bokser',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.41, 'ranking': 8}]},
#  {'_id': 297697,
#   'fname': 'Chris',
#   'lname': 'El-Araj',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.92, 'ranking': 70}]},
#  {'_id': 399672,
#   'fname': 'Doug',
#   'lname': 'Ramsay',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 2.96, 'ranking': 18}]},
#  {'_id': 298200,
#   'fname': 'Saiba',
#   'lname': 'Lalji',
#   'gender': 'women',
#   'age': '50+',
#   'ratings': [{'category': 'doubles', 'rating': 2.39, 'ranking': 4}]},
#  {'_id': 298022,
#   'fname': 'James',
#   'lname': 'Clift',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.29, 'ranking': 9}]},
#  {'_id': 297891,
#   'fname': 'Brad',
#   'lname': 'Daudlin',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.9, 'ranking': 40}]},
#  {'_id': 298037,
#   'fname': 'Les',
#   'lname': 'Perger',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 3.32, 'ranking': 27}]},
#  {'_id': 400234,
#   'fname': 'Jillian',
#   'lname': 'Irvine',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.8, 'ranking': 25},
#    {'category': 'doubles', 'rating': 1.76, 'ranking': 10}]},
#  {'_id': 451919,
#   'fname': 'Joe',
#   'lname': 'English',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 3.85, 'ranking': 76}]},
#  {'_id': 398470,
#   'fname': 'Sasha',
#   'lname': 'Jesperson',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 2.91, 'ranking': 9}]},
#  {'_id': 397881,
#   'fname': 'Lukas',
#   'lname': 'Wenzel',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 5.67, 'ranking': 10}]},
#  {'_id': 298925,
#   'fname': 'Mica',
#   'lname': 'Thiessen',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 5.15, 'ranking': 9}]},
#  {'_id': 298392,
#   'fname': 'Kyle',
#   'lname': 'Weatherby',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.25, 'ranking': 12}]},
#  {'_id': 242202,
#   'fname': 'Laurie',
#   'lname': 'Cavan',
#   'gender': 'women',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 3.52, 'ranking': 6}]},
#  {'_id': 414561,
#   'fname': 'Gary',
#   'lname': 'Desrosier',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'singles', 'rating': 3.62, 'ranking': 11}]},
#  {'_id': 310506,
#   'fname': 'Ken',
#   'lname': 'Lelek',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 3.72, 'ranking': 18}]},
#  {'_id': 399225,
#   'fname': 'Holly',
#   'lname': 'Ludlow',
#   'gender': 'women',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.58, 'ranking': 3}]},
#  {'_id': 386610,
#   'fname': 'Jeffrey',
#   'lname': 'Sun',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 3.56, 'ranking': 46}]},
#  {'_id': 431277,
#   'fname': 'Bryan',
#   'lname': 'Woodward',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 5.07, 'ranking': 20}]},
#  {'_id': 299152,
#   'fname': 'Jacqulin',
#   'lname': 'McNicol',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 2.86, 'ranking': 14}]},
#  {'_id': 242957,
#   'fname': 'Trevor',
#   'lname': 'Van Eerden',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'doubles', 'rating': 1.85, 'ranking': 19}]},
#  {'_id': 435360,
#   'fname': 'Rahi',
#   'lname': 'Kumar',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.06, 'ranking': 109}]},
#  {'_id': 230798,
#   'fname': 'Zachary',
#   'lname': 'Lelek',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.91, 'ranking': 26}]},
#  {'_id': 247216,
#   'fname': 'Geoff',
#   'lname': 'Emslie',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 5.44, 'ranking': 4}]},
#  {'_id': 251826,
#   'fname': 'Matt',
#   'lname': 'Kerr',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 4.94, 'ranking': 15}]},
#  {'_id': 400389,
#   'fname': 'Lucy',
#   'lname': "O'Connor",
#   'gender': 'women',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 2.83, 'ranking': 13}]},
#  {'_id': 386810,
#   'fname': 'Greg',
#   'lname': 'Coutts',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 3.11, 'ranking': 4}]},
#  {'_id': 395787,
#   'fname': 'Lloyd',
#   'lname': 'Edmonds',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 4.48, 'ranking': 36}]},
#  {'_id': 435758,
#   'fname': 'Tania',
#   'lname': 'Dearden',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 1.79, 'ranking': 33}]},
#  {'_id': 298615,
#   'fname': 'Shawn',
#   'lname': 'Worsfold',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.02, 'ranking': 46}]},
#  {'_id': 255885,
#   'fname': 'Mike',
#   'lname': 'Lavigne',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'doubles', 'rating': 3.78, 'ranking': 7}]},
#  {'_id': 417797,
#   'fname': 'Mike',
#   'lname': 'Carrier',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.88, 'ranking': 5},
#    {'category': 'doubles', 'rating': 3.79, 'ranking': 7}]},
#  {'_id': 386365,
#   'fname': 'Timothy',
#   'lname': 'Nichols',
#   'gender': 'men',
#   'age': '25+',
#   'ratings': [{'category': 'singles', 'rating': 3.98, 'ranking': 53}]},
#  {'_id': 298596,
#   'fname': 'Mahamood',
#   'lname': 'Vallani',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 2.76, 'ranking': 29}]},
#  {'_id': 398435,
#   'fname': 'Julianne',
#   'lname': 'Leekie',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 2.81, 'ranking': 15}]},
#  {'_id': 417567,
#   'fname': 'Ben',
#   'lname': 'Gula',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 3.59, 'ranking': 100}]},
#  {'_id': 400525,
#   'fname': 'Matias',
#   'lname': 'Herrero',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.92, 'ranking': 21},
#    {'category': 'doubles', 'rating': 1.75, 'ranking': 18}]},
#  {'_id': 385588,
#   'fname': 'Gill',
#   'lname': 'Rhodes',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 3.08, 'ranking': 9}]},
#  {'_id': 310387,
#   'fname': 'Charlie',
#   'lname': 'Maddison',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 3.05, 'ranking': 5}]},
#  {'_id': 263812,
#   'fname': 'Ian',
#   'lname': 'Heck',
#   'gender': 'men',
#   'age': '19+',
#   'ratings': [{'category': 'singles', 'rating': 5.35, 'ranking': 18}]},
#  {'_id': 377141,
#   'fname': 'Sue',
#   'lname': 'Griffin',
#   'gender': 'women',
#   'age': '65+',
#   'ratings': [{'category': 'singles', 'rating': 2.88, 'ranking': 6}]},
#  {'_id': 398020,
#   'fname': 'William',
#   'lname': 'James',
#   'gender': 'men',
#   'age': '65+',
#   'ratings': [{'category': 'doubles', 'rating': 2.31, 'ranking': 16}]},
#  {'_id': 310334,
#   'fname': 'Maurice',
#   'lname': 'Goulet',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 1.92, 'ranking': 13}]},
#  {'_id': 470339,
#   'fname': 'Paul',
#   'lname': 'Stevenson',
#   'gender': 'men',
#   'age': '70+',
#   'ratings': [{'category': 'doubles', 'rating': 1.5, 'ranking': 16}]},
#  {'_id': 308499,
#   'fname': 'Ben',
#   'lname': 'Weiler',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.45, 'ranking': 52}]},
#  {'_id': 440965,
#   'fname': 'Brendan',
#   'lname': 'George',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'doubles', 'rating': 4.09, 'ranking': 5}]},
#  {'_id': 417744,
#   'fname': 'Alex',
#   'lname': 'Dale',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.82, 'ranking': 104}]},
#  {'_id': 386035,
#   'fname': 'Jennifer',
#   'lname': 'Beliveau',
#   'gender': 'women',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 1.52, 'ranking': 17}]},
#  {'_id': 242662,
#   'fname': 'David',
#   'lname': 'Phillips',
#   'gender': 'men',
#   'age': '40+',
#   'ratings': [{'category': 'singles', 'rating': 4.92, 'ranking': 23}]},
#  {'_id': 317422,
#   'fname': 'Chris',
#   'lname': 'Rose',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 4.06, 'ranking': 75}]},
#  {'_id': 399759,
#   'fname': 'Rudi',
#   'lname': 'van de Rode',
#   'gender': 'men',
#   'age': '45+',
#   'ratings': [{'category': 'singles', 'rating': 4.36, 'ranking': 52}]},
#  {'_id': 385857,
#   'fname': 'Alfonso',
#   'lname': 'Ergas',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.5, 'ranking': 80}]},
#  {'_id': 225240,
#   'fname': 'Mark',
#   'lname': 'Ingram',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.6, 'ranking': 9}]},
#  {'_id': 34756,
#   'fname': 'Paul',
#   'lname': 'Ratchford',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 4.79, 'ranking': 36}]},
#  {'_id': 298107,
#   'fname': 'Jody',
#   'lname': 'Findlay',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.21, 'ranking': 25}]},
#  {'_id': 297592,
#   'fname': 'Morgan',
#   'lname': 'Dehnel',
#   'gender': 'men',
#   'age': '60+',
#   'ratings': [{'category': 'singles', 'rating': 4.34, 'ranking': 17}]},
#  {'_id': 298945,
#   'fname': 'Helen',
#   'lname': 'Kim',
#   'gender': 'women',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 2.73, 'ranking': 16},
#    {'category': 'doubles', 'rating': 1.6, 'ranking': 8}]},
#  {'_id': 297875,
#   'fname': 'Mark',
#   'lname': 'Damm',
#   'gender': 'men',
#   'age': '55+',
#   'ratings': [{'category': 'singles', 'rating': 4.06, 'ranking': 44}]},
#  {'_id': 466540,
#   'fname': 'Jake',
#   'lname': 'Minguk Jang',
#   'gender': 'men',
#   'age': '30+',
#   'ratings': [{'category': 'singles', 'rating': 2.83, 'ranking': 111}]},
#  {'_id': 435752,
#   'fname': 'Chelsea',
#   'lname': 'Lee',
#   'gender': 'women',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 2.12, 'ranking': 30}]},
#  {'_id': 299148,
#   'fname': 'Maclean',
#   'lname': 'Falkins',
#   'gender': 'men',
#   'age': '35+',
#   'ratings': [{'category': 'singles', 'rating': 3.88, 'ranking': 96}]},
#  {'_id': 473329,
#   'fname': 'Denn',
#   'lname': 'Golinski',
#   'gender': 'men',
#   'age': '50+',
#   'ratings': [{'category': 'singles', 'rating': 3.06, 'ranking': 89}]},
#  {'_id': 303555,
#   'fname': 'Janine',
#   'lname': 'Waite',
#   'gender': 'women',
#   'age': '45+',
#   'ratings': [{'category': 'doubles', 'rating': 3.89, 'ranking': 1}]},
#  ...]

# %%
print("Total number of players: {num}".format(num=len(players_list)))
# Out:
# Total number of players: 1216

# %%
players_df = pd.DataFrame(players_list)

# %%
players_df
# Out:
#          _id    fname          lname gender  age  \
# 0     397930   Daniel         Maczko    men  35+
# 1     298206  Shelley           Neil  women  60+
# 2     399360    Julie  Cornett-Ching  women  50+
# 3     242692     Tony           Quan    men  70+
# 4     437976   Andrew           Sage    men  35+
# ...      ...      ...            ...    ...  ...
# 1211  386643      Cam       Thompson    men  35+
# 1212  298525      Tam             Do    men  45+
# 1213  398304    Hamid  Khosrow Kiani    men  30+
# 1214  475800     bill          clark    men  55+
# 1215  397043   Nilesh          Saraf    men  50+
#
#                                                 ratings
# 0     [{'category': 'singles', 'rating': 4.52, 'rank...
# 1     [{'category': 'singles', 'rating': 3.31, 'rank...
# 2     [{'category': 'singles', 'rating': 3.48, 'rank...
# 3     [{'category': 'doubles', 'rating': 1.5, 'ranki...
# 4     [{'category': 'singles', 'rating': 3.41, 'rank...
# ...                                                 ...
# 1211  [{'category': 'doubles', 'rating': 1.5, 'ranki...
# 1212  [{'category': 'singles', 'rating': 5.29, 'rank...
# 1213  [{'category': 'singles', 'rating': 5.71, 'rank...
# 1214  [{'category': 'singles', 'rating': 3.95, 'rank...
# 1215  [{'category': 'singles', 'rating': 3.58, 'rank...
#
# [1216 rows x 6 columns]

# %% [markdown]
# ### Get matches data

# %%
matches_collection = client["squashbc"]["matches"]

# %%
matches = matches_collection.find()

# %%
matches_list = list(matches)

# %%
matches_list
# Out:
# [{'_id': ObjectId('661120a4f4ff2c25467a344b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-07-20T00:00:00',
#   'scores': '10-15, 7-15, 10-15',
#   'player_a1': 397238,
#   'player_a2': None,
#   'player_b1': 397370,
#   'player_b2': 385805},
#  {'_id': ObjectId('661120a4f4ff2c25467a344c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-07-20T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 396299,
#   'player_a2': 386742,
#   'player_b1': 397348,
#   'player_b2': 399783},
#  {'_id': ObjectId('661120a4f4ff2c25467a344d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-07-13T00:00:00',
#   'scores': '15-14, 4-15, 11-15, 15-11, 10-15',
#   'player_a1': 247259,
#   'player_a2': 246931,
#   'player_b1': 397370,
#   'player_b2': 303589},
#  {'_id': ObjectId('661120a4f4ff2c25467a344e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-07-06T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 399783,
#   'player_a2': 385805,
#   'player_b1': 246849,
#   'player_b2': 303555},
#  {'_id': ObjectId('661120a4f4ff2c25467a344f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-06-29T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 85092,
#   'player_a2': 397348,
#   'player_b1': 70354,
#   'player_b2': 396178},
#  {'_id': ObjectId('661120a4f4ff2c25467a3450'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-04-13T00:00:00',
#   'scores': '15-13, 10-15, 15-8, 13-15, 10-15',
#   'player_a1': 246182,
#   'player_a2': 271931,
#   'player_b1': 1000000289,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120a4f4ff2c25467a3451'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-30T00:00:00',
#   'scores': '11-0, 11-0, 11-0',
#   'player_a1': 0,
#   'player_a2': 0,
#   'player_b1': 71931,
#   'player_b2': 246824},
#  {'_id': ObjectId('661120a4f4ff2c25467a3452'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-30T00:00:00',
#   'scores': '15-6, 14-15, 15-11, 15-4',
#   'player_a1': 246182,
#   'player_a2': 246930,
#   'player_b1': 242138,
#   'player_b2': 246021},
#  {'_id': ObjectId('661120a4f4ff2c25467a3453'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-23T00:00:00',
#   'scores': '15-13, 15-14, 13-15, 15-11',
#   'player_a1': 271931,
#   'player_a2': 246930,
#   'player_b1': 72487,
#   'player_b2': 279520},
#  {'_id': ObjectId('661120a4f4ff2c25467a3454'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-16T00:00:00',
#   'scores': '14-15, 15-14, 6-15, 5-15',
#   'player_a1': 246021,
#   'player_a2': 1000000289,
#   'player_b1': 72487,
#   'player_b2': 279520},
#  {'_id': ObjectId('661120a4f4ff2c25467a3455'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-16T00:00:00',
#   'scores': '15-14, 15-11, 10-15, 15-10',
#   'player_a1': 271931,
#   'player_a2': 242079,
#   'player_b1': 246811,
#   'player_b2': None},
#  {'_id': ObjectId('661120a4f4ff2c25467a3456'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-02T00:00:00',
#   'scores': '15-12, 15-3, 15-6',
#   'player_a1': 246182,
#   'player_a2': 246675,
#   'player_b1': 298782,
#   'player_b2': 246945},
#  {'_id': ObjectId('661120a4f4ff2c25467a3457'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-23T00:00:00',
#   'scores': '15-5, 11-15, 15-3, 14-15, 15-7',
#   'player_a1': 242138,
#   'player_a2': 1000000289,
#   'player_b1': 298782,
#   'player_b2': 72487},
#  {'_id': ObjectId('661120a4f4ff2c25467a3458'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-23T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 71931,
#   'player_a2': 246811,
#   'player_b1': 246182,
#   'player_b2': 246930},
#  {'_id': ObjectId('661120a4f4ff2c25467a3459'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-16T00:00:00',
#   'scores': '15-4, 15-6, 8-15, 15-8',
#   'player_a1': 279520,
#   'player_a2': 72487,
#   'player_b1': 71931,
#   'player_b2': 246824},
#  {'_id': ObjectId('661120a4f4ff2c25467a345a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-16T00:00:00',
#   'scores': '7-15, 10-15, 15-9, 7-15',
#   'player_a1': 271931,
#   'player_a2': 242079,
#   'player_b1': 1000000289,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120a4f4ff2c25467a345b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-02T00:00:00',
#   'scores': '11-0, 11-0, 11-0',
#   'player_a1': 242227,
#   'player_a2': 298782,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('661120a4f4ff2c25467a345c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-02T00:00:00',
#   'scores': '15-8, 15-5, 15-11',
#   'player_a1': 242138,
#   'player_a2': 423651,
#   'player_b1': 71931,
#   'player_b2': 431418},
#  {'_id': ObjectId('661120a4f4ff2c25467a345d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-19T00:00:00',
#   'scores': '15-6, 15-12, 15-9',
#   'player_a1': 246182,
#   'player_a2': 242227,
#   'player_b1': 246811,
#   'player_b2': 431418},
#  {'_id': ObjectId('661120a4f4ff2c25467a345e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-12T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 71931,
#   'player_a2': 246811,
#   'player_b1': 72487,
#   'player_b2': 279520},
#  {'_id': ObjectId('661120a4f4ff2c25467a345f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-12T00:00:00',
#   'scores': '15-8, 13-15, 15-10, 3-15, 15-14',
#   'player_a1': 246182,
#   'player_a2': 246675,
#   'player_b1': 246021,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120a4f4ff2c25467a3460'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-05T00:00:00',
#   'scores': '15-12, 10-15, 14-15, 15-5, 13-15',
#   'player_a1': 72487,
#   'player_a2': 279520,
#   'player_b1': 246182,
#   'player_b2': 246930},
#  {'_id': ObjectId('661120a4f4ff2c25467a3461'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-12-15T00:00:00',
#   'scores': '15-14, 13-15, 15-7, 10-15, 7-15',
#   'player_a1': 71931,
#   'player_a2': 246811,
#   'player_b1': 271931,
#   'player_b2': 246930},
#  {'_id': ObjectId('661120a4f4ff2c25467a3462'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-12-01T00:00:00',
#   'scores': '11-0, 11-0, 11-0',
#   'player_a1': 246811,
#   'player_a2': 246824,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('661120a4f4ff2c25467a3463'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-12-01T00:00:00',
#   'scores': '15-13, 15-12, 15-9',
#   'player_a1': 246182,
#   'player_a2': 246811,
#   'player_b1': 217589,
#   'player_b2': 246021},
#  {'_id': ObjectId('661120a4f4ff2c25467a3464'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-17T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 246824,
#   'player_a2': 423651,
#   'player_b1': 242138,
#   'player_b2': 1000000289},
#  {'_id': ObjectId('661120a4f4ff2c25467a3465'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-10T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 242138,
#   'player_a2': 246021,
#   'player_b1': None,
#   'player_b2': 72487},
#  {'_id': ObjectId('661120a4f4ff2c25467a3466'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-10T00:00:00',
#   'scores': '9-15, 15-12, 15-9, 7-15, 13-15',
#   'player_a1': 271931,
#   'player_a2': 242227,
#   'player_b1': 71931,
#   'player_b2': 246824},
#  {'_id': ObjectId('661120a4f4ff2c25467a3467'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-03T00:00:00',
#   'scores': '9-15, 15-11, 15-12, 12-15, 14-15',
#   'player_a1': 242138,
#   'player_a2': 246021,
#   'player_b1': 246675,
#   'player_b2': 246930},
#  {'_id': ObjectId('661120a4f4ff2c25467a3468'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-03T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 246811,
#   'player_a2': 423651,
#   'player_b1': 72487,
#   'player_b2': 279520},
#  {'_id': ObjectId('661120a4f4ff2c25467a3469'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-27T00:00:00',
#   'scores': '10-15, 10-15, 12-15',
#   'player_a1': 1000000289,
#   'player_a2': 246021,
#   'player_b1': 246824,
#   'player_b2': 423651},
#  {'_id': ObjectId('661120a4f4ff2c25467a346a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-20T00:00:00',
#   'scores': '6-15, 12-15, 7-15',
#   'player_a1': None,
#   'player_a2': 246824,
#   'player_b1': 271931,
#   'player_b2': 246930},
#  {'_id': ObjectId('661120a4f4ff2c25467a346b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-06T00:00:00',
#   'scores': '9-15, 9-15, 12-15',
#   'player_a1': 1000000289,
#   'player_a2': 246021,
#   'player_b1': 271931,
#   'player_b2': 246930},
#  {'_id': ObjectId('661120a4f4ff2c25467a346c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-04-05T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 77849,
#   'player_a2': 297721,
#   'player_b1': 13263,
#   'player_b2': 330944},
#  {'_id': ObjectId('661120a4f4ff2c25467a346d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-22T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 93512,
#   'player_a2': 256046,
#   'player_b1': 246256,
#   'player_b2': 251576},
#  {'_id': ObjectId('661120a4f4ff2c25467a346e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-22T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': 242629,
#   'player_b2': 71511},
#  {'_id': ObjectId('661120a4f4ff2c25467a346f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-04T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 13263,
#   'player_a2': 410878,
#   'player_b1': 410672,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120a4f4ff2c25467a3470'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-15T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 77849,
#   'player_a2': 297721,
#   'player_b1': 13263,
#   'player_b2': 330944},
#  {'_id': ObjectId('661120a4f4ff2c25467a3471'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-15T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 217592,
#   'player_a2': 417797,
#   'player_b1': 250760,
#   'player_b2': 265464},
#  {'_id': ObjectId('661120a4f4ff2c25467a3472'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-01T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 71511,
#   'player_b1': 382735,
#   'player_b2': 411278},
#  {'_id': ObjectId('661120a4f4ff2c25467a3473'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-03-01T00:00:00',
#   'scores': '14-15, 15-11, 15-13, 10-15, 12-15',
#   'player_a1': 265464,
#   'player_a2': 250760,
#   'player_b1': 398304,
#   'player_b2': 297721},
#  {'_id': ObjectId('661120a4f4ff2c25467a3474'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-22T00:00:00',
#   'scores': '15-14, 15-12, 12-15, 15-10',
#   'player_a1': 251646,
#   'player_a2': 250672,
#   'player_b1': None,
#   'player_b2': 397904},
#  {'_id': ObjectId('661120a4f4ff2c25467a3475'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-22T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 72446,
#   'player_a2': 13263,
#   'player_b1': 256145,
#   'player_b2': 93518},
#  {'_id': ObjectId('661120a4f4ff2c25467a3476'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-15T00:00:00',
#   'scores': '15-5, 15-7, 13-15, 15-6',
#   'player_a1': 13263,
#   'player_a2': 72446,
#   'player_b1': 410672,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120a4f4ff2c25467a3477'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-01T00:00:00',
#   'scores': '12-15, 15-13, 13-15, 11-15',
#   'player_a1': 398304,
#   'player_a2': 250672,
#   'player_b1': 265464,
#   'player_b2': 250760},
#  {'_id': ObjectId('661120a4f4ff2c25467a3478'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-02-01T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 382735,
#   'player_a2': 415725,
#   'player_b1': None,
#   'player_b2': 246000},
#  {'_id': ObjectId('661120a4f4ff2c25467a3479'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-25T00:00:00',
#   'scores': '15-13, 8-15, 11-15, 8-15',
#   'player_a1': None,
#   'player_a2': 71511,
#   'player_b1': 251646,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120a4f4ff2c25467a347a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-18T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 77849,
#   'player_a2': 93465,
#   'player_b1': 398904,
#   'player_b2': 415725},
#  {'_id': ObjectId('661120a4f4ff2c25467a347b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-18T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 242629,
#   'player_a2': None,
#   'player_b1': 64414,
#   'player_b2': 93512},
#  {'_id': ObjectId('661120a4f4ff2c25467a347c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-11T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 251646,
#   'player_a2': 77849,
#   'player_b1': 64414,
#   'player_b2': 265464},
#  {'_id': ObjectId('661120a4f4ff2c25467a347d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2023-01-11T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 242629,
#   'player_a2': None,
#   'player_b1': 242644,
#   'player_b2': 415725},
#  {'_id': ObjectId('661120a4f4ff2c25467a347e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-12-14T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 242629,
#   'player_a2': 71511,
#   'player_b1': 382735,
#   'player_b2': 415725},
#  {'_id': ObjectId('661120a4f4ff2c25467a347f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-12-14T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 400555,
#   'player_a2': 64414,
#   'player_b1': 251646,
#   'player_b2': 250672},
#  {'_id': ObjectId('661120a4f4ff2c25467a3480'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-30T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 71511,
#   'player_b1': 410672,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120a4f4ff2c25467a3481'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-28T00:00:00',
#   'scores': '14-15, 15-8, 15-11, 11-15, 15-6',
#   'player_a1': 382735,
#   'player_a2': 415725,
#   'player_b1': 440965,
#   'player_b2': 256145},
#  {'_id': ObjectId('661120a4f4ff2c25467a3482'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-16T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': 72446,
#   'player_b2': 13263},
#  {'_id': ObjectId('661120a4f4ff2c25467a3483'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-16T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 71511,
#   'player_b1': 265464,
#   'player_b2': 256046},
#  {'_id': ObjectId('661120a4f4ff2c25467a3484'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-09T00:00:00',
#   'scores': '15-6, 15-14, 8-15, 15-13',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': 64414,
#   'player_b2': 250760},
#  {'_id': ObjectId('661120a4f4ff2c25467a3485'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-09T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 71511,
#   'player_b1': 382735,
#   'player_b2': 415725},
#  {'_id': ObjectId('661120a4f4ff2c25467a3486'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-02T00:00:00',
#   'scores': '15-13, 14-15, 15-8, 15-12',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': None,
#   'player_b2': 71511},
#  {'_id': ObjectId('661120a4f4ff2c25467a3487'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-11-02T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 64414,
#   'player_a2': 265464,
#   'player_b1': 13263,
#   'player_b2': 411278},
#  {'_id': ObjectId('661120a4f4ff2c25467a3488'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-19T00:00:00',
#   'scores': '15-10, 15-11, 15-12',
#   'player_a1': 411278,
#   'player_a2': 410878,
#   'player_b1': 297721,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120a4f4ff2c25467a3489'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-19T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 400555,
#   'player_a2': 256046,
#   'player_b1': None,
#   'player_b2': 71511},
#  {'_id': ObjectId('661120a4f4ff2c25467a348a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-12T00:00:00',
#   'scores': '15-11, 15-4, 8-15, 15-8',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': 440965,
#   'player_b2': 250760},
#  {'_id': ObjectId('661120a4f4ff2c25467a348b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-12T00:00:00',
#   'scores': '15-11, 15-9, 15-12',
#   'player_a1': 72446,
#   'player_a2': 415725,
#   'player_b1': None,
#   'player_b2': 71511},
#  {'_id': ObjectId('661120a4f4ff2c25467a348c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-05T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 397904,
#   'player_b1': 410672,
#   'player_b2': 242554},
#  {'_id': ObjectId('661120a4f4ff2c25467a348d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-10-05T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 415725,
#   'player_a2': 411278,
#   'player_b1': 250760,
#   'player_b2': 256046},
#  {'_id': ObjectId('661120a4f4ff2c25467a348e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-24T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 323007,
#   'player_a2': 0,
#   'player_b1': 71809,
#   'player_b2': 385805},
#  {'_id': ObjectId('661120a4f4ff2c25467a348f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-24T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 246849,
#   'player_a2': 303589,
#   'player_b1': 397238,
#   'player_b2': 396573},
#  {'_id': ObjectId('661120a4f4ff2c25467a3490'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-14T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 415271,
#   'player_a2': 247342,
#   'player_b1': 400727,
#   'player_b2': 85092},
#  {'_id': ObjectId('661120a4f4ff2c25467a3491'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-17T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 298195,
#   'player_a2': 399677,
#   'player_b1': 303569,
#   'player_b2': 303555},
#  {'_id': ObjectId('661120a4f4ff2c25467a3492'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-10T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 242692,
#   'player_a2': 303569,
#   'player_b1': 323007,
#   'player_b2': 298184},
#  {'_id': ObjectId('661120a4f4ff2c25467a3493'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-27T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 397271,
#   'player_a2': 400727,
#   'player_b1': None,
#   'player_b2': 322882},
#  {'_id': ObjectId('661120a4f4ff2c25467a3494'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-27T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 298945,
#   'player_a2': 386742,
#   'player_b1': None,
#   'player_b2': 303569},
#  {'_id': ObjectId('661120a4f4ff2c25467a3495'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-03T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 298206,
#   'player_a2': 400727,
#   'player_b1': 298945,
#   'player_b2': 303589},
#  {'_id': ObjectId('661120a4f4ff2c25467a3496'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-08-03T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 303569,
#   'player_a2': None,
#   'player_b1': 399677,
#   'player_b2': None},
#  {'_id': ObjectId('661120a4f4ff2c25467a3497'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-20T00:00:00',
#   'scores': '2-15, 9-15, 6-15',
#   'player_a1': 298184,
#   'player_a2': 397271,
#   'player_b1': 415271,
#   'player_b2': 246849},
#  {'_id': ObjectId('661120a4f4ff2c25467a3498'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-13T00:00:00',
#   'scores': '15-9, 15-13, 15-6',
#   'player_a1': 386213,
#   'player_a2': 246849,
#   'player_b1': 399677,
#   'player_b2': 396178},
#  {'_id': ObjectId('661120a4f4ff2c25467a3499'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-06T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 242207,
#   'player_a2': 298945,
#   'player_b1': 396178,
#   'player_b2': 298195},
#  {'_id': ObjectId('661120a4f4ff2c25467a349a'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-07-06T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 303555,
#   'player_a2': 242692,
#   'player_b1': 400727,
#   'player_b2': 298206},
#  {'_id': ObjectId('661120a4f4ff2c25467a349b'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-17T00:00:00',
#   'scores': '15-12, 10-15, 3-15, 13-15',
#   'player_a1': 167417,
#   'player_a2': 246905,
#   'player_b1': 271931,
#   'player_b2': 1000000289},
#  {'_id': ObjectId('661120a4f4ff2c25467a349c'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-17T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 71931,
#   'player_a2': 242138,
#   'player_b1': 397295,
#   'player_b2': 242227},
#  {'_id': ObjectId('661120a4f4ff2c25467a349d'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-10T00:00:00',
#   'scores': '15-8, 15-10, 15-12',
#   'player_a1': 246777,
#   'player_a2': 71931,
#   'player_b1': 167417,
#   'player_b2': 246905},
#  {'_id': ObjectId('661120a4f4ff2c25467a349e'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-10T00:00:00',
#   'scores': '15-14, 15-11, 8-15, 13-15, 13-15',
#   'player_a1': 271931,
#   'player_a2': 397295,
#   'player_b1': 246811,
#   'player_b2': 246021},
#  {'_id': ObjectId('661120a4f4ff2c25467a349f'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-03T00:00:00',
#   'scores': '5-15, 11-15, 6-15',
#   'player_a1': 1000000289,
#   'player_a2': 246930,
#   'player_b1': 242227,
#   'player_b2': 217589},
#  {'_id': ObjectId('661120a4f4ff2c25467a34a0'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-03T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': 72487,
#   'player_a2': 246824,
#   'player_b1': 246811,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120a4f4ff2c25467a34a1'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-24T00:00:00',
#   'scores': '15-13, 10-15, 15-7, 15-12',
#   'player_a1': 271931,
#   'player_a2': 242227,
#   'player_b1': 246811,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120a4f4ff2c25467a34a2'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-24T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 298782,
#   'player_a2': 1000000289,
#   'player_b1': 72487,
#   'player_b2': 246824},
#  {'_id': ObjectId('661120a4f4ff2c25467a34a3'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-17T00:00:00',
#   'scores': '15-7, 8-15, 15-13, 15-7',
#   'player_a1': 298782,
#   'player_a2': 271931,
#   'player_b1': 71931,
#   'player_b2': 246811},
#  {'_id': ObjectId('661120a4f4ff2c25467a34a4'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-10T00:00:00',
#   'scores': '11-15, 15-8, 15-12, 12-15, 15-14',
#   'player_a1': 397295,
#   'player_a2': 242227,
#   'player_b1': 246930,
#   'player_b2': 298782},
#  {'_id': ObjectId('661120a4f4ff2c25467a34a5'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-10T00:00:00',
#   'scores': '6-15, 15-12, 15-3, 15-12',
#   'player_a1': 71931,
#   'player_a2': 242138,
#   'player_b1': 167417,
#   'player_b2': 246824},
#  {'_id': ObjectId('661120a4f4ff2c25467a34a6'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-03T00:00:00',
#   'scores': '15-10, 15-5, 9-15, 15-4',
#   'player_a1': 217589,
#   'player_a2': 242227,
#   'player_b1': 71931,
#   'player_b2': 246811},
#  {'_id': ObjectId('661120a4f4ff2c25467a34a7'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-03T00:00:00',
#   'scores': '15-13, 15-12, 15-6',
#   'player_a1': 246930,
#   'player_a2': 298782,
#   'player_b1': 72487,
#   'player_b2': 246675},
#  {'_id': ObjectId('661120a4f4ff2c25467a34a8'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-27T00:00:00',
#   'scores': '15-8, 15-8, 15-13',
#   'player_a1': 72487,
#   'player_a2': 246824,
#   'player_b1': 271931,
#   'player_b2': 246930},
#  {'_id': ObjectId('661120a4f4ff2c25467a34a9'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-27T00:00:00',
#   'scores': '4-15, 9-15, 15-9, 15-6, 12-15',
#   'player_a1': 246811,
#   'player_a2': 242138,
#   'player_b1': 279520,
#   'player_b2': 242227},
#  {'_id': ObjectId('661120a4f4ff2c25467a34aa'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-20T00:00:00',
#   'scores': '15-10, 15-12, 10-15, 15-12',
#   'player_a1': 298782,
#   'player_a2': 279520,
#   'player_b1': 246675,
#   'player_b2': 246021},
#  {'_id': ObjectId('661120a4f4ff2c25467a34ab'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-20T00:00:00',
#   'scores': '7-15, 9-15, 9-15',
#   'player_a1': 246811,
#   'player_a2': 242138,
#   'player_b1': 1000000289,
#   'player_b2': 246930},
#  {'_id': ObjectId('661120a4f4ff2c25467a34ac'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-13T00:00:00',
#   'scores': '11-0, 11-0, 11-0',
#   'player_a1': 271931,
#   'player_a2': 246930,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('661120a4f4ff2c25467a34ad'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-13T00:00:00',
#   'scores': '11-0, 11-0, 11-0',
#   'player_a1': 0,
#   'player_a2': 0,
#   'player_b1': 71931,
#   'player_b2': 246811},
#  {'_id': ObjectId('661120a4f4ff2c25467a34ae'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-16T00:00:00',
#   'scores': '12-15, 15-13, 15-12, 15-9',
#   'player_a1': 298782,
#   'player_a2': 246930,
#   'player_b1': 246021,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120a4f4ff2c25467a34af'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-16T00:00:00',
#   'scores': '15-12, 15-12, 15-13',
#   'player_a1': 381524,
#   'player_a2': 246931,
#   'player_b1': 381524,
#   'player_b2': 242310},
#  {'_id': ObjectId('661120a4f4ff2c25467a34b0'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-09T00:00:00',
#   'scores': '15-11, 15-8, 15-11',
#   'player_a1': 242227,
#   'player_a2': 279520,
#   'player_b1': 298782,
#   'player_b2': 246930},
#  {'_id': ObjectId('661120a4f4ff2c25467a34b1'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-09T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 246811,
#   'player_a2': 242138,
#   'player_b1': 167417,
#   'player_b2': 246824},
#  {'_id': ObjectId('661120a4f4ff2c25467a34b2'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-18T00:00:00',
#   'scores': '15-9, 15-11, 15-12',
#   'player_a1': 72487,
#   'player_a2': 246824,
#   'player_b1': 271931,
#   'player_b2': 246930},
#  {'_id': ObjectId('661120a4f4ff2c25467a34b3'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-18T00:00:00',
#   'scores': '15-11, 15-5, 10-15, 9-15, 12-15',
#   'player_a1': 246811,
#   'player_a2': 242138,
#   'player_b1': 242227,
#   'player_b2': 279520},
#  {'_id': ObjectId('661120a4f4ff2c25467a34b4'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-04T00:00:00',
#   'scores': '12-15, 7-15, 9-15',
#   'player_a1': 246777,
#   'player_a2': 242227,
#   'player_b1': 72487,
#   'player_b2': 246824},
#  {'_id': ObjectId('661120a4f4ff2c25467a34b5'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-10-28T00:00:00',
#   'scores': '12-15, 15-12, 15-14, 15-13',
#   'player_a1': 246930,
#   'player_a2': 271931,
#   'player_b1': 242227,
#   'player_b2': 279520},
#  {'_id': ObjectId('661120a4f4ff2c25467a34b6'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-30T00:00:00',
#   'scores': '9-15, 11-15, 8-15',
#   'player_a1': None,
#   'player_a2': 397904,
#   'player_b1': 411278,
#   'player_b2': 410878},
#  {'_id': ObjectId('661120a4f4ff2c25467a34b7'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-16T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': None,
#   'player_a2': 410672,
#   'player_b1': 251576,
#   'player_b2': 415725},
#  {'_id': ObjectId('661120a4f4ff2c25467a34b8'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-16T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 265464,
#   'player_a2': 93512,
#   'player_b1': 255885,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120a4f4ff2c25467a34b9'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-09T00:00:00',
#   'scores': '15-9, 15-9, 9-15, 9-15, 9-15',
#   'player_a1': 298492,
#   'player_a2': 410878,
#   'player_b1': 255885,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120a4f4ff2c25467a34ba'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-09T00:00:00',
#   'scores': '15-10, 12-15, 15-7, 11-15, 15-13',
#   'player_a1': 246972,
#   'player_a2': 273389,
#   'player_b1': 298930,
#   'player_b2': 1000000289},
#  {'_id': ObjectId('661120a4f4ff2c25467a34bb'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-02T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 251646,
#   'player_a2': 93465,
#   'player_b1': 93512,
#   'player_b2': 440965},
#  {'_id': ObjectId('661120a4f4ff2c25467a34bc'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-02T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 242629,
#   'player_b1': 411278,
#   'player_b2': 410878},
#  {'_id': ObjectId('661120a4f4ff2c25467a34bd'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-03-02T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 297780,
#   'player_a2': 303589,
#   'player_b1': 398145,
#   'player_b2': 271931},
#  {'_id': ObjectId('661120a4f4ff2c25467a34be'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-23T00:00:00',
#   'scores': '13-15, 15-14, 10-15, 13-15',
#   'player_a1': 246972,
#   'player_a2': 0,
#   'player_b1': 242842,
#   'player_b2': 399642},
#  {'_id': ObjectId('661120a4f4ff2c25467a34bf'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-23T00:00:00',
#   'scores': '15-10, 15-9, 8-15, 15-8',
#   'player_a1': 271931,
#   'player_a2': 256018,
#   'player_b1': 242595,
#   'player_b2': 397351},
#  {'_id': ObjectId('661120a4f4ff2c25467a34c0'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-16T00:00:00',
#   'scores': '9-15, 9-15, 9-15',
#   'player_a1': 255885,
#   'player_a2': 250672,
#   'player_b1': 72446,
#   'player_b2': 415725},
#  {'_id': ObjectId('661120a4f4ff2c25467a34c1'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-16T00:00:00',
#   'scores': '15-9, 9-15, 9-15, 9-15',
#   'player_a1': None,
#   'player_a2': 242629,
#   'player_b1': 93512,
#   'player_b2': 256046},
#  {'_id': ObjectId('661120a4f4ff2c25467a34c2'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-16T00:00:00',
#   'scores': '14-15, 12-15, 15-10, 15-14, 15-10',
#   'player_a1': 256018,
#   'player_a2': 271931,
#   'player_b1': 246972,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120a4f4ff2c25467a34c3'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-16T00:00:00',
#   'scores': '14-15, 8-15, 15-6, 8-15',
#   'player_a1': 242842,
#   'player_a2': 303589,
#   'player_b1': 397351,
#   'player_b2': 242595},
#  {'_id': ObjectId('661120a4f4ff2c25467a34c4'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-09T00:00:00',
#   'scores': '15-9, 15-9, 15-9',
#   'player_a1': 265464,
#   'player_a2': 256046,
#   'player_b1': 251781,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120a4f4ff2c25467a34c5'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-09T00:00:00',
#   'scores': '14-15, 9-15, 14-15',
#   'player_a1': 1000000289,
#   'player_a2': 271931,
#   'player_b1': 297780,
#   'player_b2': 303589},
#  {'_id': ObjectId('661120a4f4ff2c25467a34c6'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-02-02T00:00:00',
#   'scores': '14-15, 15-11, 13-15, 15-11, 12-15',
#   'player_a1': 398145,
#   'player_a2': None,
#   'player_b1': 242765,
#   'player_b2': 242595},
#  {'_id': ObjectId('661120a4f4ff2c25467a34c7'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-26T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': None,
#   'player_a2': 242629,
#   'player_b1': 250672,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120a4f4ff2c25467a34c8'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-26T00:00:00',
#   'scores': '15-14, 12-15, 13-15, 15-11, 10-15',
#   'player_a1': 93518,
#   'player_a2': 265464,
#   'player_b1': 72446,
#   'player_b2': 410878},
#  {'_id': ObjectId('661120a4f4ff2c25467a34c9'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-26T00:00:00',
#   'scores': '12-15, 15-13, 12-15, 8-15',
#   'player_a1': 256018,
#   'player_a2': 271931,
#   'player_b1': 242765,
#   'player_b2': 242595},
#  {'_id': ObjectId('661120a4f4ff2c25467a34ca'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-26T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 242842,
#   'player_a2': 71809,
#   'player_b1': 246972,
#   'player_b2': None},
#  {'_id': ObjectId('661120a4f4ff2c25467a34cb'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-19T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 13263,
#   'player_a2': 411278,
#   'player_b1': 77849,
#   'player_b2': None},
#  {'_id': ObjectId('661120a4f4ff2c25467a34cc'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-19T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 298934,
#   'player_a2': 93512,
#   'player_b1': 401706,
#   'player_b2': 242629},
#  {'_id': ObjectId('661120a4f4ff2c25467a34cd'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-19T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': None,
#   'player_a2': None,
#   'player_b1': 298930,
#   'player_b2': 256142},
#  {'_id': ObjectId('661120a4f4ff2c25467a34ce'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-19T00:00:00',
#   'scores': '15-12, 14-15, 13-15, 15-9, 15-12',
#   'player_a1': 242765,
#   'player_a2': 242595,
#   'player_b1': 297780,
#   'player_b2': 397343},
#  {'_id': ObjectId('661120a4f4ff2c25467a34cf'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-12T00:00:00',
#   'scores': '15-14, 15-11, 14-15, 14-15, 7-15',
#   'player_a1': 246256,
#   'player_a2': 398195,
#   'player_b1': 242629,
#   'player_b2': None},
#  {'_id': ObjectId('661120a4f4ff2c25467a34d0'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-12T00:00:00',
#   'scores': '9-15, 5-15, 12-15',
#   'player_a1': 242842,
#   'player_a2': 71809,
#   'player_b1': 256018,
#   'player_b2': 271931},
#  {'_id': ObjectId('661120a4f4ff2c25467a34d1'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-05T00:00:00',
#   'scores': '9-15, 15-9, 15-9, 15-9',
#   'player_a1': 440965,
#   'player_a2': 265464,
#   'player_b1': 72446,
#   'player_b2': 411278},
#  {'_id': ObjectId('661120a4f4ff2c25467a34d2'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2022-01-05T00:00:00',
#   'scores': '12-15, 12-15, 15-14, 11-15',
#   'player_a1': 246972,
#   'player_a2': None,
#   'player_b1': 297780,
#   'player_b2': 303589},
#  {'_id': ObjectId('661120a4f4ff2c25467a34d3'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-15T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': None,
#   'player_a2': None,
#   'player_b1': 250760,
#   'player_b2': 298934},
#  {'_id': ObjectId('661120a4f4ff2c25467a34d4'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-15T00:00:00',
#   'scores': '15-13, 15-14, 8-15, 15-14',
#   'player_a1': 415725,
#   'player_a2': 411278,
#   'player_b1': 255885,
#   'player_b2': 77849},
#  {'_id': ObjectId('661120a4f4ff2c25467a34d5'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-15T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': 246972,
#   'player_a2': None,
#   'player_b1': 256018,
#   'player_b2': None},
#  {'_id': ObjectId('661120a4f4ff2c25467a34d6'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-15T00:00:00',
#   'scores': '11-15, 15-11, 15-6, 15-4',
#   'player_a1': 242842,
#   'player_a2': 71809,
#   'player_b1': 242765,
#   'player_b2': 242595},
#  {'_id': ObjectId('661120a4f4ff2c25467a34d7'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-08T00:00:00',
#   'scores': '15-10, 15-10, 10-15, 10-15, 10-15',
#   'player_a1': 255885,
#   'player_a2': None,
#   'player_b1': 250760,
#   'player_b2': 265464},
#  {'_id': ObjectId('661120a4f4ff2c25467a34d8'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-08T00:00:00',
#   'scores': '8-15, 14-15, 7-15',
#   'player_a1': 298930,
#   'player_a2': 242869,
#   'player_b1': 242842,
#   'player_b2': 397343},
#  {'_id': ObjectId('661120a4f4ff2c25467a34d9'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-12-08T00:00:00',
#   'scores': '15-14, 10-15, 12-15, 15-7, 14-15',
#   'player_a1': 397370,
#   'player_a2': 242595,
#   'player_b1': 246972,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120a4f4ff2c25467a34da'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-17T00:00:00',
#   'scores': '15-8, 8-15, 15-7, 15-6',
#   'player_a1': 397343,
#   'player_a2': 71809,
#   'player_b1': None,
#   'player_b2': 397297},
#  {'_id': ObjectId('661120a4f4ff2c25467a34db'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-17T00:00:00',
#   'scores': '15-10, 15-11, 15-9',
#   'player_a1': 397351,
#   'player_a2': 397370,
#   'player_b1': 386262,
#   'player_b2': 256142},
#  {'_id': ObjectId('661120a4f4ff2c25467a34dc'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-10T00:00:00',
#   'scores': '15-6, 15-5, 13-15, 15-13',
#   'player_a1': 255885,
#   'player_a2': 93465,
#   'player_b1': 246256,
#   'player_b2': 397422},
#  {'_id': ObjectId('661120a4f4ff2c25467a34dd'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-10T00:00:00',
#   'scores': '15-4, 15-4, 15-13',
#   'player_a1': 398145,
#   'player_a2': 271931,
#   'player_b1': None,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120a4f4ff2c25467a34de'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-11-10T00:00:00',
#   'scores': '12-15, 15-14, 15-11, 15-13',
#   'player_a1': 310387,
#   'player_a2': 242595,
#   'player_b1': 297780,
#   'player_b2': 247283},
#  {'_id': ObjectId('661120a4f4ff2c25467a34df'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-10-27T00:00:00',
#   'scores': '9-15, 9-15, 15-9, 15-9, 15-9',
#   'player_a1': None,
#   'player_a2': 242138,
#   'player_b1': 71809,
#   'player_b2': 242842},
#  {'_id': ObjectId('661120a4f4ff2c25467a34e0'),
#   'event_name': 'Random League',
#   'type': 'League',
#   'date': '2021-10-27T00:00:00',
#   'scores': '15-12, 15-13, 11-15, 15-6',
#   'player_a1': 397351,
#   'player_a2': 242595,
#   'player_b1': 256018,
#   'player_b2': 256142},
#  {'_id': ObjectId('661120d2992c23c0910df530'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-16T00:00:00',
#   'scores': '15-9,15-13,15-9',
#   'player_a1': 251646,
#   'player_a2': 398904,
#   'player_b1': 255882,
#   'player_b2': 263492},
#  {'_id': ObjectId('661120d2992c23c0910df531'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-15T00:00:00',
#   'scores': '15-11,11-15,7-15,15-14,15-12',
#   'player_a1': 382735,
#   'player_a2': 415725,
#   'player_b1': 64414,
#   'player_b2': 404094},
#  {'_id': ObjectId('661120d2992c23c0910df532'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-16T00:00:00',
#   'scores': '13-15,15-4,15-8,15-9',
#   'player_a1': 78826,
#   'player_a2': 77849,
#   'player_b1': 410672,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120d2992c23c0910df533'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '15-10,15-4,15-4',
#   'player_a1': 400794,
#   'player_a2': 72670,
#   'player_b1': 72446,
#   'player_b2': 256029},
#  {'_id': ObjectId('661120d2992c23c0910df534'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '15-9,15-11,15-12',
#   'player_a1': 251646,
#   'player_a2': 398904,
#   'player_b1': 382735,
#   'player_b2': 415725},
#  {'_id': ObjectId('661120d2992c23c0910df535'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-9,12-15,15-7,15-12',
#   'player_a1': 78826,
#   'player_a2': 77849,
#   'player_b1': 72446,
#   'player_b2': 256029},
#  {'_id': ObjectId('661120d2992c23c0910df536'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-19T00:00:00',
#   'scores': '15-12,15-14,15-7',
#   'player_a1': 251646,
#   'player_a2': 398904,
#   'player_b1': 72446,
#   'player_b2': 256029},
#  {'_id': ObjectId('661120d2992c23c0910df537'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-0,15-0,14-15,15-0',
#   'player_a1': 255882,
#   'player_a2': 263492,
#   'player_b1': 64414,
#   'player_b2': 404094},
#  {'_id': ObjectId('661120d2992c23c0910df538'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-8,15-7,15-10',
#   'player_a1': 410672,
#   'player_a2': 93465,
#   'player_b1': 400794,
#   'player_b2': 72670},
#  {'_id': ObjectId('661120d2992c23c0910df539'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-19T00:00:00',
#   'scores': '',
#   'player_a1': 255882,
#   'player_a2': 263492,
#   'player_b1': 410672,
#   'player_b2': 93465},
#  {'_id': ObjectId('661120d2992c23c0910df53a'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-15T00:00:00',
#   'scores': '',
#   'player_a1': 72487,
#   'player_a2': 242227,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('661120d2992c23c0910df53b'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '7-15,7-15,15-10,15-11,15-9',
#   'player_a1': 246824,
#   'player_a2': 280973,
#   'player_b1': 174510,
#   'player_b2': 271931},
#  {'_id': ObjectId('661120d2992c23c0910df53c'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-15T00:00:00',
#   'scores': '15-4,15-7,15-7',
#   'player_a1': 398968,
#   'player_a2': 323011,
#   'player_b1': 279520,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120d2992c23c0910df53d'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-16T00:00:00',
#   'scores': '15-9,15-7,15-3',
#   'player_a1': 328787,
#   'player_a2': 71931,
#   'player_b1': 397037,
#   'player_b2': 246843},
#  {'_id': ObjectId('661120d2992c23c0910df53e'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-7,15-11,11-15,15-12',
#   'player_a1': 72487,
#   'player_a2': 242227,
#   'player_b1': 174510,
#   'player_b2': 271931},
#  {'_id': ObjectId('661120d2992c23c0910df53f'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-13,10-15,15-11,15-5',
#   'player_a1': 398968,
#   'player_a2': 323011,
#   'player_b1': 397037,
#   'player_b2': 246843},
#  {'_id': ObjectId('661120d2992c23c0910df540'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-19T00:00:00',
#   'scores': '15-7,13-15,15-4,15-6',
#   'player_a1': 72487,
#   'player_a2': 242227,
#   'player_b1': 397037,
#   'player_b2': 246843},
#  {'_id': ObjectId('661120d2992c23c0910df541'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-15T00:00:00',
#   'scores': '',
#   'player_a1': 0,
#   'player_a2': 0,
#   'player_b1': 246824,
#   'player_b2': 280973},
#  {'_id': ObjectId('661120d2992c23c0910df542'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-13,13-15,15-14,15-5',
#   'player_a1': 279520,
#   'player_a2': 242138,
#   'player_b1': 328787,
#   'player_b2': 71931},
#  {'_id': ObjectId('661120d2992c23c0910df543'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-19T00:00:00',
#   'scores': '12-15,15-10,15-12,15-4',
#   'player_a1': 246824,
#   'player_a2': 280973,
#   'player_b1': 279520,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120d2992c23c0910df544'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '15-9,15-3,15-11',
#   'player_a1': 77849,
#   'player_a2': 280973,
#   'player_b1': 71931,
#   'player_b2': 256046},
#  {'_id': ObjectId('661120d2992c23c0910df545'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '15-14,15-8,15-13',
#   'player_a1': 167312,
#   'player_a2': 130188,
#   'player_b1': 242227,
#   'player_b2': 410672},
#  {'_id': ObjectId('661120d2992c23c0910df546'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-15T00:00:00',
#   'scores': '15-13,9-15,15-12,15-14',
#   'player_a1': 398904,
#   'player_a2': 398968,
#   'player_b1': 250672,
#   'player_b2': 217589},
#  {'_id': ObjectId('661120d2992c23c0910df547'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-17T00:00:00',
#   'scores': '14-15,15-11,15-7,15-4',
#   'player_a1': 327890,
#   'player_a2': 72670,
#   'player_b1': 255882,
#   'player_b2': 246843},
#  {'_id': ObjectId('661120d2992c23c0910df548'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-10,15-8,15-10',
#   'player_a1': 77849,
#   'player_a2': 280973,
#   'player_b1': 242227,
#   'player_b2': 410672},
#  {'_id': ObjectId('661120d2992c23c0910df549'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '8-15,15-5,13-15,15-12,15-8',
#   'player_a1': 398904,
#   'player_a2': 398968,
#   'player_b1': 255882,
#   'player_b2': 246843},
#  {'_id': ObjectId('661120d2992c23c0910df54a'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-19T00:00:00',
#   'scores': '15-12,15-11,12-15,15-14',
#   'player_a1': 77849,
#   'player_a2': 280973,
#   'player_b1': 398904,
#   'player_b2': 398968},
#  {'_id': ObjectId('661120d2992c23c0910df54b'),
#   'event_name': '2023 Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2023-11-18T00:00:00',
#   'scores': '15-12,15-9,15-6',
#   'player_a1': 71931,
#   'player_a2': 256046,
#   'player_b1': 167312,
#   'player_b2': 130188},
#  {'_id': ObjectId('661120d2992c23c0910df54c'),
# ...
#  {'_id': ObjectId('661120d2992c23c0910df6e1'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '12-15,12-15,15-14,15-9,15-11',
#   'player_a1': 397370,
#   'player_a2': 239021,
#   'player_b1': 381524,
#   'player_b2': 242842},
#  {'_id': ObjectId('661120d2992c23c0910df6e2'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '',
#   'player_a1': 410672,
#   'player_a2': 437332,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('661120d2992c23c0910df6e3'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 397370,
#   'player_a2': 303589,
#   'player_b1': 237850,
#   'player_b2': 398852},
#  {'_id': ObjectId('661120d2992c23c0910df6e4'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '9-15,15-9,15-9,15-9',
#   'player_a1': 310387,
#   'player_a2': 71809,
#   'player_b1': 325934,
#   'player_b2': 437578},
#  {'_id': ObjectId('661120d2992c23c0910df6e5'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '15-6,15-13,15-14',
#   'player_a1': 397043,
#   'player_a2': 386860,
#   'player_b1': 398008,
#   'player_b2': 254814},
#  {'_id': ObjectId('661120d2992c23c0910df6e6'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 397343,
#   'player_a2': 242765,
#   'player_b1': 71473,
#   'player_b2': 242884},
#  {'_id': ObjectId('661120d2992c23c0910df6e7'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-11,15-14,15-11',
#   'player_a1': 297880,
#   'player_a2': 436713,
#   'player_b1': 85092,
#   'player_b2': 246972},
#  {'_id': ObjectId('661120d2992c23c0910df6e8'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-8,15-5,15-12',
#   'player_a1': 399732,
#   'player_a2': 71912,
#   'player_b1': 417740,
#   'player_b2': 397297},
#  {'_id': ObjectId('661120d2992c23c0910df6e9'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '',
#   'player_a1': 0,
#   'player_a2': 0,
#   'player_b1': 245999,
#   'player_b2': 246824},
#  {'_id': ObjectId('661120d2992c23c0910df6ea'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '15-11,15-9,15-9',
#   'player_a1': 410672,
#   'player_a2': 437332,
#   'player_b1': 237850,
#   'player_b2': 398852},
#  {'_id': ObjectId('661120d2992c23c0910df6eb'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-12,4-15,15-10,9-15,15-13',
#   'player_a1': 310387,
#   'player_a2': 71809,
#   'player_b1': 398008,
#   'player_b2': 254814},
#  {'_id': ObjectId('661120d2992c23c0910df6ec'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-14,15-14,15-11',
#   'player_a1': 397343,
#   'player_a2': 242765,
#   'player_b1': 85092,
#   'player_b2': 246972},
#  {'_id': ObjectId('661120d2992c23c0910df6ed'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-11,15-14',
#   'player_a1': 399732,
#   'player_a2': 71912,
#   'player_b1': 245999,
#   'player_b2': 246824},
#  {'_id': ObjectId('661120d2992c23c0910df6ee'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-3,15-5,15-3',
#   'player_a1': 410672,
#   'player_a2': 437332,
#   'player_b1': 310387,
#   'player_b2': 71809},
#  {'_id': ObjectId('661120d2992c23c0910df6ef'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-6,15-11,11-15,15-13',
#   'player_a1': 85092,
#   'player_a2': 246972,
#   'player_b1': 399732,
#   'player_b2': 71912},
#  {'_id': ObjectId('661120d2992c23c0910df6f0'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '15-7,15-9,15-11',
#   'player_a1': 410672,
#   'player_a2': 437332,
#   'player_b1': 399732,
#   'player_b2': 71912},
#  {'_id': ObjectId('661120d2992c23c0910df6f1'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '',
#   'player_a1': 0,
#   'player_a2': 0,
#   'player_b1': 397370,
#   'player_b2': 303589},
#  {'_id': ObjectId('661120d2992c23c0910df6f2'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '15-7,15-8,15-12',
#   'player_a1': 325934,
#   'player_a2': 437578,
#   'player_b1': 397043,
#   'player_b2': 386860},
#  {'_id': ObjectId('661120d2992c23c0910df6f3'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '15-3,15-5,15-5',
#   'player_a1': 71473,
#   'player_a2': 242884,
#   'player_b1': 297880,
#   'player_b2': 436713},
#  {'_id': ObjectId('661120d2992c23c0910df6f4'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '',
#   'player_a1': 417740,
#   'player_a2': 397297,
#   'player_b1': 0,
#   'player_b2': 0},
#  {'_id': ObjectId('661120d2992c23c0910df6f5'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '15-9,15-7,12-15,15-4',
#   'player_a1': 397370,
#   'player_a2': 303589,
#   'player_b1': 245999,
#   'player_b2': 246824},
#  {'_id': ObjectId('661120d2992c23c0910df6f6'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-10,15-8,15-13',
#   'player_a1': 325934,
#   'player_a2': 437578,
#   'player_b1': 397343,
#   'player_b2': 242765},
#  {'_id': ObjectId('661120d2992c23c0910df6f7'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '',
#   'player_a1': 297880,
#   'player_a2': 436713,
#   'player_b1': 398008,
#   'player_b2': 254814},
#  {'_id': ObjectId('661120d2992c23c0910df6f8'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-6,15-10,15-6',
#   'player_a1': 417740,
#   'player_a2': 397297,
#   'player_b1': 237850,
#   'player_b2': 398852},
#  {'_id': ObjectId('661120d2992c23c0910df6f9'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '9-15,9-15,15-9,15-9,15-9',
#   'player_a1': 245999,
#   'player_a2': 246824,
#   'player_b1': 397343,
#   'player_b2': 242765},
#  {'_id': ObjectId('661120d2992c23c0910df6fa'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '',
#   'player_a1': -1,
#   'player_a2': -1,
#   'player_b1': 237850,
#   'player_b2': 398852},
#  {'_id': ObjectId('661120d2992c23c0910df6fb'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '15-7,15-6,15-13',
#   'player_a1': 397343,
#   'player_a2': 242765,
#   'player_b1': 237850,
#   'player_b2': 398852},
#  {'_id': ObjectId('661120d2992c23c0910df6fc'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '14-15,15-10,15-10,14-15,15-9',
#   'player_a1': 317416,
#   'player_a2': 242182,
#   'player_b1': 306133,
#   'player_b2': 396178},
#  {'_id': ObjectId('661120d2992c23c0910df6fd'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '15-6,15-8,15-10',
#   'player_a1': 246687,
#   'player_a2': 396299,
#   'player_b1': 298945,
#   'player_b2': 397271},
#  {'_id': ObjectId('661120d2992c23c0910df6fe'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '12-15,8-15,15-13,15-14,15-12',
#   'player_a1': 306133,
#   'player_a2': 396178,
#   'player_b1': 246687,
#   'player_b2': 396299},
#  {'_id': ObjectId('661120d2992c23c0910df6ff'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-6,15-5,15-11',
#   'player_a1': 317416,
#   'player_a2': 242182,
#   'player_b1': 298945,
#   'player_b2': 397271},
#  {'_id': ObjectId('661120d2992c23c0910df700'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-7,15-11,15-4',
#   'player_a1': 246021,
#   'player_a2': 298222,
#   'player_b1': 306133,
#   'player_b2': 396178},
#  {'_id': ObjectId('661120d2992c23c0910df701'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 246849,
#   'player_a2': 298206,
#   'player_b1': 317416,
#   'player_b2': 242182},
#  {'_id': ObjectId('661120d2992c23c0910df702'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-6,15-7,15-11',
#   'player_a1': 246021,
#   'player_a2': 298222,
#   'player_b1': 246687,
#   'player_b2': 396299},
#  {'_id': ObjectId('661120d2992c23c0910df703'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-10,15-4,15-8',
#   'player_a1': 246849,
#   'player_a2': 298206,
#   'player_b1': 298945,
#   'player_b2': 397271},
#  {'_id': ObjectId('661120d2992c23c0910df704'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': 246182,
#   'player_b2': 250760},
#  {'_id': ObjectId('661120d2992c23c0910df705'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 423651,
#   'player_a2': 330944,
#   'player_b1': 297721,
#   'player_b2': 280973},
#  {'_id': ObjectId('661120d2992c23c0910df706'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-6,15-11,15-10',
#   'player_a1': 410672,
#   'player_a2': 246930,
#   'player_b1': 323678,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120d2992c23c0910df707'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-10,15-9,15-11',
#   'player_a1': 244338,
#   'player_a2': 399111,
#   'player_b1': 398904,
#   'player_b2': 279520},
#  {'_id': ObjectId('661120d2992c23c0910df708'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-12,15-6,15-14',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': 297721,
#   'player_b2': 280973},
#  {'_id': ObjectId('661120d2992c23c0910df709'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '',
#   'player_a1': 410672,
#   'player_a2': 246930,
#   'player_b1': 398904,
#   'player_b2': 279520},
#  {'_id': ObjectId('661120d2992c23c0910df70a'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': -1,
#   'player_b2': -1},
#  {'_id': ObjectId('661120d2992c23c0910df70b'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '9-15,15-9,15-9,15-9',
#   'player_a1': 246182,
#   'player_a2': 250760,
#   'player_b1': 423651,
#   'player_b2': 330944},
#  {'_id': ObjectId('661120d2992c23c0910df70c'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '5-15,15-9,15-12,15-12',
#   'player_a1': 323678,
#   'player_a2': 242138,
#   'player_b1': 244338,
#   'player_b2': 399111},
#  {'_id': ObjectId('661120d2992c23c0910df70d'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '15-10,15-7,15-6',
#   'player_a1': 423651,
#   'player_a2': 330944,
#   'player_b1': 244338,
#   'player_b2': 399111},
#  {'_id': ObjectId('661120d2992c23c0910df70e'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': 246182,
#   'player_b2': 250760},
#  {'_id': ObjectId('661120d2992c23c0910df70f'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-9,15-9,15-9',
#   'player_a1': 423651,
#   'player_a2': 330944,
#   'player_b1': 297721,
#   'player_b2': 280973},
#  {'_id': ObjectId('661120d2992c23c0910df710'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-23T00:00:00',
#   'scores': '15-6,15-11,15-10',
#   'player_a1': 410672,
#   'player_a2': 246930,
#   'player_b1': 323678,
#   'player_b2': 242138},
#  {'_id': ObjectId('661120d2992c23c0910df711'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-24T00:00:00',
#   'scores': '15-10,15-9,15-11',
#   'player_a1': 244338,
#   'player_a2': 399111,
#   'player_b1': 398904,
#   'player_b2': 279520},
#  {'_id': ObjectId('661120d2992c23c0910df712'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '15-12,15-6,15-14',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': 297721,
#   'player_b2': 280973},
#  {'_id': ObjectId('661120d2992c23c0910df713'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-26T00:00:00',
#   'scores': '',
#   'player_a1': 410672,
#   'player_a2': 246930,
#   'player_b1': 398904,
#   'player_b2': 279520},
#  {'_id': ObjectId('661120d2992c23c0910df714'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '',
#   'player_a1': 242227,
#   'player_a2': 77849,
#   'player_b1': -1,
#   'player_b2': -1},
#  {'_id': ObjectId('661120d2992c23c0910df715'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '9-15,15-9,15-9,15-9',
#   'player_a1': 246182,
#   'player_a2': 250760,
#   'player_b1': 423651,
#   'player_b2': 330944},
#  {'_id': ObjectId('661120d2992c23c0910df716'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-25T00:00:00',
#   'scores': '5-15,15-9,15-12,15-12',
#   'player_a1': 323678,
#   'player_a2': 242138,
#   'player_b1': 244338,
#   'player_b2': 399111},
#  {'_id': ObjectId('661120d2992c23c0910df717'),
#   'event_name': 'Western Canadian Doubles Squash Championships',
#   'type': 'Tournament',
#   'date': '2022-11-27T00:00:00',
#   'scores': '15-10,15-7,15-6',
#   'player_a1': 423651,
#   'player_a2': 330944,
#   'player_b1': 244338,
#   'player_b2': 399111}]

# %%
matches_df = pd.DataFrame(matches_list)

# %%
matches_df
# Out:
#                           _id                                     event_name  \
# 0    661120a4f4ff2c25467a344b                                  Random League
# 1    661120a4f4ff2c25467a344c                                  Random League
# 2    661120a4f4ff2c25467a344d                                  Random League
# 3    661120a4f4ff2c25467a344e                                  Random League
# 4    661120a4f4ff2c25467a344f                                  Random League
# ..                        ...                                            ...
# 633  661120d2992c23c0910df713  Western Canadian Doubles Squash Championships
# 634  661120d2992c23c0910df714  Western Canadian Doubles Squash Championships
# 635  661120d2992c23c0910df715  Western Canadian Doubles Squash Championships
# 636  661120d2992c23c0910df716  Western Canadian Doubles Squash Championships
# 637  661120d2992c23c0910df717  Western Canadian Doubles Squash Championships
#
#            type                 date                            scores  \
# 0        League  2023-07-20T00:00:00                10-15, 7-15, 10-15
# 1        League  2023-07-20T00:00:00                  9-15, 9-15, 9-15
# 2        League  2023-07-13T00:00:00  15-14, 4-15, 11-15, 15-11, 10-15
# 3        League  2023-07-06T00:00:00      9-15, 9-15, 15-9, 15-9, 15-9
# 4        League  2023-06-29T00:00:00            9-15, 15-9, 15-9, 15-9
# ..          ...                  ...                               ...
# 633  Tournament  2022-11-26T00:00:00
# 634  Tournament  2022-11-27T00:00:00
# 635  Tournament  2022-11-25T00:00:00               9-15,15-9,15-9,15-9
# 636  Tournament  2022-11-25T00:00:00             5-15,15-9,15-12,15-12
# 637  Tournament  2022-11-27T00:00:00                   15-10,15-7,15-6
#
#      player_a1  player_a2  player_b1  player_b2
# 0     397238.0        NaN   397370.0   385805.0
# 1     396299.0   386742.0   397348.0   399783.0
# 2     247259.0   246931.0   397370.0   303589.0
# 3     399783.0   385805.0   246849.0   303555.0
# 4      85092.0   397348.0    70354.0   396178.0
# ..         ...        ...        ...        ...
# 633   410672.0   246930.0   398904.0   279520.0
# 634   242227.0    77849.0       -1.0       -1.0
# 635   246182.0   250760.0   423651.0   330944.0
# 636   323678.0   242138.0   244338.0   399111.0
# 637   423651.0   330944.0   244338.0   399111.0
#
# [638 rows x 9 columns]

# %% [markdown]
# ### Merge matches and players

# %%
for col in matches_df.columns:
    print("{col} colunm has {nullcount} null values".format(col=col, nullcount=matches_df[col].isna().sum()))
# Out:
# _id colunm has 0 null values
# event_name colunm has 0 null values
# type colunm has 0 null values
# date colunm has 0 null values
# scores colunm has 0 null values
# player_a1 colunm has 15 null values
# player_a2 colunm has 10 null values
# player_b1 colunm has 10 null values
# player_b2 colunm has 6 null values

# %%
# First drop NaN player IDs
matches_df = matches_df.dropna(subset=["player_a1", "player_a2", "player_b1", "player_b2"])

# %%
for col in players_df.columns:
    print("{col} colunm has {nullcount} null values".format(col=col, nullcount=players_df[col].isna().sum()))
# Out:
# _id colunm has 0 null values
# fname colunm has 0 null values
# lname colunm has 0 null values
# gender colunm has 0 null values
# age colunm has 0 null values
# ratings colunm has 0 null values

# %%
merged_df = pd.merge(matches_df, players_df, left_on=["player_a1"], right_on=["_id"], how="inner") \
                .drop(columns=["_id_x", "_id_y"]) \
                .rename(columns={
                    "ratings": "player_a1_ratings",
                    "gender": "player_a1_gender",
                    "age": "player_a1_age",
                })
merged_df["player_a1_name"] = merged_df["fname"] + " " + merged_df["lname"]
merged_df.drop(columns=["fname", "lname", "player_a1"], inplace=True)

# %%
merged_df = pd.merge(merged_df, players_df, left_on=["player_a2"], right_on=["_id"], how="inner") \
                .drop(columns=["_id"]) \
                .rename(columns={
                    "ratings": "player_a2_ratings",
                    "gender": "player_a2_gender",
                    "age": "player_a2_age",
                })
merged_df["player_a2_name"] = merged_df["fname"] + " " + merged_df["lname"]
merged_df.drop(columns=["fname", "lname", "player_a2"], inplace=True)

# %%
merged_df = pd.merge(merged_df, players_df, left_on=["player_b1"], right_on=["_id"], how="inner") \
                .drop(columns=["_id"]) \
                .rename(columns={
                    "ratings": "player_b1_ratings",
                    "gender": "player_b1_gender",
                    "age": "player_b1_age",
                })
merged_df["player_b1_name"] = merged_df["fname"] + " " + merged_df["lname"]
merged_df.drop(columns=["fname", "lname", "player_b1"], inplace=True)

# %%
merged_df = pd.merge(merged_df, players_df, left_on=["player_b2"], right_on=["_id"], how="inner") \
                .drop(columns=["_id"]) \
                .rename(columns={
                    "ratings": "player_b2_ratings",
                    "gender": "player_b2_gender",
                    "age": "player_b2_age",
                })
merged_df["player_b2_name"] = merged_df["fname"] + " " + merged_df["lname"]
merged_df.drop(columns=["fname", "lname", "player_b2"], inplace=True)

# %%
merged_df
# Out:
#                                             event_name        type  \
# 0                                        Random League      League
# 1           Evergreen Summer Doubles Squash Tournament  Tournament
# 2           Evergreen Summer Doubles Squash Tournament  Tournament
# 3    2023 Western Canadian Doubles Squash Champions...  Tournament
# 4    2023 Western Canadian Doubles Squash Champions...  Tournament
# ..                                                 ...         ...
# 389         Evergreen Summer Doubles Squash Tournament  Tournament
# 390         Evergreen Summer Doubles Squash Tournament  Tournament
# 391      Western Canadian Doubles Squash Championships  Tournament
# 392         Evergreen Summer Doubles Squash Tournament  Tournament
# 393  Hillside Wealth Management 2023 BC Doubles Cha...  Tournament
#
#                     date                         scores player_a1_gender  \
# 0    2023-07-20T00:00:00               9-15, 9-15, 9-15            women
# 1    2023-06-22T00:00:00                 15-6,15-6,15-9              men
# 2    2023-06-24T00:00:00                15-11,15-8,15-8            women
# 3    2023-11-16T00:00:00         15-12,15-13,14-15,15-5              men
# 4    2023-11-16T00:00:00         15-12,15-13,14-15,15-5              men
# ..                   ...                            ...              ...
# 389  2023-06-22T00:00:00  15-12,12-15,14-15,15-14,15-10              men
# 390  2023-06-22T00:00:00                15-9,15-7,15-10              men
# 391  2022-11-23T00:00:00                15-8,15-5,15-12              men
# 392  2023-06-23T00:00:00    15-8,10-15,10-15,15-12,15-9              men
# 393  2023-03-08T00:00:00                15-9,15-14,15-8              men
#
#     player_a1_age                                  player_a1_ratings  \
# 0             30+  [{'category': 'singles', 'rating': 3.51, 'rank...
# 1             60+  [{'category': 'doubles', 'rating': 4.45, 'rank...
# 2             60+  [{'category': 'singles', 'rating': 3.68, 'rank...
# 3             50+  [{'category': 'singles', 'rating': 4.74, 'rank...
# 4             50+  [{'category': 'singles', 'rating': 4.74, 'rank...
# ..            ...                                                ...
# 389           25+  [{'category': 'singles', 'rating': 6.53, 'rank...
# 390           45+  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 391           45+  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 392           40+  [{'category': 'singles', 'rating': 3.78, 'rank...
# 393           45+  [{'category': 'doubles', 'rating': 5.06, 'rank...
#
#              player_a1_name player_a2_gender player_a2_age  \
# 0                 Zhelin Bu              men           65+
# 1            Dennis Forsman            women           65+
# 2          Annette Johanson              men           65+
# 3                Mark Levey              men           50+
# 4                Mark Levey              men           50+
# ..                      ...              ...           ...
# 389  Guillermo Cortes-Ortiz              men           25+
# 390                Mike Lee              men           55+
# 391                Mike Lee              men           55+
# 392          Roman Razenkov              men           40+
# 393              Gary Evans              men           40+
#
#                                      player_a2_ratings    player_a2_name  \
# 0    [{'category': 'doubles', 'rating': 1.98, 'rank...        Ernie Chan
# 1    [{'category': 'doubles', 'rating': 2.01, 'rank...  Pamela Brunswick
# 2    [{'category': 'doubles', 'rating': 2.3, 'ranki...    Richard Dustan
# 3    [{'category': 'singles', 'rating': 4.87, 'rank...        Jongho Kim
# 4    [{'category': 'singles', 'rating': 4.87, 'rank...        Jongho Kim
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.73, 'rank...    Eduardo Flores
# 390  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 391  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 392  [{'category': 'singles', 'rating': 3.39, 'rank...     Andrew Lavrov
# 393  [{'category': 'doubles', 'rating': 1.75, 'rank...      Jon De Souza
#
#     player_b1_gender player_b1_age  \
# 0                men           60+
# 1              women           60+
# 2              women           60+
# 3                men           55+
# 4                men           55+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           30+
# 392              men           65+
# 393              men           40+
#
#                                      player_b1_ratings    player_b1_name  \
# 0    [{'category': 'doubles', 'rating': 3.09, 'rank...      Ian Binstead
# 1    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 2    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 3    [{'category': 'singles', 'rating': 4.88, 'rank...      Mike Carrier
# 4    [{'category': 'singles', 'rating': 4.88, 'rank...      Mike Carrier
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 4.97, 'rank...     Patrick Frost
# 390  [{'category': 'singles', 'rating': 5.4, 'ranki...      Duncan Genge
# 391  [{'category': 'singles', 'rating': 4.51, 'rank...   Thomas Charlton
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Robert Bulger
# 393  [{'category': 'singles', 'rating': 4.77, 'rank...      Deepak Hayer
#
#     player_b2_gender player_b2_age  \
# 0                men           35+
# 1                men           35+
# 2                men           35+
# 3                men           35+
# 4                men           35+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           65+
# 392              men           75+
# 393              men           25+
#
#                                      player_b2_ratings    player_b2_name
# 0    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 1    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 2    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 3    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 4    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.74, 'rank...  Farzin Habibpour
# 390  [{'category': 'singles', 'rating': 4.62, 'rank...       Cole Parmar
# 391  [{'category': 'doubles', 'rating': 2.93, 'rank...    Warren Woodman
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Victor Tanaka
# 393  [{'category': 'singles', 'rating': 5.34, 'rank...        Jason Daou
#
# [394 rows x 20 columns]

# %%
merged_df["date"] = pd.to_datetime(merged_df["date"])

# %% [markdown]
# #### Basic stats

# %%
# Date spread
print(merged_df["date"].min(), merged_df["date"].max())
# Out:
# 2021-10-27 00:00:00 2023-11-19 00:00:00

# %%
# Counts of tournaments and league matches
for type_ in merged_df["type"].unique():
    print("{type_} : {count}".format(type_=type_, count=len(merged_df[merged_df["type"]==type_])))
# Out:
# League : 106
# Tournament : 288

# %%
merged_df
# Out:
#                                             event_name        type       date  \
# 0                                        Random League      League 2023-07-20
# 1           Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 2           Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-24
# 3    2023 Western Canadian Doubles Squash Champions...  Tournament 2023-11-16
# 4    2023 Western Canadian Doubles Squash Champions...  Tournament 2023-11-16
# ..                                                 ...         ...        ...
# 389         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 390         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 391      Western Canadian Doubles Squash Championships  Tournament 2022-11-23
# 392         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-23
# 393  Hillside Wealth Management 2023 BC Doubles Cha...  Tournament 2023-03-08
#
#                             scores player_a1_gender player_a1_age  \
# 0                 9-15, 9-15, 9-15            women           30+
# 1                   15-6,15-6,15-9              men           60+
# 2                  15-11,15-8,15-8            women           60+
# 3           15-12,15-13,14-15,15-5              men           50+
# 4           15-12,15-13,14-15,15-5              men           50+
# ..                             ...              ...           ...
# 389  15-12,12-15,14-15,15-14,15-10              men           25+
# 390                15-9,15-7,15-10              men           45+
# 391                15-8,15-5,15-12              men           45+
# 392    15-8,10-15,10-15,15-12,15-9              men           40+
# 393                15-9,15-14,15-8              men           45+
#
#                                      player_a1_ratings  \
# 0    [{'category': 'singles', 'rating': 3.51, 'rank...
# 1    [{'category': 'doubles', 'rating': 4.45, 'rank...
# 2    [{'category': 'singles', 'rating': 3.68, 'rank...
# 3    [{'category': 'singles', 'rating': 4.74, 'rank...
# 4    [{'category': 'singles', 'rating': 4.74, 'rank...
# ..                                                 ...
# 389  [{'category': 'singles', 'rating': 6.53, 'rank...
# 390  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 391  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 392  [{'category': 'singles', 'rating': 3.78, 'rank...
# 393  [{'category': 'doubles', 'rating': 5.06, 'rank...
#
#              player_a1_name player_a2_gender player_a2_age  \
# 0                 Zhelin Bu              men           65+
# 1            Dennis Forsman            women           65+
# 2          Annette Johanson              men           65+
# 3                Mark Levey              men           50+
# 4                Mark Levey              men           50+
# ..                      ...              ...           ...
# 389  Guillermo Cortes-Ortiz              men           25+
# 390                Mike Lee              men           55+
# 391                Mike Lee              men           55+
# 392          Roman Razenkov              men           40+
# 393              Gary Evans              men           40+
#
#                                      player_a2_ratings    player_a2_name  \
# 0    [{'category': 'doubles', 'rating': 1.98, 'rank...        Ernie Chan
# 1    [{'category': 'doubles', 'rating': 2.01, 'rank...  Pamela Brunswick
# 2    [{'category': 'doubles', 'rating': 2.3, 'ranki...    Richard Dustan
# 3    [{'category': 'singles', 'rating': 4.87, 'rank...        Jongho Kim
# 4    [{'category': 'singles', 'rating': 4.87, 'rank...        Jongho Kim
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.73, 'rank...    Eduardo Flores
# 390  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 391  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 392  [{'category': 'singles', 'rating': 3.39, 'rank...     Andrew Lavrov
# 393  [{'category': 'doubles', 'rating': 1.75, 'rank...      Jon De Souza
#
#     player_b1_gender player_b1_age  \
# 0                men           60+
# 1              women           60+
# 2              women           60+
# 3                men           55+
# 4                men           55+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           30+
# 392              men           65+
# 393              men           40+
#
#                                      player_b1_ratings    player_b1_name  \
# 0    [{'category': 'doubles', 'rating': 3.09, 'rank...      Ian Binstead
# 1    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 2    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 3    [{'category': 'singles', 'rating': 4.88, 'rank...      Mike Carrier
# 4    [{'category': 'singles', 'rating': 4.88, 'rank...      Mike Carrier
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 4.97, 'rank...     Patrick Frost
# 390  [{'category': 'singles', 'rating': 5.4, 'ranki...      Duncan Genge
# 391  [{'category': 'singles', 'rating': 4.51, 'rank...   Thomas Charlton
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Robert Bulger
# 393  [{'category': 'singles', 'rating': 4.77, 'rank...      Deepak Hayer
#
#     player_b2_gender player_b2_age  \
# 0                men           35+
# 1                men           35+
# 2                men           35+
# 3                men           35+
# 4                men           35+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           65+
# 392              men           75+
# 393              men           25+
#
#                                      player_b2_ratings    player_b2_name
# 0    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 1    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 2    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 3    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 4    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.74, 'rank...  Farzin Habibpour
# 390  [{'category': 'singles', 'rating': 4.62, 'rank...       Cole Parmar
# 391  [{'category': 'doubles', 'rating': 2.93, 'rank...    Warren Woodman
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Victor Tanaka
# 393  [{'category': 'singles', 'rating': 5.34, 'rank...        Jason Daou
#
# [394 rows x 20 columns]

# %%
merged_df["scores"]
# Out:
# 0                   9-15, 9-15, 9-15
# 1                     15-6,15-6,15-9
# 2                    15-11,15-8,15-8
# 3             15-12,15-13,14-15,15-5
# 4             15-12,15-13,14-15,15-5
#                    ...
# 389    15-12,12-15,14-15,15-14,15-10
# 390                  15-9,15-7,15-10
# 391                  15-8,15-5,15-12
# 392      15-8,10-15,10-15,15-12,15-9
# 393                  15-9,15-14,15-8
# Name: scores, Length: 394, dtype: object

# %%
# Convert into array of scores
def convert_to_score_array(val):
    # Split by space and append to array
    arr = []
    if type(val) == str:
        for score in val.split(", "):
            arr.append(score)
    elif type(val) == datetime.datetime:
        arr.append(val)
    return arr

# %%
def convert_to_game_score(values):
    temp = []
    for val in values:
        if type(val) == datetime:
            val = pd.Timestamp(val)
            # Extract month and date
            month = val.month
            day = val.day
            temp.append((int(month), int(day)))
        elif type(val) == str:
            a, b = val.split("-")
            temp.append((int(a), int(b)))
            
    return temp

# %%
merged_df["scores"] = merged_df["scores"].apply(convert_to_score_array)

# %%
def convert_to_game_score(scores):
    if len(scores) == 1: # 1 major string
        scores = scores[0]
        scores_arr = []
        if len(scores) != 0: # Empty string
            scores = scores.split(",") # scores array
            for score in scores:
                score_a, score_b = score.split("-")
                score_tuple = (int(score_a), int(score_b))
                scores_arr.append(score_tuple)
        return scores_arr
    else:
        scores_arr = []
        for score in scores:
            score_a, score_b = score.split("-")
            score_tuple = (int(score_a), int(score_b))
            scores_arr.append(score_tuple)
        return scores_arr

# %%
merged_df["scores"] = merged_df["scores"].apply(convert_to_game_score)

# %%
merged_df
# Out:
#                                             event_name        type       date  \
# 0                                        Random League      League 2023-07-20
# 1           Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 2           Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-24
# 3    2023 Western Canadian Doubles Squash Champions...  Tournament 2023-11-16
# 4    2023 Western Canadian Doubles Squash Champions...  Tournament 2023-11-16
# ..                                                 ...         ...        ...
# 389         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 390         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-22
# 391      Western Canadian Doubles Squash Championships  Tournament 2022-11-23
# 392         Evergreen Summer Doubles Squash Tournament  Tournament 2023-06-23
# 393  Hillside Wealth Management 2023 BC Doubles Cha...  Tournament 2023-03-08
#
#                                                 scores player_a1_gender  \
# 0                          [(9, 15), (9, 15), (9, 15)]            women
# 1                          [(15, 6), (15, 6), (15, 9)]              men
# 2                         [(15, 11), (15, 8), (15, 8)]            women
# 3              [(15, 12), (15, 13), (14, 15), (15, 5)]              men
# 4              [(15, 12), (15, 13), (14, 15), (15, 5)]              men
# ..                                                 ...              ...
# 389  [(15, 12), (12, 15), (14, 15), (15, 14), (15, ...              men
# 390                       [(15, 9), (15, 7), (15, 10)]              men
# 391                       [(15, 8), (15, 5), (15, 12)]              men
# 392   [(15, 8), (10, 15), (10, 15), (15, 12), (15, 9)]              men
# 393                       [(15, 9), (15, 14), (15, 8)]              men
#
#     player_a1_age                                  player_a1_ratings  \
# 0             30+  [{'category': 'singles', 'rating': 3.51, 'rank...
# 1             60+  [{'category': 'doubles', 'rating': 4.45, 'rank...
# 2             60+  [{'category': 'singles', 'rating': 3.68, 'rank...
# 3             50+  [{'category': 'singles', 'rating': 4.74, 'rank...
# 4             50+  [{'category': 'singles', 'rating': 4.74, 'rank...
# ..            ...                                                ...
# 389           25+  [{'category': 'singles', 'rating': 6.53, 'rank...
# 390           45+  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 391           45+  [{'category': 'doubles', 'rating': 3.42, 'rank...
# 392           40+  [{'category': 'singles', 'rating': 3.78, 'rank...
# 393           45+  [{'category': 'doubles', 'rating': 5.06, 'rank...
#
#              player_a1_name player_a2_gender player_a2_age  \
# 0                 Zhelin Bu              men           65+
# 1            Dennis Forsman            women           65+
# 2          Annette Johanson              men           65+
# 3                Mark Levey              men           50+
# 4                Mark Levey              men           50+
# ..                      ...              ...           ...
# 389  Guillermo Cortes-Ortiz              men           25+
# 390                Mike Lee              men           55+
# 391                Mike Lee              men           55+
# 392          Roman Razenkov              men           40+
# 393              Gary Evans              men           40+
#
#                                      player_a2_ratings    player_a2_name  \
# 0    [{'category': 'doubles', 'rating': 1.98, 'rank...        Ernie Chan
# 1    [{'category': 'doubles', 'rating': 2.01, 'rank...  Pamela Brunswick
# 2    [{'category': 'doubles', 'rating': 2.3, 'ranki...    Richard Dustan
# 3    [{'category': 'singles', 'rating': 4.87, 'rank...        Jongho Kim
# 4    [{'category': 'singles', 'rating': 4.87, 'rank...        Jongho Kim
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.73, 'rank...    Eduardo Flores
# 390  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 391  [{'category': 'singles', 'rating': 4.28, 'rank...      Mike Neilson
# 392  [{'category': 'singles', 'rating': 3.39, 'rank...     Andrew Lavrov
# 393  [{'category': 'doubles', 'rating': 1.75, 'rank...      Jon De Souza
#
#     player_b1_gender player_b1_age  \
# 0                men           60+
# 1              women           60+
# 2              women           60+
# 3                men           55+
# 4                men           55+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           30+
# 392              men           65+
# 393              men           40+
#
#                                      player_b1_ratings    player_b1_name  \
# 0    [{'category': 'doubles', 'rating': 3.09, 'rank...      Ian Binstead
# 1    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 2    [{'category': 'doubles', 'rating': 1.99, 'rank...  Joanne Ditommaso
# 3    [{'category': 'singles', 'rating': 4.88, 'rank...      Mike Carrier
# 4    [{'category': 'singles', 'rating': 4.88, 'rank...      Mike Carrier
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 4.97, 'rank...     Patrick Frost
# 390  [{'category': 'singles', 'rating': 5.4, 'ranki...      Duncan Genge
# 391  [{'category': 'singles', 'rating': 4.51, 'rank...   Thomas Charlton
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Robert Bulger
# 393  [{'category': 'singles', 'rating': 4.77, 'rank...      Deepak Hayer
#
#     player_b2_gender player_b2_age  \
# 0                men           35+
# 1                men           35+
# 2                men           35+
# 3                men           35+
# 4                men           35+
# ..               ...           ...
# 389              men           30+
# 390              men           19+
# 391              men           65+
# 392              men           75+
# 393              men           25+
#
#                                      player_b2_ratings    player_b2_name
# 0    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 1    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 2    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 3    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# 4    [{'category': 'singles', 'rating': 4.17, 'rank...          Lam Uong
# ..                                                 ...               ...
# 389  [{'category': 'singles', 'rating': 5.74, 'rank...  Farzin Habibpour
# 390  [{'category': 'singles', 'rating': 4.62, 'rank...       Cole Parmar
# 391  [{'category': 'doubles', 'rating': 2.93, 'rank...    Warren Woodman
# 392  [{'category': 'doubles', 'rating': 1.5, 'ranki...     Victor Tanaka
# 393  [{'category': 'singles', 'rating': 5.34, 'rank...        Jason Daou
#
# [394 rows x 20 columns]
