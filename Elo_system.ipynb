# %%
import pandas as pd

df = pd.read_csv(r"preprocessed_2019_data.csv")

print(df)
# Out:
#       Match Date           Sport  Event Type  \
# 0     2019-03-31  doubles_squash  Club Match
# 1     2019-03-29  doubles_squash  Club Match
# 2     2019-03-28  doubles_squash      League
# 3     2019-03-28  doubles_squash      League
# 4     2019-03-28  doubles_squash      League
# ...          ...             ...         ...
# 1228  2018-04-04  doubles_squash  Tournament
# 1229  2018-04-04  doubles_squash  Tournament
# 1230  2018-04-04  doubles_squash  Tournament
# 1231  2018-04-03  doubles_squash  Club Match
# 1232  2018-04-01  doubles_squash  Club Match
#
#                              Event Name Match Status Game Scores  \
# 0               Vancouver Racquets Club       Normal     ['3-0']
# 1               Vancouver Racquets Club       Normal     ['3-0']
# 2       Vancouver Ladies Doubles League       Normal     ['1-3']
# 3       Vancouver Ladies Doubles League       Normal     ['3-1']
# 4       Vancouver Ladies Doubles League       Normal     ['3-0']
# ...                                 ...          ...         ...
# 1228  2018 Evergreen Club Championships       Normal     ['1-3']
# 1229  2018 Evergreen Club Championships       Normal     ['3-0']
# 1230  2018 Evergreen Club Championships       Normal     ['2-3']
# 1231              Evergreen Squash Club       Normal     ['3-0']
# 1232            Vancouver Racquets Club       Normal     ['3-2']
#
#              Player A1  Player A1 Squash BC Number Player A1 Gender  \
# 0      Brian Covernton                    910021.0             male
# 1          Glen McNeil                    910664.0             male
# 2       Jennifer Levey                   1003723.0           female
# 3     Annette Johanson                   1002878.0           female
# 4        Melodie Flook                    993592.0           female
# ...                ...                         ...              ...
# 1228      Dana Merritt                   1002955.0           female
# 1229    Warren Woodman                   1003063.0             male
# 1230    Matthew McAdam                   1002948.0             male
# 1231      Mike Lavigne                   1002909.0             male
# 1232    Dennis Forsman                   1003716.0             male
#
#              Player A2  Player A2 Squash BC Number Player A2 Gender  \
# 0     Bruce Macfarlane                   1003801.0             male
# 1              Rick Ng                   1004025.0             male
# 2           Angel Wong                   1001150.0           female
# 3       Olivia Maxwell                   1003677.0           female
# 4     Jillian Anderson                    993468.0           female
# ...                ...                         ...              ...
# 1228     Ashley Walker                   1003046.0           female
# 1229   Doug MacDougall                   1003151.0             male
# 1230    Richard Martin                   1002941.0             male
# 1231      Laura Ramsay                   1003186.0           female
# 1232  Bruce Macfarlane                   1003801.0             male
#
#                 Player B1  Player B1 Squash BC Number Player B1 Gender  \
# 0              Adam Jinks                   1002874.0             male
# 1         Brian Covernton                    910021.0             male
# 2               Helen Kim                   1002675.0           female
# 3     Ashley Ramsden-Wood                    993876.0           female
# 4            Ana Laureano                    977664.0           female
# ...                   ...                         ...              ...
# 1228       Paul Stevenson                   1003023.0             male
# 1229           Harry Chow                   1002730.0             male
# 1230         Juan P Angel                   1002785.0             male
# 1231           Patrick Au                   1002788.0             male
# 1232          Glen McNeil                    910664.0             male
#
#             Player B2  Player B2 Squash BC Number Player B2 Gender
# 0         Glen McNeil                    910664.0             male
# 1           Jeff Ward                   1003948.0             male
# 2     Andrea Guerrero                   1002668.0           female
# 3        Shelley Neil                   1003589.0           female
# 4        Soraya Kurji                   1000303.0           female
# ...               ...                         ...              ...
# 1228       Jim Miller                   1002957.0             male
# 1229   Claude Garceau                   1002765.0             male
# 1230    Juliana Angel                   1002786.0           female
# 1231      Gary Bombay                   1003752.0             male
# 1232       Adam Jinks                   1002874.0             male
#
# [1233 rows x 18 columns]

# %%
print(df.columns)
# Out:
# Index(['Match Date', 'Sport', 'Event Type', 'Event Name', 'Match Status',
#        'Game Scores', 'Player A1', 'Player A1 Squash BC Number',
#        'Player A1 Gender', 'Player A2', 'Player A2 Squash BC Number',
#        'Player A2 Gender', 'Player B1', 'Player B1 Squash BC Number',
#        'Player B1 Gender', 'Player B2', 'Player B2 Squash BC Number',
#        'Player B2 Gender'],
#       dtype='object')

# %%
df = df[
    [
        "Match Date",
        "Game Scores",
        "Player A1",
        "Player A2",
        "Player B1",
        "Player B2",
    ]
]

# %%
# Initialize Elo ratings for each player
elo_ratings = {}

# Initialize parameters for the Elo system
starting_elo = 1200  # Starting Elo rating for new players
k_factor_base = 32  # Base K-factor for Elo rating adjustments


# Function to calculate K-factor based on Elo rating
def calculate_k_factor(elo_rating):
    if elo_rating < 2000:
        return 30
    elif elo_rating < 2400:
        return 20
    else:
        return 10


# Function to calculate expected win probability based on Elo ratings
def expected_win_probability(player_elo, opponent_elo):
    return 1 / (1 + 10 ** ((opponent_elo - player_elo) / 400))


# Iterate through each row (match) in the DataFrame
for index, row in df.iterrows():
    # Extract match details
    game_score = row["Game Scores"]
    scores = game_score.split("-")
    score_a = int(scores[0][-1])
    score_b = int(scores[1][0])

    # Extract player names
    player_a1 = row["Player A1"]
    player_a2 = row["Player A2"]
    player_b1 = row["Player B1"]
    player_b2 = row["Player B2"]

    # Initialize Elo ratings for new players
    for player in [player_a1, player_a2, player_b1, player_b2]:
        if player not in elo_ratings:
            elo_ratings[player] = starting_elo

    # Calculate expected win probability for each team
    team_a_elo = (elo_ratings[player_a1] + elo_ratings[player_a2]) / 2
    team_b_elo = (elo_ratings[player_b1] + elo_ratings[player_b2]) / 2
    expected_win_a = expected_win_probability(team_a_elo, team_b_elo)
    expected_win_b = 1 - expected_win_a

    # Update Elo ratings based on actual outcome
    k_factor_a = calculate_k_factor(team_a_elo)
    k_factor_b = calculate_k_factor(team_b_elo)

    # Determine the score difference factor
    score_difference = abs(score_a - score_b)
    score_factor = 1 + (score_difference / 3)  # Adjust this factor as needed

    if score_a > score_b:
        # Team A won
        elo_ratings[player_a1] += k_factor_a * score_factor * (1 - expected_win_a)
        elo_ratings[player_a2] += k_factor_a * score_factor * (1 - expected_win_a)
        elo_ratings[player_b1] += k_factor_b * score_factor * (0 - expected_win_b)
        elo_ratings[player_b2] += k_factor_b * score_factor * (0 - expected_win_b)
    elif score_a < score_b:
        # Team B won
        elo_ratings[player_a1] += k_factor_a * score_factor * (0 - expected_win_a)
        elo_ratings[player_a2] += k_factor_a * score_factor * (0 - expected_win_a)
        elo_ratings[player_b1] += k_factor_b * score_factor * (1 - expected_win_b)
        elo_ratings[player_b2] += k_factor_b * score_factor * (1 - expected_win_b)
    else:
        # Draw
        pass

# Display or save the updated Elo ratings for each player
sorted_elo_ratings = sorted(elo_ratings.items(), key=lambda x: x[1], reverse=True)

for player, elo in sorted_elo_ratings:
    print(f"Player: {player}, Elo: {elo}")
# Out:
# Player: Andrew Smart, Elo: 1511.2650313152883
# Player: Cathy Covernton, Elo: 1504.343833424215
# Player: Jeff Boag, Elo: 1495.2608425369356
# Player: Brian Covernton, Elo: 1491.4781423595089
# Player: Rob Fought, Elo: 1412.396405549641
# Player: Ed Berwick, Elo: 1409.135121658221
# Player: Malcolm Moore, Elo: 1396.0041970395623
# Player: Erik Nilsson, Elo: 1384.0350114745843
# Player: Justin Todd, Elo: 1382.3719027719026
# Player: Carl McCreath, Elo: 1375.5513049729184
# Player: Hussein Salemwalla, Elo: 1369.7322731280744
# Player: Brendan George, Elo: 1369.1108522656732
# Player: Dave R Watson, Elo: 1368.6782700376023
# Player: Mark Heaney, Elo: 1367.1164250722486
# Player: Jamie Bleay, Elo: 1364.835742730707
# Player: Andrew Cunningham, Elo: 1364.4473333777078
# Player: Mike Lavigne, Elo: 1362.811454266913
# Player: Mikhail Din, Elo: 1361.5693103812418
# Player: Claude Garceau, Elo: 1360.232167093595
# Player: David Goldsmith, Elo: 1358.694384819802
# Player: Chris Wilson, Elo: 1356.788697815468
# Player: Bob Hodgins, Elo: 1354.5630310409622
# Player: Doug MacDougall, Elo: 1352.697027668038
# Player: Robert Pacey, Elo: 1344.3359143322245
# Player: Rachel Au, Elo: 1343.2567685602876
# Player: Nicola Martin, Elo: 1341.308411849292
# Player: Robert Ockeloen, Elo: 1336.0909557916332
# Player: Joe Lopes, Elo: 1334.9775986332163
# Player: Steve Lawton, Elo: 1334.13837808705
# Player: Eric Fought, Elo: 1334.1242725913385
# Player: Terry Sunar, Elo: 1333.2403671177774
# Player: Tam Do, Elo: 1325.2013392027577
# Player: Thomas Haebler, Elo: 1323.299448655602
# Player: Derek Smith, Elo: 1322.7309943393666
# Player: Leslie Kerluke, Elo: 1319.159077338662
# Player: Brian MacFarlane, Elo: 1311.5639189180974
# Player: Michael Birch, Elo: 1311.226268683164
# Player: Tessa Breukels, Elo: 1307.8301369406952
# Player: Karen Levine, Elo: 1307.0655461695396
# Player: Doug Conyers, Elo: 1299.3676424351202
# Player: Duncan Maxwell, Elo: 1299.3560911882041
# Player: Ryan Haider, Elo: 1298.8875278424496
# Player: Ingus Silgailis, Elo: 1298.1680912204638
# Player: Dennis Hoffman, Elo: 1297.1607819554363
# Player: Jillian Anderson, Elo: 1297.1348550541486
# Player: Rick Ng, Elo: 1294.8850575996319
# Player: Mark Ridgeway, Elo: 1293.783328876762
# Player: Hugh Notman, Elo: 1293.6345526032328
# Player: Shan Trouton, Elo: 1292.02671172344
# Player: Charlie Park, Elo: 1290.240662402499
# Player: Lauren Price, Elo: 1288.95087717045
# Player: Blake Pottinger, Elo: 1288.8879511284613
# Player: Jason Del Vicario, Elo: 1288.297489583817
# Player: Brian Maclean, Elo: 1288.293120767423
# Player: Roland Haebler, Elo: 1284.3641723867845
# Player: Andrew Ripley, Elo: 1282.9910836479812
# Player: Aaron Lakhani, Elo: 1282.9358407257753
# Player: Geoff Emslie, Elo: 1281.7858467833182
# Player: Snehal Lakhani , Elo: 1281.417210846282
# Player: Matthew Taylor, Elo: 1279.6161031544639
# Player: Kinder Mottus, Elo: 1278.0956287394129
# Player: Tim Martin, Elo: 1277.88113162115
# Player: Max Gillanders, Elo: 1273.529448555784
# Player: Christian Schwendener, Elo: 1273.414940778865
# Player: Christine Yablonka, Elo: 1270.4665578224585
# Player: Megan Picken, Elo: 1270.235510003917
# Player: Brian Gulayets, Elo: 1265.8258288155762
# Player: Bryan Askin, Elo: 1265.6691898246124
# Player: Monica Szpak, Elo: 1265.4083867795532
# Player: Yasmine Franchi, Elo: 1264.9806750498092
# Player: Greg Charalambous, Elo: 1264.3799008459387
# Player: Bruce Matthews, Elo: 1263.1957804787548
# Player: Tony Gabriel, Elo: 1262.8143018125688
# Player: Inderbir Hundal, Elo: 1262.4680802287749
# Player: Morgan Latremouille, Elo: 1262.176487191559
# Player: John Osburn, Elo: 1261.2943551263277
# Player: Marvin Mizinski, Elo: 1260.2029944552319
# Player: Ruth Castellino, Elo: 1259.4829409067925
# Player: James Woodcock, Elo: 1259.364074641408
# Player: Doug Milne, Elo: 1257.4752738837844
# Player: Viktor Berg, Elo: 1256.4947560391859
# Player: Bob Rutherford, Elo: 1255.4835942493037
# Player: Janine Waite, Elo: 1254.6455362962474
# Player: Lialah Mavani, Elo: 1252.4850980208591
# Player: Sayeed Mavani, Elo: 1252.4850980208591
# Player: Max Hakh, Elo: 1251.6388153330622
# Player: Elizabeth  Macey, Elo: 1251.4674381290681
# Player: Tim Mosley, Elo: 1250.4956831196043
# Player: DAREN ADAMS, Elo: 1249.9992372383838
# Player: Hamid Khosrow Kiani, Elo: 1248.7099712209988
# Player: Greg Almas, Elo: 1246.3514218931111
# Player: Cameron Jackson, Elo: 1244.818068466984
# Player: Bruce Macfarlane, Elo: 1243.6030615879308
# Player: Alex Garceau, Elo: 1242.6855204244841
# Player: Norm Ellis, Elo: 1238.9147129070661
# Player: Valerie Johnson, Elo: 1238.6323349909444
# Player: Deborah Soo Lum, Elo: 1238.4580251588075
# Player: Louise Fogharty, Elo: 1237.9210463085158
# Player: Gareth Martin, Elo: 1237.5532102437235
# Player: Andy Hone, Elo: 1237.5087636707453
# Player: Jake McAdam, Elo: 1237.0915595771885
# Player: Grant Bergman, Elo: 1235.6447853871466
# Player: Matt Bicknell, Elo: 1232.8537339315303
# Player: Ava Bicknell, Elo: 1232.8537339315303
# Player: Adam Jinks, Elo: 1232.7929248114337
# Player: Daryle Birnie, Elo: 1232.1584230485082
# Player: Gavin Maxwell, Elo: 1231.6421019337815
# Player: Shawn Patton, Elo: 1230.8919195758094
# Player: Bob Bogue, Elo: 1230.7154085863774
# Player: Simon Dorey, Elo: 1229.5562481939041
# Player: Simon Bicknell, Elo: 1228.2819705458483
# Player: Roman Bicknell, Elo: 1228.2819705458483
# Player: Eric Barclay, Elo: 1227.9258141350344
# Player: Will Stiphout, Elo: 1227.1785945448428
# Player: Gordon Pybus, Elo: 1227.026471789083
# Player: Herb Evers, Elo: 1226.6021211395323
# Player: Thomas Brinkman, Elo: 1226.0806970344136
# Player: Sue Kaffka, Elo: 1225.693726262395
# Player: Kip Kramer, Elo: 1225.4847029581185
# Player: Glenn Sorensen, Elo: 1225.2374211398512
# Player: Andrea Guerrero, Elo: 1225.0
# Player: mike  dodds, Elo: 1224.8201136442187
# Player: David Tucker, Elo: 1224.427148058291
# Player: Jennifer Levey, Elo: 1224.0781624012511
# Player: Tiffany Jung, Elo: 1222.8095351078325
# Player: Neil Johansen, Elo: 1222.4861170181666
# Player: Richard Johansen, Elo: 1222.4861170181666
# Player: Jon Bishop, Elo: 1222.4129834959108
# Player: Richard  Yendell, Elo: 1222.3756147836787
# Player: Will Gaherty, Elo: 1221.2325240439563
# Player: Byron Kidd, Elo: 1220.976640860014
# Player: Brook Parkin, Elo: 1220.8194985129276
# Player: Abby Kidd, Elo: 1220.7364615923286
# Player: Donna  Pakaluk, Elo: 1220.1078984699257
# Player: Diana Hardie, Elo: 1220.0
# Player: Ben Gaster, Elo: 1218.9616387322944
# Player: Mike Neilson, Elo: 1218.886131729748
# Player: Tim Kehler, Elo: 1218.7987200753626
# Player: Greg Desaulniers, Elo: 1218.436941111334
# Player: Luke Vaggers, Elo: 1218.2752638067514
# Player: Doug McDougal, Elo: 1217.3699748057907
# Player: Noel McDowell, Elo: 1216.2768450955389
# Player: Brian Meakin, Elo: 1215.1910495419347
# Player: Paddy Penn, Elo: 1214.512312861702
# Player: Sofia Ansari, Elo: 1213.8058942670891
# Player: Nicola Ahern, Elo: 1213.6207298369252
# Player: Luis Moran, Elo: 1213.554277689122
# Player: Alicia Haneine, Elo: 1212.5394784189982
# Player: Doug Buchanan, Elo: 1210.1982538028699
# Player: Michael Leckie, Elo: 1209.9553986709566
# Player: Mark St.Georges, Elo: 1208.7182079867948
# Player: Wayne Jackson, Elo: 1207.8717648468155
# Player: Guy Steuart, Elo: 1206.5158353108138
# Player: Matt Reece, Elo: 1205.5049215136714
# Player: Paul Tindle, Elo: 1205.4085831138773
# Player: Dennis Forsman, Elo: 1205.0651509243705
# Player: Albert Troll, Elo: 1204.6479487754204
# Player: Paul Austin, Elo: 1203.4748775190026
# Player: Patricia Penn, Elo: 1203.2112170561709
# Player: Sam Davison, Elo: 1202.2541869407455
# Player: Peter Reimer, Elo: 1201.9800517252181
# Player: Kelsey Parsons, Elo: 1201.6085840517592
# Player: Dennis Cusack, Elo: 1201.281426921893
# Player: Drew Henderson, Elo: 1200.9047999704032
# Player: Sarfaraz Ahmed, Elo: 1200.9047999704032
# Player: No Player, Elo: 1200.0
# Player: Ashley Ramsden-Wood, Elo: 1199.4146272789742
# Player: Ian Binstead, Elo: 1198.6155331342202
# Player: Jeffrey Harnum, Elo: 1198.4979708805079
# Player: Emma Parke, Elo: 1197.973943531833
# Player: Jamie Goddard, Elo: 1197.9552635837963
# Player: Melodie Flook, Elo: 1197.71130667113
# Player: Sasha Djurdjevic, Elo: 1197.1829415504887
# Player: Jeff Smithson, Elo: 1196.286088444066
# Player: Garth Edgar, Elo: 1196.2665611852055
# Player: Tristan Bracewell , Elo: 1196.1804671311745
# Player: Gregg Ashby, Elo: 1194.0092299042356
# Player: Richard Chester, Elo: 1192.9164384242856
# Player: Hugh Woolley, Elo: 1192.3853240973392
# Player: Paul Gray, Elo: 1190.698351964602
# Player: brad ridgway, Elo: 1190.4425457199713
# Player: Olivia Maxwell, Elo: 1190.3895999191734
# Player: Brian Markus, Elo: 1190.0124378891032
# Player: Nancy Thompson, Elo: 1189.8211190555437
# Player: Kevin Johnson, Elo: 1188.7209419451806
# Player: Randy Mottus, Elo: 1188.0510855987798
# Player: Courtenay Davies, Elo: 1187.4568731479508
# Player: Peter OLoughlin, Elo: 1187.1892207255016
# Player: Mark Hinchcliffe, Elo: 1186.3636592590808
# Player: Daniel Karnowsky, Elo: 1186.3636592590808
# Player: Jim Miller, Elo: 1186.2172481479279
# Player: Donna Pakulak, Elo: 1185.7104487635877
# Player: David Bauman, Elo: 1185.523809981851
# Player: Jennifer McKinley, Elo: 1184.8451688852479
# Player: Shelley Neil, Elo: 1184.7579321030403
# Player: Leo Chester, Elo: 1183.26413180866
# Player: Glen McNeil, Elo: 1183.198246478632
# Player: Jackson Baker, Elo: 1182.892088323585
# Player: Ed McCorkell, Elo: 1182.8635567783194
# Player: Rod Nicolls, Elo: 1181.876019856543
# Player: Anna Kirbyson, Elo: 1181.095040547109
# Player: Penni Brink, Elo: 1179.8644857067404
# Player: Matt Desouza, Elo: 1179.8259716044788
# Player: Peter Tallman, Elo: 1178.9151930066846
# Player: Rod McKeen, Elo: 1178.544471695121
# Player: Shane Sibley NV, Elo: 1177.7227534563167
# Player: Tom Carter, Elo: 1177.313664305018
# Player: Jeff Evans, Elo: 1176.9200140646453
# Player: Mike Kaffka, Elo: 1176.2586397583339
# Player: Pamela White, Elo: 1176.1071214383142
# Player: Greg Charalambus, Elo: 1176.0665849684804
# Player: Carolyn Russell, Elo: 1175.0003068630224
# Player:  , Elo: 1175.0
# Player: Michael Walker, Elo: 1173.2452990908714
# Player: Daniel Allard, Elo: 1172.9013955615033
# Player: Frances Frost, Elo: 1171.9078448690514
# Player: Juan P Angel, Elo: 1171.5113087305144
# Player: Juliana Angel, Elo: 1171.5113087305144
# Player: Noel MacDowell, Elo: 1171.260645402922
# Player: Matthew Waite, Elo: 1171.09517634854
# Player: Bill James, Elo: 1168.8262740827727
# Player: Laurence Owen, Elo: 1168.1177908356635
# Player: Zach Owen, Elo: 1168.1177908356635
# Player: Razaan Lalji, Elo: 1167.922579333938
# Player: Kian Lalji, Elo: 1167.922579333938
# Player: Paul Stevenson, Elo: 1167.5932305837382
# Player: Bevan Moss, Elo: 1167.5344752576314
# Player: Duncan  Genge, Elo: 1166.4951563399206
# Player: Madeleine Sava, Elo: 1166.030735955651
# Player: Beverly Lawton, Elo: 1165.6486914094314
# Player: Rod McKeown, Elo: 1165.3056116157918
# Player: Bruce Pope, Elo: 1163.500679941943
# Player: Cathy Brown, Elo: 1162.5881741816256
# Player: Daryl Heathman, Elo: 1161.0174549677156
# Player: David Thistle, Elo: 1160.900699998985
# Player: Bob Wickett, Elo: 1160.390796408874
# Player: Adam Mullock, Elo: 1160.2755250132293
# Player: Randy Mullock, Elo: 1160.2755250132293
# Player: Jody Evans, Elo: 1160.185552072244
# Player: Annie Novoa, Elo: 1158.9945926764697
# Player: Mike Carrier, Elo: 1158.9471625577014
# Player: Gerry Takeuchi, Elo: 1158.4409886370274
# Player: Matthew McAdam, Elo: 1157.9539451877733
# Player: Chad Forbes, Elo: 1157.9198719375772
# Player: Laura Ramsay, Elo: 1157.9188414466132
# Player: Soraya Kurji, Elo: 1157.9011324284331
# Player: Bob Puddicombe, Elo: 1157.3878378145698
# Player: Liz Tuck, Elo: 1157.2929206233184
# Player: Mark Longpre, Elo: 1157.1467605351909
# Player: Michael Longpre, Elo: 1157.1467605351909
# Player: Bonnie Cooney, Elo: 1156.8143261497744
# Player: George Maddison, Elo: 1154.833241702873
# Player: Nick James, Elo: 1154.2871951028205
# Player: Jon De Souza, Elo: 1153.2924074958992
# Player: Joe Martin, Elo: 1152.591586236103
# Player: Ben Boon, Elo: 1151.7929201454838
# Player: Chris Davies, Elo: 1150.2374493797881
# Player: Mark Levey, Elo: 1150.2025064660932
# Player: Warren Woodman, Elo: 1149.1539292722543
# Player: Ross Genge, Elo: 1148.0030887822743
# Player: Rhonda Porter, Elo: 1147.965720742066
# Player: Adam Terheege, Elo: 1145.6718268138234
# Player: Damian Botteselle, Elo: 1145.582582181801
# Player: Lane du Toit, Elo: 1145.582582181801
# Player: Lynn Broman, Elo: 1144.475749934133
# Player: Steve Baker, Elo: 1144.2647634811724
# Player: Andrew Mount, Elo: 1144.2340637833897
# Player: Rick Kochanski, Elo: 1143.185038543742
# Player: James Yang, Elo: 1143.0754602943914
# Player: Mark  St. Georges, Elo: 1142.2305926012964
# Player: Kevin McElgunn, Elo: 1141.761235783386
# Player: Penny Paul, Elo: 1141.7068812191603
# Player: Patrick Au, Elo: 1140.2534267634298
# Player: Chris Staargaard, Elo: 1140.067237886236
# Player: Tyler Steele, Elo: 1137.9455085974603
# Player: mike  mclsaac , Elo: 1137.9455085974603
# Player: Matt Warner, Elo: 1136.86444218948
# Player: Jamie Sonego, Elo: 1136.520359351563
# Player: Dayton Bracewell, Elo: 1135.777929133387
# Player: Cole Parmar, Elo: 1135.777929133387
# Player: John MacLean, Elo: 1135.4477864945984
# Player: Ana Laureano, Elo: 1134.890185356256
# Player: Paul Brebner, Elo: 1133.3797655820058
# Player: Martin Kaffka, Elo: 1132.9196284161656
# Player: Allison Wallace, Elo: 1131.0935852624898
# Player: Chuck Williams, Elo: 1130.8147984915445
# Player: Dana Merritt, Elo: 1129.5897522610314
# Player: Melissa Troll, Elo: 1129.015000459386
# Player: Deidre Smith, Elo: 1126.5345729450921
# Player: Richard Freeman, Elo: 1126.391312501988
# Player: Jennifer Pearson, Elo: 1124.2624889053318
# Player: John Grant, Elo: 1123.4372020814462
# Player: David O'Brien, Elo: 1123.0528022733674
# Player: Sylvia Males, Elo: 1122.838209165923
# Player: Dave Canning, Elo: 1121.716199047548
# Player: Mary Anne Keilty, Elo: 1120.2254657406086
# Player: Ian MacKinnon, Elo: 1117.3881623245215
# Player: Marilyn Mah, Elo: 1117.1551475564868
# Player: John Wordsworth, Elo: 1116.8667168410832
# Player: Mike Young, Elo: 1116.6857737932396
# Player: Rip Peterman, Elo: 1115.2664544553522
# Player: Kim Wilson-Sheldon, Elo: 1114.391093054171
# Player: Richard Dustan, Elo: 1114.3169935643903
# Player: Helen Kim, Elo: 1113.2306316289853
# Player: Claire Simpkins, Elo: 1111.628627990206
# Player: Noah Deziel, Elo: 1109.279519438712
# Player: Rob Forrest, Elo: 1106.4548043661405
# Player: Ryan May, Elo: 1106.0545231798424
# Player: Lynn Buntain, Elo: 1105.6434972743348
# Player: Julienne Joe, Elo: 1101.786207764354
# Player: Gary Evans, Elo: 1101.3342095816458
# Player: Ashley Walker, Elo: 1101.1413643139367
# Player: Greg Coutts, Elo: 1100.8592809786207
# Player: Jane McDonald, Elo: 1100.1645513707192
# Player: Richard Martin, Elo: 1096.210522284545
# Player: Caitlin Hungerford, Elo: 1095.6672899719297
# Player: Dan Allard, Elo: 1092.1857210193339
# Player: Jongho Kim, Elo: 1088.8313175817311
# Player: Charlie Maddison, Elo: 1088.7555221283465
# Player: John King, Elo: 1088.0859611480607
# Player: Tony Quan, Elo: 1086.052565768409
# Player: Miranda Lam, Elo: 1084.721982882591
# Player: Ron Simmer, Elo: 1082.7526184719115
# Player: Stacy Hall, Elo: 1078.9090405826419
# Player: Mike Tooley, Elo: 1075.8103952899871
# Player: Paul Deziel, Elo: 1064.6850870962587
# Player: Scott Sibley, Elo: 1057.2172508537665
# Player: Gerry Whitworth, Elo: 1056.7417031331222
# Player: Tony Goodson, Elo: 1056.5924424796453
# Player: Liam Gillanders, Elo: 1056.5924424796453
# Player: Keith Schaefer, Elo: 1051.1459056120552
# Player: Chris Galer, Elo: 1045.4753111684408
# Player: Alan Farlow, Elo: 1031.1608826140957
# Player: Pamela Brunswick, Elo: 1029.8818012424008
# Player: Wayne Maunder, Elo: 1028.8988711481807
# Player: Gary Bombay, Elo: 1027.7883700530217
# Player: Boyd Muir, Elo: 1021.4039879079545
# Player: Chris Wallace, Elo: 1018.2243290762337
# Player: Maurice Goulet, Elo: 1013.6040654887746
# Player: Tom Locke, Elo: 1010.7219267327181
# Player: Lisa Norlander, Elo: 1008.0618646861702
# Player: Connie Engh, Elo: 1006.2944534276039
# Player: Harry Chow, Elo: 1003.8092348171399
# Player: Angel Wong, Elo: 982.5279594584612
# Player: Annika Lakhani, Elo: 962.8442632492597
# Player: Jeff Ward, Elo: 948.5977986598874
# Player: Tom Horler, Elo: 937.1274896496449
# Player: Annette Johanson, Elo: 933.3801611474772

# %%
# Initialize win and loss counters
wins = 0
losses = 0
name = "Grant Bergman"

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    # Extract match details
    game_score = row['Game Scores']
    scores = game_score.split('-')
    score_a = int(scores[0][-1])
    score_b = int(scores[1][0])

    # Extract player names (assuming the capitalization of 'p' in 'Player')
    player_a1 = row['Player A1']
    player_a2 = row['Player A2']
    player_b1 = row['Player B1']
    player_b2 = row['Player B2']

    # Check if player is part of the winning team
    if name in [player_a1, player_a2] and score_a > score_b:
        wins += 1
    elif name in [player_b1, player_b2] and score_b > score_a:
        wins += 1
    elif name in [player_a1, player_a2] or name in [player_b1, player_b2]:
        losses += 1

print(f"{name}'s Win-Loss Record: {wins}-{losses}")
# Out:
# Grant Bergman's Win-Loss Record: 3-1
